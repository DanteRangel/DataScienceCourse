# %% [markdown]
# # Redes Neuronales
#
# En este notebook vamos a construir la unidad básica de las redes neuronales, el Perceptrón. Tiene dos partes:
# 1. **Perceptrón a mano**: primero, vamos a estudiar la función sigmoide y la entropía categórica para un caso sencillo, unidimensional. Vamos a encontrar el mínimo de la función de costo haciendo una exploración exhaustiva del espacio de parámetros, simil GridSearch. Podríamos también hacer la parte de gradiente descendiente, pero excede el alcance de lo que queremos presentar en el curso, y además para eso están las librerías como Keras. De todas formas, si alguien se anima, puede intentarlo y lo ayudamos con algunas pistas.
# 2. **Perceptrón con Keras**: luego, vamos a entrenar un Perceptrón con Keras sobre el mismo dataset. Vamos a usarlo como excusa para presentar las principales características de la librería.
# 3. **Perceptrón 2D**: vamos a entrenar un Perceptrón con Keras sobre un dataset ficticio. Exploramos cómo son las fronteras en 2D. Limitaciones del Perceptrón. Como probablemente no alcance el tiempo en esta clase, esta sección también será el comienzo del siguiente notebook.
#
# ## 1. Perceptrón a mano
#
# El objetivo es ajustar un Perceptrón a los datos del Challenger. Recuerden estos datos tienen un solo feature, la temperatura. ¿Cuántos parámetros tendrá el Perceptrón?
#
# 1. Escribir una función que, dado un vector x y dos parámetros w0 y w1, calcula la función sigmoide. Hacer un plot para algunos parámetros, tratando de obtener los gráficos de la presentación.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.set()

# %%
def sigmoid_function(x,w0, w1):
    '''Equivalente a perceptron con funcion de activacion sigmoide'''
    z = w0 + w1*x #notar que es una funcion lineal
    y = 1/(1 + np.exp(-z))   #notar que es una composicion
    return y

# %%
x = np.linspace(-10,10,500)

y = sigmoid_function(x, 0,1)
plt.plot(x,sigmoid_function(x, 0,1), label = 'w0 = 0, w1 = 1')
plt.plot(x,sigmoid_function(x, 0,-1), label = 'w0 = 0, w1 = -1')

plt.legend()
plt.tight_layout()
# plt.savefig('regresion_logistica.png', dpi = 400)

plt.show()

# %% [markdown]
# 2. Escribir una función que, dado la etiqueta de una instancia `y` y una predicción `y_pred`, calcula la función de perdida *entropía cruzada*. Hacer un plot para el caso `y = 0` e `y = 1`, tratando de obtener los gráficos de la presentación.

# %%
def cross_entropy_loss(y, y_pred):
    L = -y*np.log(y_pred) - (1-y)*np.log(1 - y_pred)
    return L

# %%
y = 1
ys_pred = np.linspace(0,1,1000)
plt.plot(ys_pred, cross_entropy_loss(y,ys_pred))
plt.xlabel('y_pred, probabilidad predicha')
plt.ylabel('Perdida')
plt.title('y = 1')
plt.tight_layout()
# plt.savefig('perdida_0.png', dpi = 400)
plt.show()
# Out:
# /Users/danteulisesrangelrobles/miniconda3/envs/datascience/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#
# /Users/danteulisesrangelrobles/miniconda3/envs/datascience/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in multiply

# %% [markdown]
# 3. Escribir una función que, dado las etiquetas muchas instancias `y` y las predicciones `y_pred`, calcula la función de  costo *entropía cruzada* para todas las instancias. PISTA: hacer un `for` sobre las instancias y llamar a la función `cross_entropy_loss` que crearon antes.

# %%
def cross_entropy_cost(y, y_pred):
    ## Un sanity check
    assert y_pred.size == y.size, 'Ojo que los vectores no tienen el mismo tamaño'
    
    y_pred = y_pred.reshape(y_pred.size)
    y = y.reshape(y.size)
    J = 0
    for i in range(y_pred.size):
        J += cross_entropy_loss(y[i], y_pred[i])
    J /= y_pred.size
    return J

# %%
### Por si alguno/a quiere ver por que no usamos esta funcion de costo
def MSE(y,y_pred):
    '''Calcula Mean Squared Error'''
    assert(len(y) == len(y_pred))
    n = len(y)
    return ((y - y_pred)**2).sum()/n

# %% [markdown]
# **Datos del Challenger**
#
# Cargamos los datos usados en la presentación. Nosotros nos encargamos del preprocesamiento y de los gráficos.

# %%
dataset = pd.read_csv('../datasets//DS_Encuentro_30_Challenger.csv')
dataset.dropna(inplace = True) # Tiramos los NaN (una sola fila)
dataset['Temperature (C)'] = np.round((dataset['Temperature'] - 32)/1.8,2) # pasamos a celcius
dataset
# Out:
#           Date  Temperature      Damage Incident  Temperature (C)
# 0   04/12/1981           66                    0            18.89
# 1   11/12/1981           70                    1            21.11
# 2      3/22/82           69                    0            20.56
# 4   01/11/1982           68                    0            20.00
# 5   04/04/1983           67                    0            19.44
# 6      6/18/83           72                    0            22.22
# 7      8/30/83           73                    0            22.78
# 8     11/28/83           70                    0            21.11
# 9   02/03/1984           57                    1            13.89
# 10  04/06/1984           63                    1            17.22
# 11     8/30/84           70                    1            21.11
# 12  10/05/1984           78                    0            25.56
# 13  11/08/1984           67                    0            19.44
# 14     1/24/85           53                    1            11.67
# 15  04/12/1985           67                    0            19.44
# 16     4/29/85           75                    0            23.89
# 17     6/17/85           70                    0            21.11
# 18     7/29/85           81                    0            27.22
# 19     8/27/85           76                    0            24.44
# 20  10/03/1985           79                    0            26.11
# 21    10/30/85           75                    1            23.89
# 22    11/26/85           76                    0            24.44
# 23  01/12/1986           58                    1            14.44
# 24     1/28/86           31  Challenger Accident            -0.56

# %%
plt.figure(figsize = (8,4))
plot = sns.scatterplot(x = 'Date', y  = 'Temperature (C)', hue = 'Damage Incident', data = dataset, s = 100)
for item in plot.get_xticklabels():
    item.set_rotation(90)
plt.tight_layout()
plt.show()

# %%
# dataset.drop([24], inplace = True)
plt.figure(figsize = (8,4))
plot = sns.scatterplot(x = 'Temperature (C)', y  = 'Damage Incident', hue = 'Damage Incident', data = dataset, s = 100)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Variables para entrenamiento**

# %%
X = dataset.drop([24])['Temperature (C)'].values
y = dataset.drop([24])['Damage Incident'].values.astype(int)

# %% [markdown]
# Es muy importante reescalar los datos cuando trabajen con Redes Neuronales

# %%
X_mean = X.mean()
X_std = X.std()
X = (X - X_mean)/X_std

# %% [markdown]
# **Explorando la función de costo**
#
# El objetivo es lograr obtener el gráfico de la función de costo como hicimos la clase anterior. Para ellos, es importante que respondan: ¿cuántos parámetros tiene la función sigmoide/perceptrón?¿Qué tipo de gráfico quieren obtener?
#
# 1. Crear un arreglo con valores para w0 y w1 (`w0s, w1s`)

# %%
w0s = np.linspace(-5,0,50)
w1s = np.linspace(-5,0,50)

# %% [markdown]
# 2. Recorrer los dos arreglos y calcular el costo para cada combinación de parámetros `w0, w1`

# %%
#%%time
costos = []
for w0 in w0s:
    for w1 in w1s:
        y_pred = sigmoid_function(X.flatten(), w0,w1)
#         costos.append(MSE(y,y_pred))
        costos.append(cross_entropy_cost(y,y_pred))
costos = np.array(costos)

# %% [markdown]
# 3. Graficar

# %%
W0s, W1s = np.meshgrid(w0s,w1s, indexing = 'ij')
costos_matriz = costos.reshape(w0s.size, w1s.size)

# %%
idxs_minimo = np.unravel_index(costos_matriz.argmin(), costos_matriz.shape)
fig = plt.figure(figsize = (8,6))
ax = fig.gca()

plt.pcolormesh(W0s, W1s,costos_matriz)
ax.contourf(W0s, W1s, costos_matriz)
plt.colorbar()
plt.scatter(W0s[idxs_minimo], W1s[idxs_minimo])
plt.title('Costo en el minimo:' + str(costos_matriz[idxs_minimo]))
plt.xlabel('W0')
plt.ylabel('W1')
plt.tight_layout()
plt.show()

# %%
w0_encontrado = W0s[idxs_minimo]
w1_encontrado = W1s[idxs_minimo]

print('w0 encontrado:', w0_encontrado)
print('w1 encontrado:', w1_encontrado)
# Out:
# w0 encontrado: -1.1224489795918364
# w1 encontrado: -1.6326530612244898

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib as mpl

fig = plt.figure(figsize = (8,6))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(W0s, W1s,costos_matriz,linewidth=0.0, antialiased=False, cmap = 'plasma')
# ax.view_init(0, 180)
ax.set_xlabel('m')
ax.set_ylabel('b')
ax.set_zlabel('costo')
plt.tight_layout()
plt.colorbar(surf)    
plt.show()

# %% [markdown]
# 4. Graficar la función sigmoide para los parámetros obtenidos.

# %%
X_mean
# Out:
# 20.868695652173916

# %%
plt.figure(figsize = (8,4))
plot = sns.scatterplot(x = 'Temperature (C)', y  = 'Damage Incident', hue = 'Damage Incident', data = dataset, s = 100)

x_plot = np.linspace(-5,30,100)
z = (x_plot - X_mean)/X_std
plt.plot(x_plot, sigmoid_function(z,w0_encontrado,w1_encontrado))

plt.axhline(0.5, ls = '--', c = 'r', label = 'probabilidad de 0.5')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Perceptron con Keras
#
#
# Keras es un entorno de desarrollo para Redes Neuronales de alto nivel. Esto quiere decir que es - o al menos trata de ser- más amigable que otros entornos de desarrollo, como por ejemplo TensorFlow. Sin embargo, está basado en TensorFlow, que es quien hace el "trabajo pesado". Una de las principales ventajas de Keras es que es rápido para hacer prototipos, hay muchas funciones de costo, optimizadores y tipo de neuronas implementadas, lo cual lo hacen muy versátil.
#
# Tal vez una desventaja sea que la documentación tiende a ser escueta. Pero por otro lado hay muchos ejemplos y tutoriales en internet que se pueden usar que están buenos.
#
# https://keras.io/getting-started/sequential-model-guide/
#
# Los pasos básicos a seguir con Keras son:
# 1. Definimos un modelo: indicamos cantidad y tipos de neuronas.
# 2. Compilamos el modelo: indicamos función de costo y optimizador.
# 3. Entrenamos el modelo: cantidad de iteraciones y otros parámetros.

# %% [markdown]
# 1. Definimos el modelo. El tipo de modelo se llama `Sequential` y le agregamos una capa (`layer`) con una Neurona `Dense`, con una función de activación `'sigmoid'`.

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(1, activation='sigmoid'))
# Out:
# Using TensorFlow backend.

# %% [markdown]
# 2. Compilamos el modelo llamando a `model.compile(...)`. Los argumentos más importantes son el optimizador `optimizer`, la pérdida `loss` y, si queremos, un métrica que evalúa durante el entrenamiento. **Importante**: solamente la evalúa, nada más.
#
# La forma en que pasamos los argumentos no es la única que hay, también se pueden crear *objetos* optimizadores y pasarles argumentos de forma más detallada. Mirar algunos ejemplos en la documentación.

# %%
# model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])
# optimizer = keras.optimizers.Adam(lr=0.001, beta_1=0.0, beta_2=0.0, epsilon=None, decay=0.0, amsgrad=False)

optimizer = keras.optimizers.Adam(lr=0.001, beta_1=0.0, beta_2=0.0, decay=0.0, amsgrad=False)
model.compile(optimizer = optimizer,loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# 3. Entrenamos el modelo con `model.fit(...)`. Los argumentos son, en primer lugar, los features `X` y las etiquetas `y`, y la cantidad de iteraciones `epochs`.

# %%
X = X.reshape(X.size, 1)
history = model.fit(X, y, epochs=1000)
# Out:
# Epoch 1/1000
# 23/23 [==============================] - 0s 17ms/step - loss: 0.5421 - accuracy: 0.6087
# Epoch 2/1000
# 23/23 [==============================] - 0s 140us/step - loss: 0.5419 - accuracy: 0.6087
# Epoch 3/1000
# 23/23 [==============================] - 0s 154us/step - loss: 0.5417 - accuracy: 0.6087
# Epoch 4/1000
# 23/23 [==============================] - 0s 143us/step - loss: 0.5415 - accuracy: 0.6087
# Epoch 5/1000
# 23/23 [==============================] - 0s 264us/step - loss: 0.5413 - accuracy: 0.6087
# Epoch 6/1000
# 23/23 [==============================] - 0s 120us/step - loss: 0.5410 - accuracy: 0.6087
# Epoch 7/1000
# 23/23 [==============================] - 0s 135us/step - loss: 0.5408 - accuracy: 0.6087
# Epoch 8/1000
# 23/23 [==============================] - 0s 84us/step - loss: 0.5406 - accuracy: 0.6087
# Epoch 9/1000
# 23/23 [==============================] - 0s 98us/step - loss: 0.5404 - accuracy: 0.6087
# Epoch 10/1000
# 23/23 [==============================] - 0s 162us/step - loss: 0.5402 - accuracy: 0.6087
# Epoch 11/1000
# 23/23 [==============================] - 0s 210us/step - loss: 0.5399 - accuracy: 0.6087
# Epoch 12/1000
# 23/23 [==============================] - 0s 137us/step - loss: 0.5397 - accuracy: 0.6087
# Epoch 13/1000
# 23/23 [==============================] - 0s 120us/step - loss: 0.5395 - accuracy: 0.6087
# Epoch 14/1000
# 23/23 [==============================] - 0s 101us/step - loss: 0.5393 - accuracy: 0.6087
# Epoch 15/1000
# 23/23 [==============================] - 0s 138us/step - loss: 0.5391 - accuracy: 0.6087
# Epoch 16/1000
# 23/23 [==============================] - 0s 235us/step - loss: 0.5388 - accuracy: 0.6087
# Epoch 17/1000
# 23/23 [==============================] - 0s 129us/step - loss: 0.5386 - accuracy: 0.6087
# Epoch 18/1000
# 23/23 [==============================] - 0s 108us/step - loss: 0.5384 - accuracy: 0.6087
# Epoch 19/1000
# 23/23 [==============================] - 0s 99us/step - loss: 0.5382 - accuracy: 0.6087
# Epoch 20/1000
# 23/23 [==============================] - 0s 126us/step - loss: 0.5380 - accuracy: 0.6087
# Epoch 21/1000
# 23/23 [==============================] - 0s 105us/step - loss: 0.5378 - accuracy: 0.6087
# Epoch 22/1000
# 23/23 [==============================] - 0s 98us/step - loss: 0.5376 - accuracy: 0.6087
# Epoch 23/1000
# 23/23 [==============================] - 0s 163us/step - loss: 0.5373 - accuracy: 0.6087
# Epoch 24/1000
# 23/23 [==============================] - 0s 171us/step - loss: 0.5371 - accuracy: 0.6087
# Epoch 25/1000
# 23/23 [==============================] - 0s 165us/step - loss: 0.5369 - accuracy: 0.6087
# Epoch 26/1000
# 23/23 [==============================] - 0s 83us/step - loss: 0.5367 - accuracy: 0.6087
# Epoch 27/1000
# 23/23 [==============================] - 0s 125us/step - loss: 0.5365 - accuracy: 0.6087
# Epoch 28/1000
# 23/23 [==============================] - 0s 94us/step - loss: 0.5363 - accuracy: 0.6087
# Epoch 29/1000
# 23/23 [==============================] - 0s 98us/step - loss: 0.5361 - accuracy: 0.6087
# Epoch 30/1000
# 23/23 [==============================] - 0s 93us/step - loss: 0.5358 - accuracy: 0.6087
# Epoch 31/1000
# 23/23 [==============================] - 0s 111us/step - loss: 0.5356 - accuracy: 0.6087
# Epoch 32/1000
# 23/23 [==============================] - 0s 149us/step - loss: 0.5354 - accuracy: 0.6087
# Epoch 33/1000
# 23/23 [==============================] - 0s 77us/step - loss: 0.5352 - accuracy: 0.6087
# Epoch 34/1000
# 23/23 [==============================] - 0s 230us/step - loss: 0.5350 - accuracy: 0.6087
# Epoch 35/1000
# 23/23 [==============================] - 0s 100us/step - loss: 0.5348 - accuracy: 0.6087
# Epoch 36/1000
# 23/23 [==============================] - 0s 90us/step - loss: 0.5346 - accuracy: 0.6087
# Epoch 37/1000
# 23/23 [==============================] - 0s 129us/step - loss: 0.5344 - accuracy: 0.6087
# Epoch 38/1000
# 23/23 [==============================] - 0s 152us/step - loss: 0.5342 - accuracy: 0.6087
# Epoch 39/1000
# 23/23 [==============================] - 0s 70us/step - loss: 0.5340 - accuracy: 0.6087
# Epoch 40/1000
# 23/23 [==============================] - 0s 117us/step - loss: 0.5337 - accuracy: 0.6087
# Epoch 41/1000
# 23/23 [==============================] - 0s 132us/step - loss: 0.5335 - accuracy: 0.6087
# Epoch 42/1000
# 23/23 [==============================] - 0s 139us/step - loss: 0.5333 - accuracy: 0.6087
# Epoch 43/1000
# 23/23 [==============================] - 0s 90us/step - loss: 0.5331 - accuracy: 0.6087
# Epoch 44/1000
# 23/23 [==============================] - 0s 92us/step - loss: 0.5329 - accuracy: 0.6087
# Epoch 45/1000
# 23/23 [==============================] - 0s 72us/step - loss: 0.5327 - accuracy: 0.6087
# Epoch 46/1000
# 23/23 [==============================] - 0s 264us/step - loss: 0.5325 - accuracy: 0.6087
# Epoch 47/1000
# 23/23 [==============================] - 0s 86us/step - loss: 0.5323 - accuracy: 0.6087
# Epoch 48/1000
# 23/23 [==============================] - 0s 199us/step - loss: 0.5321 - accuracy: 0.6087
# Epoch 49/1000
# 23/23 [==============================] - 0s 95us/step - loss: 0.5319 - accuracy: 0.6087
# Epoch 50/1000
# 23/23 [==============================] - 0s 92us/step - loss: 0.5317 - accuracy: 0.6087
# Epoch 51/1000
# 23/23 [==============================] - 0s 162us/step - loss: 0.5315 - accuracy: 0.6087
# Epoch 52/1000
# 23/23 [==============================] - 0s 97us/step - loss: 0.5313 - accuracy: 0.6087
# Epoch 53/1000
# 23/23 [==============================] - 0s 109us/step - loss: 0.5311 - accuracy: 0.6087
# Epoch 54/1000
# 23/23 [==============================] - 0s 92us/step - loss: 0.5309 - accuracy: 0.6087
# Epoch 55/1000
# 23/23 [==============================] - 0s 82us/step - loss: 0.5307 - accuracy: 0.6087
# Epoch 56/1000
# 23/23 [==============================] - 0s 109us/step - loss: 0.5305 - accuracy: 0.6087
# Epoch 57/1000
# 23/23 [==============================] - 0s 94us/step - loss: 0.5303 - accuracy: 0.6087
# Epoch 58/1000
# 23/23 [==============================] - 0s 99us/step - loss: 0.5301 - accuracy: 0.6087
# Epoch 59/1000
# 23/23 [==============================] - 0s 97us/step - loss: 0.5299 - accuracy: 0.6087
# Epoch 60/1000
# 23/23 [==============================] - 0s 155us/step - loss: 0.5297 - accuracy: 0.6087
# Epoch 61/1000
# 23/23 [==============================] - 0s 164us/step - loss: 0.5295 - accuracy: 0.6087
# Epoch 62/1000
# 23/23 [==============================] - 0s 95us/step - loss: 0.5292 - accuracy: 0.6087
# Epoch 63/1000
# 23/23 [==============================] - 0s 180us/step - loss: 0.5290 - accuracy: 0.6087
# Epoch 64/1000
# 23/23 [==============================] - 0s 96us/step - loss: 0.5288 - accuracy: 0.6087
# Epoch 65/1000
# 23/23 [==============================] - 0s 125us/step - loss: 0.5286 - accuracy: 0.6087
# Epoch 66/1000
# 23/23 [==============================] - 0s 142us/step - loss: 0.5284 - accuracy: 0.6087
# Epoch 67/1000
# 23/23 [==============================] - 0s 93us/step - loss: 0.5283 - accuracy: 0.6087
# Epoch 68/1000
# 23/23 [==============================] - 0s 141us/step - loss: 0.5281 - accuracy: 0.6087
# Epoch 69/1000
# 23/23 [==============================] - 0s 89us/step - loss: 0.5279 - accuracy: 0.6087
# Epoch 70/1000
# 23/23 [==============================] - 0s 82us/step - loss: 0.5277 - accuracy: 0.6087
# Epoch 71/1000
# 23/23 [==============================] - 0s 138us/step - loss: 0.5275 - accuracy: 0.6087
# Epoch 72/1000
# 23/23 [==============================] - 0s 107us/step - loss: 0.5273 - accuracy: 0.6087
# Epoch 73/1000
# 23/23 [==============================] - 0s 74us/step - loss: 0.5271 - accuracy: 0.6087
# Epoch 74/1000
# 23/23 [==============================] - 0s 99us/step - loss: 0.5269 - accuracy: 0.6087
# Epoch 75/1000
# 23/23 [==============================] - 0s 68us/step - loss: 0.5267 - accuracy: 0.6087
# Epoch 76/1000
# 23/23 [==============================] - 0s 85us/step - loss: 0.5265 - accuracy: 0.6087
# Epoch 77/1000
# 23/23 [==============================] - 0s 154us/step - loss: 0.5263 - accuracy: 0.6087
# Epoch 78/1000
# 23/23 [==============================] - 0s 132us/step - loss: 0.5261 - accuracy: 0.6087
# Epoch 79/1000
# 23/23 [==============================] - 0s 83us/step - loss: 0.5259 - accuracy: 0.6087
# Epoch 80/1000
# 23/23 [==============================] - 0s 124us/step - loss: 0.5257 - accuracy: 0.6087
# Epoch 81/1000
# 23/23 [==============================] - 0s 126us/step - loss: 0.5255 - accuracy: 0.6087
# Epoch 82/1000
# 23/23 [==============================] - 0s 119us/step - loss: 0.5253 - accuracy: 0.6087
# Epoch 83/1000
# 23/23 [==============================] - 0s 150us/step - loss: 0.5251 - accuracy: 0.6087
# Epoch 84/1000
# 23/23 [==============================] - 0s 214us/step - loss: 0.5249 - accuracy: 0.6087
# Epoch 85/1000
# 23/23 [==============================] - 0s 132us/step - loss: 0.5247 - accuracy: 0.6087
# Epoch 86/1000
# 23/23 [==============================] - 0s 99us/step - loss: 0.5245 - accuracy: 0.6087
# Epoch 87/1000
# 23/23 [==============================] - 0s 113us/step - loss: 0.5243 - accuracy: 0.6087
# Epoch 88/1000
# 23/23 [==============================] - 0s 111us/step - loss: 0.5241 - accuracy: 0.6087
# Epoch 89/1000
# 23/23 [==============================] - 0s 165us/step - loss: 0.5240 - accuracy: 0.6087
# Epoch 90/1000
# 23/23 [==============================] - 0s 139us/step - loss: 0.5238 - accuracy: 0.6087
# Epoch 91/1000
# 23/23 [==============================] - 0s 126us/step - loss: 0.5236 - accuracy: 0.6087
# Epoch 92/1000
# 23/23 [==============================] - 0s 99us/step - loss: 0.5234 - accuracy: 0.6087
# Epoch 93/1000
# 23/23 [==============================] - 0s 120us/step - loss: 0.5232 - accuracy: 0.6087
# Epoch 94/1000
# 23/23 [==============================] - 0s 101us/step - loss: 0.5230 - accuracy: 0.6087
# Epoch 95/1000
# 23/23 [==============================] - 0s 180us/step - loss: 0.5228 - accuracy: 0.6087
# Epoch 96/1000
# 23/23 [==============================] - 0s 127us/step - loss: 0.5226 - accuracy: 0.6087
# Epoch 97/1000
# 23/23 [==============================] - 0s 151us/step - loss: 0.5224 - accuracy: 0.6087
# Epoch 98/1000
# 23/23 [==============================] - 0s 101us/step - loss: 0.5222 - accuracy: 0.6087
# Epoch 99/1000
# 23/23 [==============================] - 0s 166us/step - loss: 0.5221 - accuracy: 0.6087
# Epoch 100/1000
# 23/23 [==============================] - 0s 139us/step - loss: 0.5219 - accuracy: 0.6522
# Epoch 101/1000
# 23/23 [==============================] - 0s 125us/step - loss: 0.5217 - accuracy: 0.6522
# Epoch 102/1000
# 23/23 [==============================] - 0s 195us/step - loss: 0.5215 - accuracy: 0.6522
# Epoch 103/1000
# 23/23 [==============================] - 0s 186us/step - loss: 0.5213 - accuracy: 0.6522
# Epoch 104/1000
# 23/23 [==============================] - 0s 115us/step - loss: 0.5211 - accuracy: 0.6522
# Epoch 105/1000
# 23/23 [==============================] - 0s 167us/step - loss: 0.5209 - accuracy: 0.6522
# Epoch 106/1000
# 23/23 [==============================] - 0s 100us/step - loss: 0.5207 - accuracy: 0.6522
# Epoch 107/1000
# 23/23 [==============================] - 0s 145us/step - loss: 0.5206 - accuracy: 0.6522
# Epoch 108/1000
# 23/23 [==============================] - 0s 95us/step - loss: 0.5204 - accuracy: 0.6522
# Epoch 109/1000
# 23/23 [==============================] - 0s 105us/step - loss: 0.5202 - accuracy: 0.6522
# Epoch 110/1000
# 23/23 [==============================] - 0s 155us/step - loss: 0.5200 - accuracy: 0.6522
# Epoch 111/1000
# 23/23 [==============================] - 0s 163us/step - loss: 0.5198 - accuracy: 0.6522
# Epoch 112/1000
# 23/23 [==============================] - 0s 105us/step - loss: 0.5196 - accuracy: 0.6522
# Epoch 113/1000
# 23/23 [==============================] - 0s 146us/step - loss: 0.5194 - accuracy: 0.6522
# Epoch 114/1000
# 23/23 [==============================] - 0s 170us/step - loss: 0.5193 - accuracy: 0.6522
# Epoch 115/1000
# 23/23 [==============================] - 0s 122us/step - loss: 0.5191 - accuracy: 0.6522
# Epoch 116/1000
# 23/23 [==============================] - 0s 243us/step - loss: 0.5189 - accuracy: 0.6522
# Epoch 117/1000
# 23/23 [==============================] - 0s 132us/step - loss: 0.5187 - accuracy: 0.6522
# Epoch 118/1000
# 23/23 [==============================] - 0s 97us/step - loss: 0.5185 - accuracy: 0.6522
# Epoch 119/1000
# 23/23 [==============================] - 0s 156us/step - loss: 0.5183 - accuracy: 0.6522
# Epoch 120/1000
# 23/23 [==============================] - 0s 114us/step - loss: 0.5182 - accuracy: 0.6522
# Epoch 121/1000
# 23/23 [==============================] - 0s 136us/step - loss: 0.5180 - accuracy: 0.6522
# Epoch 122/1000
# 23/23 [==============================] - 0s 194us/step - loss: 0.5178 - accuracy: 0.6522
# Epoch 123/1000
# 23/23 [==============================] - 0s 225us/step - loss: 0.5176 - accuracy: 0.6522
# Epoch 124/1000
# 23/23 [==============================] - 0s 105us/step - loss: 0.5174 - accuracy: 0.6522
# Epoch 125/1000
# 23/23 [==============================] - 0s 139us/step - loss: 0.5173 - accuracy: 0.6522
# Epoch 126/1000
# 23/23 [==============================] - 0s 101us/step - loss: 0.5171 - accuracy: 0.6522
# Epoch 127/1000
# 23/23 [==============================] - 0s 158us/step - loss: 0.5169 - accuracy: 0.6522
# Epoch 128/1000
# 23/23 [==============================] - 0s 165us/step - loss: 0.5167 - accuracy: 0.6522
# Epoch 129/1000
# 23/23 [==============================] - 0s 129us/step - loss: 0.5165 - accuracy: 0.6522
# Epoch 130/1000
# 23/23 [==============================] - 0s 114us/step - loss: 0.5164 - accuracy: 0.6522
# Epoch 131/1000
# 23/23 [==============================] - 0s 115us/step - loss: 0.5162 - accuracy: 0.6522
# Epoch 132/1000
# 23/23 [==============================] - 0s 175us/step - loss: 0.5160 - accuracy: 0.6522
# Epoch 133/1000
# 23/23 [==============================] - 0s 99us/step - loss: 0.5158 - accuracy: 0.6522
# Epoch 134/1000
# 23/23 [==============================] - 0s 111us/step - loss: 0.5157 - accuracy: 0.6522
# Epoch 135/1000
# 23/23 [==============================] - 0s 141us/step - loss: 0.5155 - accuracy: 0.6522
# Epoch 136/1000
# 23/23 [==============================] - 0s 94us/step - loss: 0.5153 - accuracy: 0.6522
# Epoch 137/1000
# 23/23 [==============================] - 0s 107us/step - loss: 0.5151 - accuracy: 0.6522
# Epoch 138/1000
# 23/23 [==============================] - 0s 121us/step - loss: 0.5149 - accuracy: 0.6522
# Epoch 139/1000
# 23/23 [==============================] - 0s 122us/step - loss: 0.5148 - accuracy: 0.6522
# Epoch 140/1000
# 23/23 [==============================] - 0s 121us/step - loss: 0.5146 - accuracy: 0.6522
# Epoch 141/1000
# 23/23 [==============================] - 0s 114us/step - loss: 0.5144 - accuracy: 0.6522
# Epoch 142/1000
# 23/23 [==============================] - 0s 120us/step - loss: 0.5142 - accuracy: 0.6522
# Epoch 143/1000
# 23/23 [==============================] - 0s 124us/step - loss: 0.5141 - accuracy: 0.6522
# Epoch 144/1000
# 23/23 [==============================] - 0s 114us/step - loss: 0.5139 - accuracy: 0.6522
# Epoch 145/1000
# 23/23 [==============================] - 0s 85us/step - loss: 0.5137 - accuracy: 0.6522
# Epoch 146/1000
# 23/23 [==============================] - 0s 137us/step - loss: 0.5136 - accuracy: 0.6522
# Epoch 147/1000
# 23/23 [==============================] - 0s 92us/step - loss: 0.5134 - accuracy: 0.6522
# Epoch 148/1000
# 23/23 [==============================] - 0s 105us/step - loss: 0.5132 - accuracy: 0.6522
# Epoch 149/1000
# 23/23 [==============================] - 0s 91us/step - loss: 0.5130 - accuracy: 0.6522
# Epoch 150/1000
# 23/23 [==============================] - 0s 101us/step - loss: 0.5129 - accuracy: 0.6522
# Epoch 151/1000
# 23/23 [==============================] - 0s 102us/step - loss: 0.5127 - accuracy: 0.6522
# Epoch 152/1000
# 23/23 [==============================] - 0s 120us/step - loss: 0.5125 - accuracy: 0.6522
# Epoch 153/1000
# 23/23 [==============================] - 0s 86us/step - loss: 0.5123 - accuracy: 0.6522
# Epoch 154/1000
# 23/23 [==============================] - 0s 93us/step - loss: 0.5122 - accuracy: 0.6522
# Epoch 155/1000
# 23/23 [==============================] - 0s 149us/step - loss: 0.5120 - accuracy: 0.6522
# Epoch 156/1000
# 23/23 [==============================] - 0s 81us/step - loss: 0.5118 - accuracy: 0.6522
# Epoch 157/1000
# 23/23 [==============================] - 0s 85us/step - loss: 0.5117 - accuracy: 0.6522
# Epoch 158/1000
# 23/23 [==============================] - 0s 84us/step - loss: 0.5115 - accuracy: 0.6522
# Epoch 159/1000
# 23/23 [==============================] - 0s 90us/step - loss: 0.5113 - accuracy: 0.6522
# Epoch 160/1000
# 23/23 [==============================] - 0s 105us/step - loss: 0.5112 - accuracy: 0.6522
# Epoch 161/1000
# 23/23 [==============================] - 0s 127us/step - loss: 0.5110 - accuracy: 0.6522
# Epoch 162/1000
# 23/23 [==============================] - 0s 135us/step - loss: 0.5108 - accuracy: 0.6522
# Epoch 163/1000
# 23/23 [==============================] - 0s 106us/step - loss: 0.5106 - accuracy: 0.6522
# Epoch 164/1000
# 23/23 [==============================] - 0s 81us/step - loss: 0.5105 - accuracy: 0.6522
# Epoch 165/1000
# 23/23 [==============================] - 0s 136us/step - loss: 0.5103 - accuracy: 0.6522
# Epoch 166/1000
# 23/23 [==============================] - 0s 126us/step - loss: 0.5101 - accuracy: 0.6522
# Epoch 167/1000
# 23/23 [==============================] - 0s 105us/step - loss: 0.5100 - accuracy: 0.6522
# Epoch 168/1000
# 23/23 [==============================] - 0s 81us/step - loss: 0.5098 - accuracy: 0.6522
# Epoch 169/1000
# 23/23 [==============================] - 0s 75us/step - loss: 0.5096 - accuracy: 0.6522
# Epoch 170/1000
# 23/23 [==============================] - 0s 158us/step - loss: 0.5095 - accuracy: 0.6522
# Epoch 171/1000
# 23/23 [==============================] - 0s 97us/step - loss: 0.5093 - accuracy: 0.6522
# Epoch 172/1000
# 23/23 [==============================] - 0s 91us/step - loss: 0.5091 - accuracy: 0.6522
# Epoch 173/1000
# 23/23 [==============================] - 0s 97us/step - loss: 0.5090 - accuracy: 0.6522
# Epoch 174/1000
# 23/23 [==============================] - 0s 109us/step - loss: 0.5088 - accuracy: 0.6522
# Epoch 175/1000
# 23/23 [==============================] - 0s 85us/step - loss: 0.5087 - accuracy: 0.6522
# Epoch 176/1000
# 23/23 [==============================] - 0s 95us/step - loss: 0.5085 - accuracy: 0.6522
# Epoch 177/1000
# 23/23 [==============================] - 0s 97us/step - loss: 0.5083 - accuracy: 0.6522
# Epoch 178/1000
# 23/23 [==============================] - 0s 108us/step - loss: 0.5082 - accuracy: 0.6522
# Epoch 179/1000
# 23/23 [==============================] - 0s 199us/step - loss: 0.5080 - accuracy: 0.6522
# Epoch 180/1000
# 23/23 [==============================] - 0s 111us/step - loss: 0.5078 - accuracy: 0.6522
# Epoch 181/1000
# 23/23 [==============================] - 0s 105us/step - loss: 0.5077 - accuracy: 0.6522
# Epoch 182/1000
# 23/23 [==============================] - 0s 123us/step - loss: 0.5075 - accuracy: 0.6522
# Epoch 183/1000
# 23/23 [==============================] - 0s 113us/step - loss: 0.5073 - accuracy: 0.6522
# Epoch 184/1000
# 23/23 [==============================] - 0s 98us/step - loss: 0.5072 - accuracy: 0.6522
# Epoch 185/1000
# 23/23 [==============================] - 0s 83us/step - loss: 0.5070 - accuracy: 0.6522
# Epoch 186/1000
# 23/23 [==============================] - 0s 88us/step - loss: 0.5069 - accuracy: 0.6522
# Epoch 187/1000
# 23/23 [==============================] - 0s 181us/step - loss: 0.5067 - accuracy: 0.6522
# Epoch 188/1000
# 23/23 [==============================] - 0s 151us/step - loss: 0.5065 - accuracy: 0.6522
# Epoch 189/1000
# 23/23 [==============================] - 0s 78us/step - loss: 0.5064 - accuracy: 0.6522
# Epoch 190/1000
# 23/23 [==============================] - 0s 104us/step - loss: 0.5062 - accuracy: 0.6522
# Epoch 191/1000
# 23/23 [==============================] - 0s 86us/step - loss: 0.5061 - accuracy: 0.6522
# Epoch 192/1000
# 23/23 [==============================] - 0s 78us/step - loss: 0.5059 - accuracy: 0.6522
# Epoch 193/1000
# 23/23 [==============================] - 0s 123us/step - loss: 0.5057 - accuracy: 0.6522
# Epoch 194/1000
# 23/23 [==============================] - 0s 109us/step - loss: 0.5056 - accuracy: 0.6522
# Epoch 195/1000
# 23/23 [==============================] - 0s 177us/step - loss: 0.5054 - accuracy: 0.6522
# Epoch 196/1000
# 23/23 [==============================] - 0s 96us/step - loss: 0.5053 - accuracy: 0.6522
# Epoch 197/1000
# 23/23 [==============================] - 0s 76us/step - loss: 0.5051 - accuracy: 0.6522
# Epoch 198/1000
# 23/23 [==============================] - 0s 90us/step - loss: 0.5050 - accuracy: 0.6522
# Epoch 199/1000
# 23/23 [==============================] - 0s 105us/step - loss: 0.5048 - accuracy: 0.6522
# Epoch 200/1000
# 23/23 [==============================] - 0s 89us/step - loss: 0.5046 - accuracy: 0.6522
# Epoch 201/1000
# 23/23 [==============================] - 0s 100us/step - loss: 0.5045 - accuracy: 0.6522
# Epoch 202/1000
# 23/23 [==============================] - 0s 136us/step - loss: 0.5043 - accuracy: 0.6522
# Epoch 203/1000
# 23/23 [==============================] - 0s 77us/step - loss: 0.5042 - accuracy: 0.6522
# Epoch 204/1000
# 23/23 [==============================] - 0s 150us/step - loss: 0.5040 - accuracy: 0.6522
# Epoch 205/1000
# 23/23 [==============================] - 0s 100us/step - loss: 0.5039 - accuracy: 0.6522
# Epoch 206/1000
# 23/23 [==============================] - 0s 88us/step - loss: 0.5037 - accuracy: 0.6522
# Epoch 207/1000
# 23/23 [==============================] - 0s 110us/step - loss: 0.5036 - accuracy: 0.6522
# Epoch 208/1000
# 23/23 [==============================] - 0s 183us/step - loss: 0.5034 - accuracy: 0.6522
# Epoch 209/1000
# 23/23 [==============================] - 0s 161us/step - loss: 0.5032 - accuracy: 0.6522
# Epoch 210/1000
# 23/23 [==============================] - 0s 158us/step - loss: 0.5031 - accuracy: 0.6522
# Epoch 211/1000
# 23/23 [==============================] - 0s 136us/step - loss: 0.5029 - accuracy: 0.6522
# Epoch 212/1000
# 23/23 [==============================] - 0s 161us/step - loss: 0.5028 - accuracy: 0.6522
# Epoch 213/1000
# 23/23 [==============================] - 0s 102us/step - loss: 0.5026 - accuracy: 0.6522
# Epoch 214/1000
# 23/23 [==============================] - 0s 111us/step - loss: 0.5025 - accuracy: 0.6522
# Epoch 215/1000
# 23/23 [==============================] - 0s 102us/step - loss: 0.5023 - accuracy: 0.6522
# Epoch 216/1000
# 23/23 [==============================] - 0s 87us/step - loss: 0.5022 - accuracy: 0.6522
# Epoch 217/1000
# 23/23 [==============================] - 0s 106us/step - loss: 0.5020 - accuracy: 0.6522
# Epoch 218/1000
# 23/23 [==============================] - 0s 217us/step - loss: 0.5019 - accuracy: 0.6522
# Epoch 219/1000
# 23/23 [==============================] - 0s 96us/step - loss: 0.5017 - accuracy: 0.6522
# Epoch 220/1000
# 23/23 [==============================] - 0s 114us/step - loss: 0.5016 - accuracy: 0.6522
# Epoch 221/1000
# 23/23 [==============================] - 0s 97us/step - loss: 0.5014 - accuracy: 0.6522
# Epoch 222/1000
# 23/23 [==============================] - 0s 119us/step - loss: 0.5013 - accuracy: 0.6522
# Epoch 223/1000
# 23/23 [==============================] - 0s 94us/step - loss: 0.5011 - accuracy: 0.6522
# Epoch 224/1000
# 23/23 [==============================] - 0s 110us/step - loss: 0.5010 - accuracy: 0.6522
# Epoch 225/1000
# 23/23 [==============================] - 0s 92us/step - loss: 0.5008 - accuracy: 0.6522
# Epoch 226/1000
# 23/23 [==============================] - 0s 79us/step - loss: 0.5007 - accuracy: 0.6522
# Epoch 227/1000
# 23/23 [==============================] - 0s 113us/step - loss: 0.5005 - accuracy: 0.6522
# Epoch 228/1000
# 23/23 [==============================] - 0s 136us/step - loss: 0.5004 - accuracy: 0.6522
# Epoch 229/1000
# 23/23 [==============================] - 0s 98us/step - loss: 0.5002 - accuracy: 0.6522
# Epoch 230/1000
# 23/23 [==============================] - 0s 100us/step - loss: 0.5001 - accuracy: 0.6522
# Epoch 231/1000
# 23/23 [==============================] - 0s 85us/step - loss: 0.4999 - accuracy: 0.6522
# Epoch 232/1000
# 23/23 [==============================] - 0s 115us/step - loss: 0.4998 - accuracy: 0.6522
# Epoch 233/1000
# 23/23 [==============================] - 0s 139us/step - loss: 0.4996 - accuracy: 0.6522
# Epoch 234/1000
# 23/23 [==============================] - 0s 106us/step - loss: 0.4995 - accuracy: 0.6522
# Epoch 235/1000
# 23/23 [==============================] - 0s 87us/step - loss: 0.4993 - accuracy: 0.6522
# Epoch 236/1000
# 23/23 [==============================] - 0s 104us/step - loss: 0.4992 - accuracy: 0.6522
# Epoch 237/1000
# 23/23 [==============================] - 0s 155us/step - loss: 0.4990 - accuracy: 0.6522
# Epoch 238/1000
# 23/23 [==============================] - 0s 146us/step - loss: 0.4989 - accuracy: 0.6522
# Epoch 239/1000
# 23/23 [==============================] - 0s 84us/step - loss: 0.4987 - accuracy: 0.6522
# Epoch 240/1000
# 23/23 [==============================] - 0s 100us/step - loss: 0.4986 - accuracy: 0.6522
# Epoch 241/1000
# 23/23 [==============================] - 0s 70us/step - loss: 0.4985 - accuracy: 0.6522
# Epoch 242/1000
# 23/23 [==============================] - 0s 72us/step - loss: 0.4983 - accuracy: 0.6522
# Epoch 243/1000
# 23/23 [==============================] - 0s 91us/step - loss: 0.4982 - accuracy: 0.6522
# Epoch 244/1000
# 23/23 [==============================] - 0s 77us/step - loss: 0.4980 - accuracy: 0.6522
# Epoch 245/1000
# 23/23 [==============================] - 0s 103us/step - loss: 0.4979 - accuracy: 0.6522
# Epoch 246/1000
# 23/23 [==============================] - 0s 83us/step - loss: 0.4977 - accuracy: 0.6522
# Epoch 247/1000
# 23/23 [==============================] - 0s 73us/step - loss: 0.4976 - accuracy: 0.6522
# Epoch 248/1000
# 23/23 [==============================] - 0s 79us/step - loss: 0.4975 - accuracy: 0.6522
# Epoch 249/1000
# 23/23 [==============================] - 0s 84us/step - loss: 0.4973 - accuracy: 0.6522
# Epoch 250/1000
# 23/23 [==============================] - 0s 82us/step - loss: 0.4972 - accuracy: 0.6522
# Epoch 251/1000
# 23/23 [==============================] - 0s 79us/step - loss: 0.4970 - accuracy: 0.6522
# Epoch 252/1000
# 23/23 [==============================] - 0s 95us/step - loss: 0.4969 - accuracy: 0.6522
# Epoch 253/1000
# 23/23 [==============================] - 0s 83us/step - loss: 0.4967 - accuracy: 0.6522
# Epoch 254/1000
# 23/23 [==============================] - 0s 78us/step - loss: 0.4966 - accuracy: 0.6522
# Epoch 255/1000
# 23/23 [==============================] - 0s 82us/step - loss: 0.4965 - accuracy: 0.6522
# Epoch 256/1000
# 23/23 [==============================] - 0s 86us/step - loss: 0.4963 - accuracy: 0.6522
# Epoch 257/1000
# 23/23 [==============================] - 0s 75us/step - loss: 0.4962 - accuracy: 0.6522
# Epoch 258/1000
# 23/23 [==============================] - 0s 82us/step - loss: 0.4960 - accuracy: 0.6522
# Epoch 259/1000
# 23/23 [==============================] - 0s 85us/step - loss: 0.4959 - accuracy: 0.6522
# Epoch 260/1000
# 23/23 [==============================] - 0s 102us/step - loss: 0.4958 - accuracy: 0.6522
# Epoch 261/1000
# 23/23 [==============================] - 0s 179us/step - loss: 0.4956 - accuracy: 0.6522
# Epoch 262/1000
# 23/23 [==============================] - 0s 116us/step - loss: 0.4955 - accuracy: 0.6522
# Epoch 263/1000
# 23/23 [==============================] - 0s 88us/step - loss: 0.4953 - accuracy: 0.6522
# Epoch 264/1000
# 23/23 [==============================] - 0s 144us/step - loss: 0.4952 - accuracy: 0.6522
# Epoch 265/1000
# 23/23 [==============================] - 0s 103us/step - loss: 0.4951 - accuracy: 0.6522
# Epoch 266/1000
# 23/23 [==============================] - 0s 88us/step - loss: 0.4949 - accuracy: 0.6522
# Epoch 267/1000
# 23/23 [==============================] - 0s 110us/step - loss: 0.4948 - accuracy: 0.6522
# Epoch 268/1000
# 23/23 [==============================] - 0s 82us/step - loss: 0.4947 - accuracy: 0.6522
# Epoch 269/1000
# 23/23 [==============================] - 0s 142us/step - loss: 0.4945 - accuracy: 0.6522
# Epoch 270/1000
# 23/23 [==============================] - 0s 78us/step - loss: 0.4944 - accuracy: 0.6522
# Epoch 271/1000
# 23/23 [==============================] - 0s 83us/step - loss: 0.4942 - accuracy: 0.6522
# Epoch 272/1000
# 23/23 [==============================] - 0s 133us/step - loss: 0.4941 - accuracy: 0.6522
# Epoch 273/1000
# 23/23 [==============================] - 0s 118us/step - loss: 0.4940 - accuracy: 0.6522
# Epoch 274/1000
# 23/23 [==============================] - 0s 116us/step - loss: 0.4938 - accuracy: 0.6522
# Epoch 275/1000
# 23/23 [==============================] - 0s 84us/step - loss: 0.4937 - accuracy: 0.6522
# Epoch 276/1000
# 23/23 [==============================] - 0s 100us/step - loss: 0.4936 - accuracy: 0.6522
# Epoch 277/1000
# 23/23 [==============================] - 0s 82us/step - loss: 0.4934 - accuracy: 0.6522
# Epoch 278/1000
# 23/23 [==============================] - 0s 80us/step - loss: 0.4933 - accuracy: 0.6522
# Epoch 279/1000
# 23/23 [==============================] - 0s 88us/step - loss: 0.4932 - accuracy: 0.6522
# Epoch 280/1000
# 23/23 [==============================] - 0s 151us/step - loss: 0.4930 - accuracy: 0.6522
# Epoch 281/1000
# 23/23 [==============================] - 0s 109us/step - loss: 0.4929 - accuracy: 0.6522
# Epoch 282/1000
# 23/23 [==============================] - 0s 151us/step - loss: 0.4928 - accuracy: 0.6522
# Epoch 283/1000
# 23/23 [==============================] - 0s 100us/step - loss: 0.4926 - accuracy: 0.6522
# Epoch 284/1000
# 23/23 [==============================] - 0s 138us/step - loss: 0.4925 - accuracy: 0.6522
# Epoch 285/1000
# 23/23 [==============================] - 0s 86us/step - loss: 0.4924 - accuracy: 0.6522
# Epoch 286/1000
# 23/23 [==============================] - 0s 104us/step - loss: 0.4922 - accuracy: 0.6522
# Epoch 287/1000
# 23/23 [==============================] - 0s 86us/step - loss: 0.4921 - accuracy: 0.6522
# Epoch 288/1000
# 23/23 [==============================] - 0s 109us/step - loss: 0.4920 - accuracy: 0.6522
# Epoch 289/1000
# 23/23 [==============================] - 0s 94us/step - loss: 0.4918 - accuracy: 0.6522
# Epoch 290/1000
# 23/23 [==============================] - 0s 125us/step - loss: 0.4917 - accuracy: 0.6522
# Epoch 291/1000
# 23/23 [==============================] - 0s 103us/step - loss: 0.4916 - accuracy: 0.6522
# Epoch 292/1000
# 23/23 [==============================] - 0s 81us/step - loss: 0.4914 - accuracy: 0.6522
# Epoch 293/1000
# 23/23 [==============================] - 0s 92us/step - loss: 0.4913 - accuracy: 0.6522
# Epoch 294/1000
# 23/23 [==============================] - 0s 132us/step - loss: 0.4912 - accuracy: 0.6522
# Epoch 295/1000
# 23/23 [==============================] - 0s 95us/step - loss: 0.4911 - accuracy: 0.6522
# Epoch 296/1000
# 23/23 [==============================] - 0s 129us/step - loss: 0.4909 - accuracy: 0.6522
# Epoch 297/1000
# 23/23 [==============================] - 0s 85us/step - loss: 0.4908 - accuracy: 0.6522
# Epoch 298/1000
# 23/23 [==============================] - 0s 92us/step - loss: 0.4907 - accuracy: 0.6522
# Epoch 299/1000
# 23/23 [==============================] - 0s 99us/step - loss: 0.4905 - accuracy: 0.6522
# Epoch 300/1000
# 23/23 [==============================] - 0s 144us/step - loss: 0.4904 - accuracy: 0.6522
# Epoch 301/1000
# 23/23 [==============================] - 0s 124us/step - loss: 0.4903 - accuracy: 0.6522
# Epoch 302/1000
# 23/23 [==============================] - 0s 202us/step - loss: 0.4901 - accuracy: 0.6522
# Epoch 303/1000
# 23/23 [==============================] - 0s 104us/step - loss: 0.4900 - accuracy: 0.6522
# Epoch 304/1000
# 23/23 [==============================] - 0s 114us/step - loss: 0.4899 - accuracy: 0.6522
# Epoch 305/1000
# 23/23 [==============================] - 0s 116us/step - loss: 0.4898 - accuracy: 0.6522
# Epoch 306/1000
# 23/23 [==============================] - 0s 124us/step - loss: 0.4896 - accuracy: 0.6522
# Epoch 307/1000
# 23/23 [==============================] - 0s 146us/step - loss: 0.4895 - accuracy: 0.6522
# Epoch 308/1000
# 23/23 [==============================] - 0s 80us/step - loss: 0.4894 - accuracy: 0.6522
# Epoch 309/1000
# 23/23 [==============================] - 0s 201us/step - loss: 0.4893 - accuracy: 0.6522
# Epoch 310/1000
# 23/23 [==============================] - 0s 334us/step - loss: 0.4891 - accuracy: 0.6522
# Epoch 311/1000
# 23/23 [==============================] - 0s 273us/step - loss: 0.4890 - accuracy: 0.6522
# Epoch 312/1000
# 23/23 [==============================] - 0s 233us/step - loss: 0.4889 - accuracy: 0.6522
# Epoch 313/1000
# 23/23 [==============================] - 0s 186us/step - loss: 0.4888 - accuracy: 0.6522
# Epoch 314/1000
# 23/23 [==============================] - 0s 117us/step - loss: 0.4886 - accuracy: 0.6522
# Epoch 315/1000
# 23/23 [==============================] - 0s 185us/step - loss: 0.4885 - accuracy: 0.6522
# Epoch 316/1000
# 23/23 [==============================] - 0s 124us/step - loss: 0.4884 - accuracy: 0.6522
# Epoch 317/1000
# 23/23 [==============================] - 0s 166us/step - loss: 0.4883 - accuracy: 0.6522
# Epoch 318/1000
# 23/23 [==============================] - 0s 116us/step - loss: 0.4881 - accuracy: 0.6522
# Epoch 319/1000
# 23/23 [==============================] - 0s 104us/step - loss: 0.4880 - accuracy: 0.6522
# Epoch 320/1000
# 23/23 [==============================] - 0s 90us/step - loss: 0.4879 - accuracy: 0.6522
# Epoch 321/1000
# 23/23 [==============================] - 0s 144us/step - loss: 0.4878 - accuracy: 0.6522
# Epoch 322/1000
# 23/23 [==============================] - 0s 108us/step - loss: 0.4876 - accuracy: 0.6522
# Epoch 323/1000
# 23/23 [==============================] - 0s 87us/step - loss: 0.4875 - accuracy: 0.6522
# Epoch 324/1000
# 23/23 [==============================] - 0s 83us/step - loss: 0.4874 - accuracy: 0.6522
# Epoch 325/1000
# 23/23 [==============================] - 0s 123us/step - loss: 0.4873 - accuracy: 0.6522
# Epoch 326/1000
# 23/23 [==============================] - 0s 138us/step - loss: 0.4872 - accuracy: 0.6522
# Epoch 327/1000
# 23/23 [==============================] - 0s 92us/step - loss: 0.4870 - accuracy: 0.6522
# Epoch 328/1000
# 23/23 [==============================] - 0s 90us/step - loss: 0.4869 - accuracy: 0.6957
# Epoch 329/1000
# 23/23 [==============================] - 0s 83us/step - loss: 0.4868 - accuracy: 0.6957
# Epoch 330/1000
# 23/23 [==============================] - 0s 105us/step - loss: 0.4867 - accuracy: 0.6957
# Epoch 331/1000
# 23/23 [==============================] - 0s 135us/step - loss: 0.4865 - accuracy: 0.6957
# Epoch 332/1000
# 23/23 [==============================] - 0s 80us/step - loss: 0.4864 - accuracy: 0.6957
# Epoch 333/1000
# 23/23 [==============================] - 0s 98us/step - loss: 0.4863 - accuracy: 0.6957
# Epoch 334/1000
# 23/23 [==============================] - 0s 81us/step - loss: 0.4862 - accuracy: 0.6957
# Epoch 335/1000
# 23/23 [==============================] - 0s 98us/step - loss: 0.4861 - accuracy: 0.6957
# Epoch 336/1000
# 23/23 [==============================] - 0s 90us/step - loss: 0.4859 - accuracy: 0.6957
# Epoch 337/1000
# 23/23 [==============================] - 0s 92us/step - loss: 0.4858 - accuracy: 0.6957
# Epoch 338/1000
# 23/23 [==============================] - 0s 106us/step - loss: 0.4857 - accuracy: 0.6957
# Epoch 339/1000
# 23/23 [==============================] - 0s 105us/step - loss: 0.4856 - accuracy: 0.6957
# Epoch 340/1000
# 23/23 [==============================] - 0s 89us/step - loss: 0.4855 - accuracy: 0.6957
# Epoch 341/1000
# 23/23 [==============================] - 0s 89us/step - loss: 0.4853 - accuracy: 0.6957
# Epoch 342/1000
# 23/23 [==============================] - 0s 93us/step - loss: 0.4852 - accuracy: 0.6957
# Epoch 343/1000
# 23/23 [==============================] - 0s 76us/step - loss: 0.4851 - accuracy: 0.6957
# Epoch 344/1000
# 23/23 [==============================] - 0s 102us/step - loss: 0.4850 - accuracy: 0.6957
# Epoch 345/1000
# 23/23 [==============================] - 0s 146us/step - loss: 0.4849 - accuracy: 0.6957
# Epoch 346/1000
# 23/23 [==============================] - 0s 86us/step - loss: 0.4847 - accuracy: 0.6957
# Epoch 347/1000
# 23/23 [==============================] - 0s 109us/step - loss: 0.4846 - accuracy: 0.6957
# Epoch 348/1000
# 23/23 [==============================] - 0s 69us/step - loss: 0.4845 - accuracy: 0.6957
# Epoch 349/1000
# 23/23 [==============================] - 0s 102us/step - loss: 0.4844 - accuracy: 0.6957
# Epoch 350/1000
# 23/23 [==============================] - 0s 103us/step - loss: 0.4843 - accuracy: 0.6957
# Epoch 351/1000
# 23/23 [==============================] - 0s 231us/step - loss: 0.4841 - accuracy: 0.6957
# Epoch 352/1000
# 23/23 [==============================] - 0s 118us/step - loss: 0.4840 - accuracy: 0.6957
# Epoch 353/1000
# 23/23 [==============================] - 0s 105us/step - loss: 0.4839 - accuracy: 0.6957
# Epoch 354/1000
# 23/23 [==============================] - 0s 75us/step - loss: 0.4838 - accuracy: 0.6957
# Epoch 355/1000
# 23/23 [==============================] - 0s 92us/step - loss: 0.4837 - accuracy: 0.6957
# Epoch 356/1000
# 23/23 [==============================] - 0s 82us/step - loss: 0.4836 - accuracy: 0.6957
# Epoch 357/1000
# 23/23 [==============================] - 0s 85us/step - loss: 0.4834 - accuracy: 0.6957
# Epoch 358/1000
# 23/23 [==============================] - 0s 101us/step - loss: 0.4833 - accuracy: 0.6957
# Epoch 359/1000
# 23/23 [==============================] - 0s 109us/step - loss: 0.4832 - accuracy: 0.6957
# Epoch 360/1000
# 23/23 [==============================] - 0s 79us/step - loss: 0.4831 - accuracy: 0.6957
# Epoch 361/1000
# 23/23 [==============================] - 0s 101us/step - loss: 0.4830 - accuracy: 0.6957
# Epoch 362/1000
# 23/23 [==============================] - 0s 170us/step - loss: 0.4829 - accuracy: 0.6957
# Epoch 363/1000
# 23/23 [==============================] - 0s 121us/step - loss: 0.4827 - accuracy: 0.6957
# Epoch 364/1000
# 23/23 [==============================] - 0s 119us/step - loss: 0.4826 - accuracy: 0.6957
# Epoch 365/1000
# 23/23 [==============================] - 0s 134us/step - loss: 0.4825 - accuracy: 0.6957
# Epoch 366/1000
# 23/23 [==============================] - 0s 94us/step - loss: 0.4824 - accuracy: 0.6957
# Epoch 367/1000
# 23/23 [==============================] - 0s 93us/step - loss: 0.4823 - accuracy: 0.6957
# Epoch 368/1000
# 23/23 [==============================] - 0s 84us/step - loss: 0.4822 - accuracy: 0.6957
# Epoch 369/1000
# 23/23 [==============================] - 0s 102us/step - loss: 0.4820 - accuracy: 0.6957
# Epoch 370/1000
# 23/23 [==============================] - 0s 100us/step - loss: 0.4819 - accuracy: 0.6957
# Epoch 371/1000
# 23/23 [==============================] - 0s 96us/step - loss: 0.4818 - accuracy: 0.6957
# Epoch 372/1000
# 23/23 [==============================] - 0s 74us/step - loss: 0.4817 - accuracy: 0.6957
# Epoch 373/1000
# 23/23 [==============================] - 0s 113us/step - loss: 0.4816 - accuracy: 0.6957
# Epoch 374/1000
# 23/23 [==============================] - 0s 112us/step - loss: 0.4815 - accuracy: 0.6957
# Epoch 375/1000
# 23/23 [==============================] - 0s 220us/step - loss: 0.4814 - accuracy: 0.6957
# Epoch 376/1000
# 23/23 [==============================] - 0s 119us/step - loss: 0.4812 - accuracy: 0.6957
# Epoch 377/1000
# 23/23 [==============================] - 0s 83us/step - loss: 0.4811 - accuracy: 0.6957
# Epoch 378/1000
# 23/23 [==============================] - 0s 165us/step - loss: 0.4810 - accuracy: 0.6957
# Epoch 379/1000
# 23/23 [==============================] - 0s 83us/step - loss: 0.4809 - accuracy: 0.6957
# Epoch 380/1000
# 23/23 [==============================] - 0s 121us/step - loss: 0.4808 - accuracy: 0.6957
# Epoch 381/1000
# 23/23 [==============================] - 0s 98us/step - loss: 0.4807 - accuracy: 0.6957
# Epoch 382/1000
# 23/23 [==============================] - 0s 142us/step - loss: 0.4806 - accuracy: 0.6957
# Epoch 383/1000
# 23/23 [==============================] - 0s 74us/step - loss: 0.4805 - accuracy: 0.6957
# Epoch 384/1000
# 23/23 [==============================] - 0s 90us/step - loss: 0.4803 - accuracy: 0.6957
# Epoch 385/1000
# 23/23 [==============================] - 0s 95us/step - loss: 0.4802 - accuracy: 0.6957
# Epoch 386/1000
# 23/23 [==============================] - 0s 140us/step - loss: 0.4801 - accuracy: 0.6957
# Epoch 387/1000
# 23/23 [==============================] - 0s 106us/step - loss: 0.4800 - accuracy: 0.6957
# Epoch 388/1000
# 23/23 [==============================] - 0s 180us/step - loss: 0.4799 - accuracy: 0.6957
# Epoch 389/1000
# 23/23 [==============================] - 0s 108us/step - loss: 0.4798 - accuracy: 0.6957
# Epoch 390/1000
# 23/23 [==============================] - 0s 174us/step - loss: 0.4797 - accuracy: 0.6957
# Epoch 391/1000
# 23/23 [==============================] - 0s 169us/step - loss: 0.4796 - accuracy: 0.6957
# Epoch 392/1000
# 23/23 [==============================] - 0s 133us/step - loss: 0.4794 - accuracy: 0.6957
# Epoch 393/1000
# 23/23 [==============================] - 0s 84us/step - loss: 0.4793 - accuracy: 0.6957
# Epoch 394/1000
# 23/23 [==============================] - 0s 86us/step - loss: 0.4792 - accuracy: 0.6957
# Epoch 395/1000
# 23/23 [==============================] - 0s 82us/step - loss: 0.4791 - accuracy: 0.6957
# Epoch 396/1000
# 23/23 [==============================] - 0s 102us/step - loss: 0.4790 - accuracy: 0.6957
# Epoch 397/1000
# 23/23 [==============================] - 0s 80us/step - loss: 0.4789 - accuracy: 0.6957
# Epoch 398/1000
# 23/23 [==============================] - 0s 81us/step - loss: 0.4788 - accuracy: 0.6957
# Epoch 399/1000
# 23/23 [==============================] - 0s 176us/step - loss: 0.4787 - accuracy: 0.6957
# Epoch 400/1000
# 23/23 [==============================] - 0s 89us/step - loss: 0.4786 - accuracy: 0.6957
# Epoch 401/1000
# 23/23 [==============================] - 0s 107us/step - loss: 0.4785 - accuracy: 0.6957
# Epoch 402/1000
# 23/23 [==============================] - 0s 119us/step - loss: 0.4783 - accuracy: 0.6957
# Epoch 403/1000
# 23/23 [==============================] - 0s 109us/step - loss: 0.4782 - accuracy: 0.6957
# Epoch 404/1000
# 23/23 [==============================] - 0s 145us/step - loss: 0.4781 - accuracy: 0.6957
# Epoch 405/1000
# 23/23 [==============================] - 0s 102us/step - loss: 0.4780 - accuracy: 0.6957
# Epoch 406/1000
# 23/23 [==============================] - 0s 113us/step - loss: 0.4779 - accuracy: 0.6957
# Epoch 407/1000
# 23/23 [==============================] - 0s 91us/step - loss: 0.4778 - accuracy: 0.6957
# Epoch 408/1000
# 23/23 [==============================] - 0s 103us/step - loss: 0.4777 - accuracy: 0.6957
# Epoch 409/1000
# 23/23 [==============================] - 0s 87us/step - loss: 0.4776 - accuracy: 0.6957
# Epoch 410/1000
# 23/23 [==============================] - 0s 111us/step - loss: 0.4775 - accuracy: 0.6957
# Epoch 411/1000
# 23/23 [==============================] - 0s 81us/step - loss: 0.4774 - accuracy: 0.6957
# Epoch 412/1000
# 23/23 [==============================] - 0s 96us/step - loss: 0.4773 - accuracy: 0.6957
# Epoch 413/1000
# 23/23 [==============================] - 0s 92us/step - loss: 0.4772 - accuracy: 0.6957
# Epoch 414/1000
# 23/23 [==============================] - 0s 104us/step - loss: 0.4770 - accuracy: 0.6957
# Epoch 415/1000
# 23/23 [==============================] - 0s 101us/step - loss: 0.4769 - accuracy: 0.6957
# Epoch 416/1000
# 23/23 [==============================] - 0s 84us/step - loss: 0.4768 - accuracy: 0.6957
# Epoch 417/1000
# 23/23 [==============================] - 0s 86us/step - loss: 0.4767 - accuracy: 0.6957
# Epoch 418/1000
# 23/23 [==============================] - 0s 87us/step - loss: 0.4766 - accuracy: 0.6957
# Epoch 419/1000
# 23/23 [==============================] - 0s 82us/step - loss: 0.4765 - accuracy: 0.6957
# Epoch 420/1000
# 23/23 [==============================] - 0s 103us/step - loss: 0.4764 - accuracy: 0.6957
# Epoch 421/1000
# 23/23 [==============================] - 0s 138us/step - loss: 0.4763 - accuracy: 0.6957
# Epoch 422/1000
# 23/23 [==============================] - 0s 79us/step - loss: 0.4762 - accuracy: 0.6957
# Epoch 423/1000
# 23/23 [==============================] - 0s 143us/step - loss: 0.4761 - accuracy: 0.6957
# Epoch 424/1000
# 23/23 [==============================] - 0s 99us/step - loss: 0.4760 - accuracy: 0.6957
# Epoch 425/1000
# 23/23 [==============================] - 0s 96us/step - loss: 0.4759 - accuracy: 0.6957
# Epoch 426/1000
# 23/23 [==============================] - 0s 84us/step - loss: 0.4758 - accuracy: 0.6957
# Epoch 427/1000
# 23/23 [==============================] - 0s 87us/step - loss: 0.4757 - accuracy: 0.6957
# Epoch 428/1000
# 23/23 [==============================] - 0s 112us/step - loss: 0.4756 - accuracy: 0.6957
# Epoch 429/1000
# 23/23 [==============================] - 0s 97us/step - loss: 0.4755 - accuracy: 0.6957
# Epoch 430/1000
# 23/23 [==============================] - 0s 86us/step - loss: 0.4754 - accuracy: 0.6957
# Epoch 431/1000
# 23/23 [==============================] - 0s 81us/step - loss: 0.4753 - accuracy: 0.6957
# Epoch 432/1000
# 23/23 [==============================] - 0s 83us/step - loss: 0.4751 - accuracy: 0.6957
# Epoch 433/1000
# 23/23 [==============================] - 0s 176us/step - loss: 0.4750 - accuracy: 0.6957
# Epoch 434/1000
# 23/23 [==============================] - 0s 148us/step - loss: 0.4749 - accuracy: 0.6957
# Epoch 435/1000
# 23/23 [==============================] - 0s 132us/step - loss: 0.4748 - accuracy: 0.6957
# Epoch 436/1000
# 23/23 [==============================] - 0s 99us/step - loss: 0.4747 - accuracy: 0.6957
# Epoch 437/1000
# 23/23 [==============================] - 0s 92us/step - loss: 0.4746 - accuracy: 0.6957
# Epoch 438/1000
# 23/23 [==============================] - 0s 88us/step - loss: 0.4745 - accuracy: 0.6957
# Epoch 439/1000
# 23/23 [==============================] - 0s 94us/step - loss: 0.4744 - accuracy: 0.6957
# Epoch 440/1000
# 23/23 [==============================] - 0s 86us/step - loss: 0.4743 - accuracy: 0.6957
# Epoch 441/1000
# 23/23 [==============================] - 0s 81us/step - loss: 0.4742 - accuracy: 0.6957
# Epoch 442/1000
# 23/23 [==============================] - 0s 78us/step - loss: 0.4741 - accuracy: 0.6957
# Epoch 443/1000
# 23/23 [==============================] - 0s 88us/step - loss: 0.4740 - accuracy: 0.6957
# Epoch 444/1000
# 23/23 [==============================] - 0s 90us/step - loss: 0.4739 - accuracy: 0.6957
# Epoch 445/1000
# 23/23 [==============================] - 0s 119us/step - loss: 0.4738 - accuracy: 0.6957
# Epoch 446/1000
# 23/23 [==============================] - 0s 145us/step - loss: 0.4737 - accuracy: 0.6957
# Epoch 447/1000
# 23/23 [==============================] - 0s 101us/step - loss: 0.4736 - accuracy: 0.6957
# Epoch 448/1000
# 23/23 [==============================] - 0s 97us/step - loss: 0.4735 - accuracy: 0.6957
# Epoch 449/1000
# 23/23 [==============================] - 0s 100us/step - loss: 0.4734 - accuracy: 0.6957
# Epoch 450/1000
# 23/23 [==============================] - 0s 100us/step - loss: 0.4733 - accuracy: 0.6957
# Epoch 451/1000
# 23/23 [==============================] - 0s 121us/step - loss: 0.4732 - accuracy: 0.6957
# Epoch 452/1000
# 23/23 [==============================] - 0s 89us/step - loss: 0.4731 - accuracy: 0.6957
# Epoch 453/1000
# 23/23 [==============================] - 0s 118us/step - loss: 0.4730 - accuracy: 0.6957
# Epoch 454/1000
# 23/23 [==============================] - 0s 76us/step - loss: 0.4729 - accuracy: 0.6957
# Epoch 455/1000
# 23/23 [==============================] - 0s 86us/step - loss: 0.4728 - accuracy: 0.6957
# Epoch 456/1000
# 23/23 [==============================] - 0s 108us/step - loss: 0.4727 - accuracy: 0.6957
# Epoch 457/1000
# 23/23 [==============================] - 0s 95us/step - loss: 0.4726 - accuracy: 0.6957
# Epoch 458/1000
# 23/23 [==============================] - 0s 164us/step - loss: 0.4725 - accuracy: 0.6957
# Epoch 459/1000
# 23/23 [==============================] - 0s 92us/step - loss: 0.4724 - accuracy: 0.6957
# Epoch 460/1000
# 23/23 [==============================] - 0s 89us/step - loss: 0.4723 - accuracy: 0.6957
# Epoch 461/1000
# 23/23 [==============================] - 0s 98us/step - loss: 0.4722 - accuracy: 0.6957
# Epoch 462/1000
# 23/23 [==============================] - 0s 102us/step - loss: 0.4721 - accuracy: 0.6957
# Epoch 463/1000
# 23/23 [==============================] - 0s 86us/step - loss: 0.4720 - accuracy: 0.6957
# Epoch 464/1000
# 23/23 [==============================] - 0s 105us/step - loss: 0.4719 - accuracy: 0.6957
# Epoch 465/1000
# ...
# 23/23 [==============================] - 0s 87us/step - loss: 0.4464 - accuracy: 0.8696
# Epoch 847/1000
# 23/23 [==============================] - 0s 97us/step - loss: 0.4463 - accuracy: 0.8696
# Epoch 848/1000
# 23/23 [==============================] - 0s 113us/step - loss: 0.4463 - accuracy: 0.8696
# Epoch 849/1000
# 23/23 [==============================] - 0s 127us/step - loss: 0.4463 - accuracy: 0.8696
# Epoch 850/1000
# 23/23 [==============================] - 0s 111us/step - loss: 0.4462 - accuracy: 0.8696
# Epoch 851/1000
# 23/23 [==============================] - 0s 155us/step - loss: 0.4462 - accuracy: 0.8696
# Epoch 852/1000
# 23/23 [==============================] - 0s 78us/step - loss: 0.4462 - accuracy: 0.8696
# Epoch 853/1000
# 23/23 [==============================] - 0s 143us/step - loss: 0.4461 - accuracy: 0.8696
# Epoch 854/1000
# 23/23 [==============================] - 0s 100us/step - loss: 0.4461 - accuracy: 0.8696
# Epoch 855/1000
# 23/23 [==============================] - 0s 113us/step - loss: 0.4461 - accuracy: 0.8696
# Epoch 856/1000
# 23/23 [==============================] - 0s 228us/step - loss: 0.4460 - accuracy: 0.8696
# Epoch 857/1000
# 23/23 [==============================] - 0s 157us/step - loss: 0.4460 - accuracy: 0.8696
# Epoch 858/1000
# 23/23 [==============================] - 0s 105us/step - loss: 0.4459 - accuracy: 0.8696
# Epoch 859/1000
# 23/23 [==============================] - 0s 127us/step - loss: 0.4459 - accuracy: 0.8696
# Epoch 860/1000
# 23/23 [==============================] - 0s 80us/step - loss: 0.4459 - accuracy: 0.8696
# Epoch 861/1000
# 23/23 [==============================] - 0s 86us/step - loss: 0.4458 - accuracy: 0.8696
# Epoch 862/1000
# 23/23 [==============================] - 0s 88us/step - loss: 0.4458 - accuracy: 0.8696
# Epoch 863/1000
# 23/23 [==============================] - 0s 100us/step - loss: 0.4458 - accuracy: 0.8696
# Epoch 864/1000
# 23/23 [==============================] - 0s 80us/step - loss: 0.4457 - accuracy: 0.8696
# Epoch 865/1000
# 23/23 [==============================] - 0s 89us/step - loss: 0.4457 - accuracy: 0.8696
# Epoch 866/1000
# 23/23 [==============================] - 0s 94us/step - loss: 0.4457 - accuracy: 0.8696
# Epoch 867/1000
# 23/23 [==============================] - 0s 115us/step - loss: 0.4456 - accuracy: 0.8696
# Epoch 868/1000
# 23/23 [==============================] - 0s 98us/step - loss: 0.4456 - accuracy: 0.8696
# Epoch 869/1000
# 23/23 [==============================] - 0s 81us/step - loss: 0.4456 - accuracy: 0.8696
# Epoch 870/1000
# 23/23 [==============================] - 0s 84us/step - loss: 0.4455 - accuracy: 0.8696
# Epoch 871/1000
# 23/23 [==============================] - 0s 82us/step - loss: 0.4455 - accuracy: 0.8696
# Epoch 872/1000
# 23/23 [==============================] - 0s 85us/step - loss: 0.4455 - accuracy: 0.8696
# Epoch 873/1000
# 23/23 [==============================] - 0s 77us/step - loss: 0.4454 - accuracy: 0.8696
# Epoch 874/1000
# 23/23 [==============================] - 0s 78us/step - loss: 0.4454 - accuracy: 0.8696
# Epoch 875/1000
# 23/23 [==============================] - 0s 76us/step - loss: 0.4454 - accuracy: 0.8696
# Epoch 876/1000
# 23/23 [==============================] - 0s 88us/step - loss: 0.4453 - accuracy: 0.8696
# Epoch 877/1000
# 23/23 [==============================] - 0s 76us/step - loss: 0.4453 - accuracy: 0.8696
# Epoch 878/1000
# 23/23 [==============================] - 0s 81us/step - loss: 0.4453 - accuracy: 0.8696
# Epoch 879/1000
# 23/23 [==============================] - 0s 98us/step - loss: 0.4452 - accuracy: 0.8696
# Epoch 880/1000
# 23/23 [==============================] - 0s 98us/step - loss: 0.4452 - accuracy: 0.8696
# Epoch 881/1000
# 23/23 [==============================] - 0s 114us/step - loss: 0.4452 - accuracy: 0.8696
# Epoch 882/1000
# 23/23 [==============================] - 0s 164us/step - loss: 0.4452 - accuracy: 0.8696
# Epoch 883/1000
# 23/23 [==============================] - 0s 86us/step - loss: 0.4451 - accuracy: 0.8696
# Epoch 884/1000
# 23/23 [==============================] - 0s 80us/step - loss: 0.4451 - accuracy: 0.8696
# Epoch 885/1000
# 23/23 [==============================] - 0s 105us/step - loss: 0.4451 - accuracy: 0.8696
# Epoch 886/1000
# 23/23 [==============================] - 0s 81us/step - loss: 0.4450 - accuracy: 0.8696
# Epoch 887/1000
# 23/23 [==============================] - 0s 73us/step - loss: 0.4450 - accuracy: 0.8696
# Epoch 888/1000
# 23/23 [==============================] - 0s 87us/step - loss: 0.4450 - accuracy: 0.8696
# Epoch 889/1000
# 23/23 [==============================] - 0s 86us/step - loss: 0.4449 - accuracy: 0.8696
# Epoch 890/1000
# 23/23 [==============================] - 0s 94us/step - loss: 0.4449 - accuracy: 0.8696
# Epoch 891/1000
# 23/23 [==============================] - 0s 120us/step - loss: 0.4449 - accuracy: 0.8696
# Epoch 892/1000
# 23/23 [==============================] - 0s 88us/step - loss: 0.4448 - accuracy: 0.8696
# Epoch 893/1000
# 23/23 [==============================] - 0s 108us/step - loss: 0.4448 - accuracy: 0.8696
# Epoch 894/1000
# 23/23 [==============================] - 0s 73us/step - loss: 0.4448 - accuracy: 0.8696
# Epoch 895/1000
# 23/23 [==============================] - 0s 73us/step - loss: 0.4448 - accuracy: 0.8696
# Epoch 896/1000
# 23/23 [==============================] - 0s 80us/step - loss: 0.4447 - accuracy: 0.8696
# Epoch 897/1000
# 23/23 [==============================] - 0s 78us/step - loss: 0.4447 - accuracy: 0.8696
# Epoch 898/1000
# 23/23 [==============================] - 0s 105us/step - loss: 0.4447 - accuracy: 0.8696
# Epoch 899/1000
# 23/23 [==============================] - 0s 73us/step - loss: 0.4446 - accuracy: 0.8696
# Epoch 900/1000
# 23/23 [==============================] - 0s 76us/step - loss: 0.4446 - accuracy: 0.8696
# Epoch 901/1000
# 23/23 [==============================] - 0s 86us/step - loss: 0.4446 - accuracy: 0.8696
# Epoch 902/1000
# 23/23 [==============================] - 0s 84us/step - loss: 0.4446 - accuracy: 0.8696
# Epoch 903/1000
# 23/23 [==============================] - 0s 85us/step - loss: 0.4445 - accuracy: 0.8696
# Epoch 904/1000
# 23/23 [==============================] - 0s 92us/step - loss: 0.4445 - accuracy: 0.8696
# Epoch 905/1000
# 23/23 [==============================] - 0s 73us/step - loss: 0.4445 - accuracy: 0.8696
# Epoch 906/1000
# 23/23 [==============================] - 0s 99us/step - loss: 0.4444 - accuracy: 0.8696
# Epoch 907/1000
# 23/23 [==============================] - 0s 71us/step - loss: 0.4444 - accuracy: 0.8696
# Epoch 908/1000
# 23/23 [==============================] - 0s 83us/step - loss: 0.4444 - accuracy: 0.8696
# Epoch 909/1000
# 23/23 [==============================] - 0s 82us/step - loss: 0.4444 - accuracy: 0.8696
# Epoch 910/1000
# 23/23 [==============================] - 0s 91us/step - loss: 0.4443 - accuracy: 0.8696
# Epoch 911/1000
# 23/23 [==============================] - 0s 84us/step - loss: 0.4443 - accuracy: 0.8696
# Epoch 912/1000
# 23/23 [==============================] - 0s 96us/step - loss: 0.4443 - accuracy: 0.8696
# Epoch 913/1000
# 23/23 [==============================] - 0s 103us/step - loss: 0.4443 - accuracy: 0.8696
# Epoch 914/1000
# 23/23 [==============================] - 0s 88us/step - loss: 0.4442 - accuracy: 0.8696
# Epoch 915/1000
# 23/23 [==============================] - 0s 92us/step - loss: 0.4442 - accuracy: 0.8696
# Epoch 916/1000
# 23/23 [==============================] - 0s 77us/step - loss: 0.4442 - accuracy: 0.8696
# Epoch 917/1000
# 23/23 [==============================] - 0s 81us/step - loss: 0.4441 - accuracy: 0.8696
# Epoch 918/1000
# 23/23 [==============================] - 0s 81us/step - loss: 0.4441 - accuracy: 0.8696
# Epoch 919/1000
# 23/23 [==============================] - 0s 105us/step - loss: 0.4441 - accuracy: 0.8696
# Epoch 920/1000
# 23/23 [==============================] - 0s 85us/step - loss: 0.4441 - accuracy: 0.8696
# Epoch 921/1000
# 23/23 [==============================] - 0s 79us/step - loss: 0.4440 - accuracy: 0.8696
# Epoch 922/1000
# 23/23 [==============================] - 0s 92us/step - loss: 0.4440 - accuracy: 0.8696
# Epoch 923/1000
# 23/23 [==============================] - 0s 103us/step - loss: 0.4440 - accuracy: 0.8696
# Epoch 924/1000
# 23/23 [==============================] - 0s 192us/step - loss: 0.4440 - accuracy: 0.8696
# Epoch 925/1000
# 23/23 [==============================] - 0s 176us/step - loss: 0.4439 - accuracy: 0.8696
# Epoch 926/1000
# 23/23 [==============================] - 0s 89us/step - loss: 0.4439 - accuracy: 0.8696
# Epoch 927/1000
# 23/23 [==============================] - 0s 106us/step - loss: 0.4439 - accuracy: 0.8696
# Epoch 928/1000
# 23/23 [==============================] - 0s 88us/step - loss: 0.4439 - accuracy: 0.8696
# Epoch 929/1000
# 23/23 [==============================] - 0s 71us/step - loss: 0.4438 - accuracy: 0.8696
# Epoch 930/1000
# 23/23 [==============================] - 0s 135us/step - loss: 0.4438 - accuracy: 0.8696
# Epoch 931/1000
# 23/23 [==============================] - 0s 117us/step - loss: 0.4438 - accuracy: 0.8696
# Epoch 932/1000
# 23/23 [==============================] - 0s 125us/step - loss: 0.4438 - accuracy: 0.8696
# Epoch 933/1000
# 23/23 [==============================] - 0s 137us/step - loss: 0.4437 - accuracy: 0.8696
# Epoch 934/1000
# 23/23 [==============================] - 0s 129us/step - loss: 0.4437 - accuracy: 0.8696
# Epoch 935/1000
# 23/23 [==============================] - 0s 88us/step - loss: 0.4437 - accuracy: 0.8696
# Epoch 936/1000
# 23/23 [==============================] - 0s 87us/step - loss: 0.4437 - accuracy: 0.8696
# Epoch 937/1000
# 23/23 [==============================] - 0s 83us/step - loss: 0.4436 - accuracy: 0.8696
# Epoch 938/1000
# 23/23 [==============================] - 0s 71us/step - loss: 0.4436 - accuracy: 0.8696
# Epoch 939/1000
# 23/23 [==============================] - 0s 100us/step - loss: 0.4436 - accuracy: 0.8696
# Epoch 940/1000
# 23/23 [==============================] - 0s 80us/step - loss: 0.4436 - accuracy: 0.8696
# Epoch 941/1000
# 23/23 [==============================] - 0s 85us/step - loss: 0.4436 - accuracy: 0.8696
# Epoch 942/1000
# 23/23 [==============================] - 0s 86us/step - loss: 0.4435 - accuracy: 0.8696
# Epoch 943/1000
# 23/23 [==============================] - 0s 92us/step - loss: 0.4435 - accuracy: 0.8696
# Epoch 944/1000
# 23/23 [==============================] - 0s 92us/step - loss: 0.4435 - accuracy: 0.8696
# Epoch 945/1000
# 23/23 [==============================] - 0s 102us/step - loss: 0.4435 - accuracy: 0.8696
# Epoch 946/1000
# 23/23 [==============================] - 0s 110us/step - loss: 0.4434 - accuracy: 0.8696
# Epoch 947/1000
# 23/23 [==============================] - 0s 89us/step - loss: 0.4434 - accuracy: 0.8696
# Epoch 948/1000
# 23/23 [==============================] - 0s 77us/step - loss: 0.4434 - accuracy: 0.8696
# Epoch 949/1000
# 23/23 [==============================] - 0s 103us/step - loss: 0.4434 - accuracy: 0.8696
# Epoch 950/1000
# 23/23 [==============================] - 0s 79us/step - loss: 0.4434 - accuracy: 0.8696
# Epoch 951/1000
# 23/23 [==============================] - 0s 78us/step - loss: 0.4433 - accuracy: 0.8696
# Epoch 952/1000
# 23/23 [==============================] - 0s 84us/step - loss: 0.4433 - accuracy: 0.8696
# Epoch 953/1000
# 23/23 [==============================] - 0s 98us/step - loss: 0.4433 - accuracy: 0.8696
# Epoch 954/1000
# 23/23 [==============================] - 0s 88us/step - loss: 0.4433 - accuracy: 0.8696
# Epoch 955/1000
# 23/23 [==============================] - 0s 76us/step - loss: 0.4433 - accuracy: 0.8696
# Epoch 956/1000
# 23/23 [==============================] - 0s 86us/step - loss: 0.4432 - accuracy: 0.8696
# Epoch 957/1000
# 23/23 [==============================] - 0s 86us/step - loss: 0.4432 - accuracy: 0.8696
# Epoch 958/1000
# 23/23 [==============================] - 0s 83us/step - loss: 0.4432 - accuracy: 0.8696
# Epoch 959/1000
# 23/23 [==============================] - 0s 78us/step - loss: 0.4432 - accuracy: 0.8696
# Epoch 960/1000
# 23/23 [==============================] - 0s 85us/step - loss: 0.4431 - accuracy: 0.8696
# Epoch 961/1000
# 23/23 [==============================] - 0s 80us/step - loss: 0.4431 - accuracy: 0.8696
# Epoch 962/1000
# 23/23 [==============================] - 0s 86us/step - loss: 0.4431 - accuracy: 0.8696
# Epoch 963/1000
# 23/23 [==============================] - 0s 79us/step - loss: 0.4431 - accuracy: 0.8696
# Epoch 964/1000
# 23/23 [==============================] - 0s 80us/step - loss: 0.4431 - accuracy: 0.8696
# Epoch 965/1000
# 23/23 [==============================] - 0s 109us/step - loss: 0.4430 - accuracy: 0.8696
# Epoch 966/1000
# 23/23 [==============================] - 0s 81us/step - loss: 0.4430 - accuracy: 0.8696
# Epoch 967/1000
# 23/23 [==============================] - 0s 100us/step - loss: 0.4430 - accuracy: 0.8696
# Epoch 968/1000
# 23/23 [==============================] - 0s 76us/step - loss: 0.4430 - accuracy: 0.8696
# Epoch 969/1000
# 23/23 [==============================] - 0s 81us/step - loss: 0.4430 - accuracy: 0.8696
# Epoch 970/1000
# 23/23 [==============================] - 0s 93us/step - loss: 0.4430 - accuracy: 0.8696
# Epoch 971/1000
# 23/23 [==============================] - 0s 118us/step - loss: 0.4429 - accuracy: 0.8696
# Epoch 972/1000
# 23/23 [==============================] - 0s 81us/step - loss: 0.4429 - accuracy: 0.8696
# Epoch 973/1000
# 23/23 [==============================] - 0s 78us/step - loss: 0.4429 - accuracy: 0.8696
# Epoch 974/1000
# 23/23 [==============================] - 0s 90us/step - loss: 0.4429 - accuracy: 0.8696
# Epoch 975/1000
# 23/23 [==============================] - 0s 76us/step - loss: 0.4429 - accuracy: 0.8696
# Epoch 976/1000
# 23/23 [==============================] - 0s 78us/step - loss: 0.4428 - accuracy: 0.8696
# Epoch 977/1000
# 23/23 [==============================] - 0s 148us/step - loss: 0.4428 - accuracy: 0.8696
# Epoch 978/1000
# 23/23 [==============================] - 0s 91us/step - loss: 0.4428 - accuracy: 0.8696
# Epoch 979/1000
# 23/23 [==============================] - 0s 116us/step - loss: 0.4428 - accuracy: 0.8696
# Epoch 980/1000
# 23/23 [==============================] - 0s 80us/step - loss: 0.4428 - accuracy: 0.8696
# Epoch 981/1000
# 23/23 [==============================] - 0s 94us/step - loss: 0.4428 - accuracy: 0.8696
# Epoch 982/1000
# 23/23 [==============================] - 0s 92us/step - loss: 0.4427 - accuracy: 0.8696
# Epoch 983/1000
# 23/23 [==============================] - 0s 100us/step - loss: 0.4427 - accuracy: 0.8696
# Epoch 984/1000
# 23/23 [==============================] - 0s 78us/step - loss: 0.4427 - accuracy: 0.8696
# Epoch 985/1000
# 23/23 [==============================] - 0s 87us/step - loss: 0.4427 - accuracy: 0.8696
# Epoch 986/1000
# 23/23 [==============================] - 0s 74us/step - loss: 0.4427 - accuracy: 0.8696
# Epoch 987/1000
# 23/23 [==============================] - 0s 131us/step - loss: 0.4427 - accuracy: 0.8696
# Epoch 988/1000
# 23/23 [==============================] - 0s 85us/step - loss: 0.4426 - accuracy: 0.8696
# Epoch 989/1000
# 23/23 [==============================] - 0s 78us/step - loss: 0.4426 - accuracy: 0.8696
# Epoch 990/1000
# 23/23 [==============================] - 0s 94us/step - loss: 0.4426 - accuracy: 0.8696
# Epoch 991/1000
# 23/23 [==============================] - 0s 81us/step - loss: 0.4426 - accuracy: 0.8696
# Epoch 992/1000
# 23/23 [==============================] - 0s 78us/step - loss: 0.4426 - accuracy: 0.8696
# Epoch 993/1000
# 23/23 [==============================] - 0s 81us/step - loss: 0.4426 - accuracy: 0.8696
# Epoch 994/1000
# 23/23 [==============================] - 0s 86us/step - loss: 0.4425 - accuracy: 0.8696
# Epoch 995/1000
# 23/23 [==============================] - 0s 73us/step - loss: 0.4425 - accuracy: 0.8696
# Epoch 996/1000
# 23/23 [==============================] - 0s 92us/step - loss: 0.4425 - accuracy: 0.8696
# Epoch 997/1000
# 23/23 [==============================] - 0s 116us/step - loss: 0.4425 - accuracy: 0.8696
# Epoch 998/1000
# 23/23 [==============================] - 0s 82us/step - loss: 0.4425 - accuracy: 0.8696
# Epoch 999/1000
# 23/23 [==============================] - 0s 95us/step - loss: 0.4425 - accuracy: 0.8696
# Epoch 1000/1000
# 23/23 [==============================] - 0s 79us/step - loss: 0.4425 - accuracy: 0.8696

# %% [markdown]
# Acá ya tenemos el modelo entrenado. Algunas funciones de Keras que están buenas:
#
# 1. Obviamente, hacer predicciones:

# %%
valor_a_predecir = -1
valor_a_predecir = (valor_a_predecir - X_mean)/X_std
model.predict([valor_a_predecir])
# Out:
# array([[0.99963593]], dtype=float32)

# %% [markdown]
# ¿Qué significa ese número que devuelve?
#
# 2. Ver la cantidad de parámetros y capas del modelo. Tendrá más sentido cuando entrenemos redes más profundas

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 3. Ver la historia de entrenamiento del modelo. History es un objeto con muchas características, pero tiene guardado la pérdida para cada iteración y la métrica que le hayamos pedido que evalúe.

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy'])

# %%
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

plt.figure()

plt.plot(history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# 4. Se pueden ver los pesos que obtuvo

# %%
print(model.get_weights())
# Out:
# [array([[-1.5635687]], dtype=float32), array([-0.99999064], dtype=float32)]

# %%
w0 = model.get_weights()[0][0][0]
w1 = model.get_weights()[1][0]
print(w0,w1)
# Out:
# -1.5635687 -0.99999064

# %% [markdown]
# 5. Y, como en todo modelo, podemos graficar el resultado.

# %%
plt.figure(figsize = (8,4))
plot = sns.scatterplot(x = 'Temperature (C)', y  = 'Damage Incident', hue = 'Damage Incident', data = dataset, s = 100)

x_plot = np.linspace(-5,30,100)
z = (x_plot - X_mean)/X_std
plt.plot(x_plot, model.predict(z))
# plt.plot(x_plot, sigmoid_function(z,w0,w1))

plt.axhline(0.5, ls = '--', c = 'r', label = 'probabilidad de 0.5')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Perceptrón en 2D
#
# Seguimos con la mismas ideas que antes, pero ahora en vez de un feature hay dos. Vamos a generar un dataset sintético con unas funciones que ya vienen incorporadas en scikit-learn.

# %%
from sklearn.datasets.samples_generator import make_blobs, make_moons
X, y = make_blobs(n_samples=1000, centers=2, n_features=2,
                  random_state=0, cluster_std=0.25)

X, y = make_moons(n_samples=1000, random_state=0)

# %%
print(X.shape)
print(y.shape)
# Out:
# (1000, 2)
# (1000,)

# %%
sns.scatterplot(x = X[:,0], y = X[:,1], hue = y)
plt.show()

# %% [markdown]
# Reescalamos los datos

# %%
X[:,0] = (X[:,0] - X[:,0].mean())/X[:,0].std()
X[:,1] = (X[:,1] - X[:,1].mean())/X[:,1].std()

# %%
sns.scatterplot(x = X[:,0], y = X[:,1], hue = y)
plt.show()

# %% [markdown]
# Definimos el modelo a entrenar y volvemos a mirar algunas de sus características.

# %%
model = Sequential()
# model.add(Dense(100, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# optimizer = keras.optimizers.Adam(lr=0.001, beta_1=0.0, beta_2=0.0, epsilon=None, decay=0.0, amsgrad=False)
optimizer = keras.optimizers.Adam(lr=0.001, beta_1=0.0, beta_2=0.0, decay=0.0, amsgrad=False)
model.compile(optimizer=optimizer,loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X, y, epochs=250, validation_split=0.25)
# Out:
# Train on 750 samples, validate on 250 samples
# Epoch 1/250
# 750/750 [==============================] - 0s 341us/step - loss: 0.6725 - accuracy: 0.5000 - val_loss: 0.6501 - val_accuracy: 0.4880
# Epoch 2/250
# 750/750 [==============================] - 0s 84us/step - loss: 0.6147 - accuracy: 0.5653 - val_loss: 0.5968 - val_accuracy: 0.6040
# Epoch 3/250
# 750/750 [==============================] - 0s 120us/step - loss: 0.5629 - accuracy: 0.7533 - val_loss: 0.5514 - val_accuracy: 0.7920
# Epoch 4/250
# 750/750 [==============================] - 0s 119us/step - loss: 0.5195 - accuracy: 0.8093 - val_loss: 0.5121 - val_accuracy: 0.8000
# Epoch 5/250
# 750/750 [==============================] - 0s 145us/step - loss: 0.4831 - accuracy: 0.8107 - val_loss: 0.4775 - val_accuracy: 0.8080
# Epoch 6/250
# 750/750 [==============================] - 0s 174us/step - loss: 0.4505 - accuracy: 0.8147 - val_loss: 0.4472 - val_accuracy: 0.8160
# Epoch 7/250
# 750/750 [==============================] - 0s 122us/step - loss: 0.4229 - accuracy: 0.8187 - val_loss: 0.4209 - val_accuracy: 0.8160
# Epoch 8/250
# 750/750 [==============================] - 0s 77us/step - loss: 0.3990 - accuracy: 0.8227 - val_loss: 0.3976 - val_accuracy: 0.8280
# Epoch 9/250
# 750/750 [==============================] - 0s 95us/step - loss: 0.3793 - accuracy: 0.8253 - val_loss: 0.3783 - val_accuracy: 0.8320
# Epoch 10/250
# 750/750 [==============================] - 0s 211us/step - loss: 0.3615 - accuracy: 0.8293 - val_loss: 0.3603 - val_accuracy: 0.8360
# Epoch 11/250
# 750/750 [==============================] - 0s 131us/step - loss: 0.3466 - accuracy: 0.8333 - val_loss: 0.3460 - val_accuracy: 0.8440
# Epoch 12/250
# 750/750 [==============================] - 0s 134us/step - loss: 0.3346 - accuracy: 0.8347 - val_loss: 0.3331 - val_accuracy: 0.8440
# Epoch 13/250
# 750/750 [==============================] - 0s 83us/step - loss: 0.3241 - accuracy: 0.8400 - val_loss: 0.3213 - val_accuracy: 0.8480
# Epoch 14/250
# 750/750 [==============================] - 0s 116us/step - loss: 0.3143 - accuracy: 0.8440 - val_loss: 0.3104 - val_accuracy: 0.8520
# Epoch 15/250
# 750/750 [==============================] - 0s 99us/step - loss: 0.3055 - accuracy: 0.8507 - val_loss: 0.3005 - val_accuracy: 0.8560
# Epoch 16/250
# 750/750 [==============================] - 0s 85us/step - loss: 0.2973 - accuracy: 0.8520 - val_loss: 0.2915 - val_accuracy: 0.8560
# Epoch 17/250
# 750/750 [==============================] - 0s 107us/step - loss: 0.2908 - accuracy: 0.8560 - val_loss: 0.2834 - val_accuracy: 0.8600
# Epoch 18/250
# 750/750 [==============================] - 0s 72us/step - loss: 0.2841 - accuracy: 0.8587 - val_loss: 0.2755 - val_accuracy: 0.8640
# Epoch 19/250
# 750/750 [==============================] - 0s 135us/step - loss: 0.2779 - accuracy: 0.8640 - val_loss: 0.2681 - val_accuracy: 0.8640
# Epoch 20/250
# 750/750 [==============================] - 0s 204us/step - loss: 0.2722 - accuracy: 0.8667 - val_loss: 0.2608 - val_accuracy: 0.8640
# Epoch 21/250
# 750/750 [==============================] - 0s 163us/step - loss: 0.2669 - accuracy: 0.8707 - val_loss: 0.2543 - val_accuracy: 0.8640
# Epoch 22/250
# 750/750 [==============================] - 0s 185us/step - loss: 0.2621 - accuracy: 0.8733 - val_loss: 0.2485 - val_accuracy: 0.8680
# Epoch 23/250
# 750/750 [==============================] - 0s 172us/step - loss: 0.2575 - accuracy: 0.8760 - val_loss: 0.2429 - val_accuracy: 0.8680
# Epoch 24/250
# 750/750 [==============================] - 0s 263us/step - loss: 0.2531 - accuracy: 0.8800 - val_loss: 0.2377 - val_accuracy: 0.8720
# Epoch 25/250
# 750/750 [==============================] - 0s 151us/step - loss: 0.2492 - accuracy: 0.8813 - val_loss: 0.2329 - val_accuracy: 0.8760
# Epoch 26/250
# 750/750 [==============================] - 0s 164us/step - loss: 0.2458 - accuracy: 0.8827 - val_loss: 0.2287 - val_accuracy: 0.8800
# Epoch 27/250
# 750/750 [==============================] - 0s 201us/step - loss: 0.2422 - accuracy: 0.8840 - val_loss: 0.2239 - val_accuracy: 0.8840
# Epoch 28/250
# 750/750 [==============================] - 0s 144us/step - loss: 0.2392 - accuracy: 0.8853 - val_loss: 0.2206 - val_accuracy: 0.8880
# Epoch 29/250
# 750/750 [==============================] - 0s 395us/step - loss: 0.2366 - accuracy: 0.8853 - val_loss: 0.2169 - val_accuracy: 0.8880
# Epoch 30/250
# 750/750 [==============================] - 0s 163us/step - loss: 0.2336 - accuracy: 0.8893 - val_loss: 0.2133 - val_accuracy: 0.8880
# Epoch 31/250
# 750/750 [==============================] - 0s 152us/step - loss: 0.2310 - accuracy: 0.8893 - val_loss: 0.2102 - val_accuracy: 0.8920
# Epoch 32/250
# 750/750 [==============================] - 0s 130us/step - loss: 0.2285 - accuracy: 0.8907 - val_loss: 0.2073 - val_accuracy: 0.8960
# Epoch 33/250
# 750/750 [==============================] - 0s 184us/step - loss: 0.2259 - accuracy: 0.8920 - val_loss: 0.2043 - val_accuracy: 0.9000
# Epoch 34/250
# 750/750 [==============================] - 0s 143us/step - loss: 0.2236 - accuracy: 0.8920 - val_loss: 0.2018 - val_accuracy: 0.9080
# Epoch 35/250
# 750/750 [==============================] - 0s 149us/step - loss: 0.2212 - accuracy: 0.8933 - val_loss: 0.1995 - val_accuracy: 0.9120
# Epoch 36/250
# 750/750 [==============================] - 0s 109us/step - loss: 0.2189 - accuracy: 0.8947 - val_loss: 0.1965 - val_accuracy: 0.9120
# Epoch 37/250
# 750/750 [==============================] - 0s 116us/step - loss: 0.2163 - accuracy: 0.8973 - val_loss: 0.1937 - val_accuracy: 0.9120
# Epoch 38/250
# 750/750 [==============================] - 0s 166us/step - loss: 0.2138 - accuracy: 0.8987 - val_loss: 0.1908 - val_accuracy: 0.9120
# Epoch 39/250
# 750/750 [==============================] - 0s 118us/step - loss: 0.2111 - accuracy: 0.9000 - val_loss: 0.1883 - val_accuracy: 0.9120
# Epoch 40/250
# 750/750 [==============================] - 0s 116us/step - loss: 0.2088 - accuracy: 0.9027 - val_loss: 0.1861 - val_accuracy: 0.9160
# Epoch 41/250
# 750/750 [==============================] - 0s 95us/step - loss: 0.2065 - accuracy: 0.9027 - val_loss: 0.1836 - val_accuracy: 0.9200
# Epoch 42/250
# 750/750 [==============================] - 0s 91us/step - loss: 0.2040 - accuracy: 0.9040 - val_loss: 0.1809 - val_accuracy: 0.9200
# Epoch 43/250
# 750/750 [==============================] - 0s 85us/step - loss: 0.2015 - accuracy: 0.9067 - val_loss: 0.1783 - val_accuracy: 0.9200
# Epoch 44/250
# 750/750 [==============================] - 0s 96us/step - loss: 0.1990 - accuracy: 0.9093 - val_loss: 0.1757 - val_accuracy: 0.9200
# Epoch 45/250
# 750/750 [==============================] - 0s 86us/step - loss: 0.1968 - accuracy: 0.9107 - val_loss: 0.1735 - val_accuracy: 0.9200
# Epoch 46/250
# 750/750 [==============================] - 0s 85us/step - loss: 0.1942 - accuracy: 0.9107 - val_loss: 0.1708 - val_accuracy: 0.9240
# Epoch 47/250
# 750/750 [==============================] - 0s 112us/step - loss: 0.1915 - accuracy: 0.9133 - val_loss: 0.1684 - val_accuracy: 0.9280
# Epoch 48/250
# 750/750 [==============================] - 0s 156us/step - loss: 0.1890 - accuracy: 0.9133 - val_loss: 0.1661 - val_accuracy: 0.9280
# Epoch 49/250
# 750/750 [==============================] - 0s 92us/step - loss: 0.1869 - accuracy: 0.9147 - val_loss: 0.1637 - val_accuracy: 0.9280
# Epoch 50/250
# 750/750 [==============================] - 0s 101us/step - loss: 0.1844 - accuracy: 0.9160 - val_loss: 0.1613 - val_accuracy: 0.9280
# Epoch 51/250
# 750/750 [==============================] - 0s 110us/step - loss: 0.1816 - accuracy: 0.9200 - val_loss: 0.1591 - val_accuracy: 0.9280
# Epoch 52/250
# 750/750 [==============================] - 0s 94us/step - loss: 0.1789 - accuracy: 0.9227 - val_loss: 0.1565 - val_accuracy: 0.9280
# Epoch 53/250
# 750/750 [==============================] - 0s 95us/step - loss: 0.1764 - accuracy: 0.9227 - val_loss: 0.1546 - val_accuracy: 0.9280
# Epoch 54/250
# 750/750 [==============================] - 0s 85us/step - loss: 0.1739 - accuracy: 0.9240 - val_loss: 0.1521 - val_accuracy: 0.9320
# Epoch 55/250
# 750/750 [==============================] - 0s 84us/step - loss: 0.1714 - accuracy: 0.9253 - val_loss: 0.1503 - val_accuracy: 0.9320
# Epoch 56/250
# 750/750 [==============================] - 0s 81us/step - loss: 0.1688 - accuracy: 0.9267 - val_loss: 0.1477 - val_accuracy: 0.9400
# Epoch 57/250
# 750/750 [==============================] - 0s 83us/step - loss: 0.1660 - accuracy: 0.9280 - val_loss: 0.1451 - val_accuracy: 0.9440
# Epoch 58/250
# 750/750 [==============================] - 0s 84us/step - loss: 0.1633 - accuracy: 0.9280 - val_loss: 0.1429 - val_accuracy: 0.9440
# Epoch 59/250
# 750/750 [==============================] - 0s 88us/step - loss: 0.1606 - accuracy: 0.9280 - val_loss: 0.1401 - val_accuracy: 0.9480
# Epoch 60/250
# 750/750 [==============================] - 0s 135us/step - loss: 0.1578 - accuracy: 0.9307 - val_loss: 0.1377 - val_accuracy: 0.9480
# Epoch 61/250
# 750/750 [==============================] - 0s 78us/step - loss: 0.1552 - accuracy: 0.9347 - val_loss: 0.1355 - val_accuracy: 0.9480
# Epoch 62/250
# 750/750 [==============================] - 0s 105us/step - loss: 0.1527 - accuracy: 0.9347 - val_loss: 0.1333 - val_accuracy: 0.9480
# Epoch 63/250
# 750/750 [==============================] - 0s 82us/step - loss: 0.1503 - accuracy: 0.9373 - val_loss: 0.1310 - val_accuracy: 0.9480
# Epoch 64/250
# 750/750 [==============================] - 0s 85us/step - loss: 0.1479 - accuracy: 0.9373 - val_loss: 0.1286 - val_accuracy: 0.9480
# Epoch 65/250
# 750/750 [==============================] - 0s 85us/step - loss: 0.1456 - accuracy: 0.9387 - val_loss: 0.1265 - val_accuracy: 0.9480
# Epoch 66/250
# 750/750 [==============================] - 0s 85us/step - loss: 0.1430 - accuracy: 0.9413 - val_loss: 0.1241 - val_accuracy: 0.9480
# Epoch 67/250
# 750/750 [==============================] - 0s 87us/step - loss: 0.1407 - accuracy: 0.9440 - val_loss: 0.1220 - val_accuracy: 0.9520
# Epoch 68/250
# 750/750 [==============================] - 0s 95us/step - loss: 0.1382 - accuracy: 0.9427 - val_loss: 0.1196 - val_accuracy: 0.9520
# Epoch 69/250
# 750/750 [==============================] - 0s 95us/step - loss: 0.1357 - accuracy: 0.9453 - val_loss: 0.1174 - val_accuracy: 0.9520
# Epoch 70/250
# 750/750 [==============================] - 0s 107us/step - loss: 0.1331 - accuracy: 0.9467 - val_loss: 0.1150 - val_accuracy: 0.9520
# Epoch 71/250
# 750/750 [==============================] - 0s 75us/step - loss: 0.1306 - accuracy: 0.9493 - val_loss: 0.1132 - val_accuracy: 0.9520
# Epoch 72/250
# 750/750 [==============================] - 0s 82us/step - loss: 0.1284 - accuracy: 0.9493 - val_loss: 0.1110 - val_accuracy: 0.9560
# Epoch 73/250
# 750/750 [==============================] - 0s 86us/step - loss: 0.1258 - accuracy: 0.9520 - val_loss: 0.1089 - val_accuracy: 0.9560
# Epoch 74/250
# 750/750 [==============================] - 0s 106us/step - loss: 0.1233 - accuracy: 0.9533 - val_loss: 0.1065 - val_accuracy: 0.9600
# Epoch 75/250
# 750/750 [==============================] - 0s 85us/step - loss: 0.1210 - accuracy: 0.9533 - val_loss: 0.1044 - val_accuracy: 0.9640
# Epoch 76/250
# 750/750 [==============================] - 0s 92us/step - loss: 0.1185 - accuracy: 0.9547 - val_loss: 0.1018 - val_accuracy: 0.9640
# Epoch 77/250
# 750/750 [==============================] - 0s 98us/step - loss: 0.1163 - accuracy: 0.9573 - val_loss: 0.1001 - val_accuracy: 0.9680
# Epoch 78/250
# 750/750 [==============================] - 0s 83us/step - loss: 0.1139 - accuracy: 0.9573 - val_loss: 0.0979 - val_accuracy: 0.9680
# Epoch 79/250
# 750/750 [==============================] - 0s 96us/step - loss: 0.1114 - accuracy: 0.9587 - val_loss: 0.0959 - val_accuracy: 0.9680
# Epoch 80/250
# 750/750 [==============================] - 0s 92us/step - loss: 0.1091 - accuracy: 0.9600 - val_loss: 0.0940 - val_accuracy: 0.9680
# Epoch 81/250
# 750/750 [==============================] - 0s 96us/step - loss: 0.1068 - accuracy: 0.9613 - val_loss: 0.0915 - val_accuracy: 0.9720
# Epoch 82/250
# 750/750 [==============================] - 0s 84us/step - loss: 0.1043 - accuracy: 0.9627 - val_loss: 0.0895 - val_accuracy: 0.9760
# Epoch 83/250
# 750/750 [==============================] - 0s 95us/step - loss: 0.1020 - accuracy: 0.9627 - val_loss: 0.0873 - val_accuracy: 0.9760
# Epoch 84/250
# 750/750 [==============================] - 0s 89us/step - loss: 0.0999 - accuracy: 0.9640 - val_loss: 0.0856 - val_accuracy: 0.9800
# Epoch 85/250
# 750/750 [==============================] - 0s 149us/step - loss: 0.0977 - accuracy: 0.9653 - val_loss: 0.0838 - val_accuracy: 0.9800
# Epoch 86/250
# 750/750 [==============================] - 0s 86us/step - loss: 0.0956 - accuracy: 0.9653 - val_loss: 0.0818 - val_accuracy: 0.9840
# Epoch 87/250
# 750/750 [==============================] - 0s 70us/step - loss: 0.0932 - accuracy: 0.9667 - val_loss: 0.0795 - val_accuracy: 0.9880
# Epoch 88/250
# 750/750 [==============================] - 0s 78us/step - loss: 0.0910 - accuracy: 0.9707 - val_loss: 0.0777 - val_accuracy: 0.9880
# Epoch 89/250
# 750/750 [==============================] - 0s 187us/step - loss: 0.0887 - accuracy: 0.9707 - val_loss: 0.0754 - val_accuracy: 0.9880
# Epoch 90/250
# 750/750 [==============================] - 0s 101us/step - loss: 0.0864 - accuracy: 0.9733 - val_loss: 0.0735 - val_accuracy: 0.9880
# Epoch 91/250
# 750/750 [==============================] - 0s 109us/step - loss: 0.0842 - accuracy: 0.9760 - val_loss: 0.0716 - val_accuracy: 0.9920
# Epoch 92/250
# 750/750 [==============================] - 0s 100us/step - loss: 0.0821 - accuracy: 0.9760 - val_loss: 0.0698 - val_accuracy: 0.9920
# Epoch 93/250
# 750/750 [==============================] - 0s 93us/step - loss: 0.0800 - accuracy: 0.9773 - val_loss: 0.0683 - val_accuracy: 0.9920
# Epoch 94/250
# 750/750 [==============================] - 0s 97us/step - loss: 0.0783 - accuracy: 0.9787 - val_loss: 0.0669 - val_accuracy: 0.9920
# Epoch 95/250
# 750/750 [==============================] - 0s 99us/step - loss: 0.0765 - accuracy: 0.9787 - val_loss: 0.0651 - val_accuracy: 0.9920
# Epoch 96/250
# 750/750 [==============================] - 0s 88us/step - loss: 0.0748 - accuracy: 0.9800 - val_loss: 0.0637 - val_accuracy: 0.9920
# Epoch 97/250
# 750/750 [==============================] - 0s 74us/step - loss: 0.0732 - accuracy: 0.9813 - val_loss: 0.0623 - val_accuracy: 0.9920
# Epoch 98/250
# 750/750 [==============================] - 0s 85us/step - loss: 0.0716 - accuracy: 0.9813 - val_loss: 0.0612 - val_accuracy: 0.9920
# Epoch 99/250
# 750/750 [==============================] - 0s 92us/step - loss: 0.0699 - accuracy: 0.9827 - val_loss: 0.0590 - val_accuracy: 0.9920
# Epoch 100/250
# 750/750 [==============================] - 0s 93us/step - loss: 0.0681 - accuracy: 0.9840 - val_loss: 0.0574 - val_accuracy: 0.9920
# Epoch 101/250
# 750/750 [==============================] - 0s 103us/step - loss: 0.0662 - accuracy: 0.9853 - val_loss: 0.0559 - val_accuracy: 0.9920
# Epoch 102/250
# 750/750 [==============================] - 0s 106us/step - loss: 0.0645 - accuracy: 0.9853 - val_loss: 0.0541 - val_accuracy: 0.9920
# Epoch 103/250
# 750/750 [==============================] - 0s 105us/step - loss: 0.0625 - accuracy: 0.9853 - val_loss: 0.0523 - val_accuracy: 0.9960
# Epoch 104/250
# 750/750 [==============================] - 0s 102us/step - loss: 0.0608 - accuracy: 0.9867 - val_loss: 0.0510 - val_accuracy: 0.9960
# Epoch 105/250
# 750/750 [==============================] - 0s 98us/step - loss: 0.0593 - accuracy: 0.9867 - val_loss: 0.0497 - val_accuracy: 0.9960
# Epoch 106/250
# 750/750 [==============================] - 0s 87us/step - loss: 0.0578 - accuracy: 0.9880 - val_loss: 0.0484 - val_accuracy: 0.9960
# Epoch 107/250
# 750/750 [==============================] - 0s 90us/step - loss: 0.0561 - accuracy: 0.9880 - val_loss: 0.0470 - val_accuracy: 1.0000
# Epoch 108/250
# 750/750 [==============================] - 0s 81us/step - loss: 0.0545 - accuracy: 0.9893 - val_loss: 0.0456 - val_accuracy: 1.0000
# Epoch 109/250
# 750/750 [==============================] - 0s 82us/step - loss: 0.0531 - accuracy: 0.9880 - val_loss: 0.0446 - val_accuracy: 1.0000
# Epoch 110/250
# 750/750 [==============================] - 0s 189us/step - loss: 0.0517 - accuracy: 0.9880 - val_loss: 0.0431 - val_accuracy: 1.0000
# Epoch 111/250
# 750/750 [==============================] - 0s 96us/step - loss: 0.0502 - accuracy: 0.9907 - val_loss: 0.0418 - val_accuracy: 1.0000
# Epoch 112/250
# 750/750 [==============================] - 0s 98us/step - loss: 0.0486 - accuracy: 0.9920 - val_loss: 0.0404 - val_accuracy: 1.0000
# Epoch 113/250
# 750/750 [==============================] - 0s 85us/step - loss: 0.0471 - accuracy: 0.9920 - val_loss: 0.0390 - val_accuracy: 1.0000
# Epoch 114/250
# 750/750 [==============================] - 0s 109us/step - loss: 0.0457 - accuracy: 0.9933 - val_loss: 0.0378 - val_accuracy: 1.0000
# Epoch 115/250
# 750/750 [==============================] - 0s 81us/step - loss: 0.0443 - accuracy: 0.9947 - val_loss: 0.0368 - val_accuracy: 1.0000
# Epoch 116/250
# 750/750 [==============================] - 0s 81us/step - loss: 0.0431 - accuracy: 0.9947 - val_loss: 0.0358 - val_accuracy: 1.0000
# Epoch 117/250
# 750/750 [==============================] - 0s 80us/step - loss: 0.0418 - accuracy: 0.9947 - val_loss: 0.0343 - val_accuracy: 1.0000
# Epoch 118/250
# 750/750 [==============================] - 0s 83us/step - loss: 0.0405 - accuracy: 0.9960 - val_loss: 0.0332 - val_accuracy: 1.0000
# Epoch 119/250
# 750/750 [==============================] - 0s 84us/step - loss: 0.0393 - accuracy: 0.9960 - val_loss: 0.0323 - val_accuracy: 1.0000
# Epoch 120/250
# 750/750 [==============================] - 0s 187us/step - loss: 0.0382 - accuracy: 0.9973 - val_loss: 0.0312 - val_accuracy: 1.0000
# Epoch 121/250
# 750/750 [==============================] - 0s 93us/step - loss: 0.0371 - accuracy: 0.9973 - val_loss: 0.0304 - val_accuracy: 1.0000
# Epoch 122/250
# 750/750 [==============================] - 0s 85us/step - loss: 0.0360 - accuracy: 0.9973 - val_loss: 0.0293 - val_accuracy: 1.0000
# Epoch 123/250
# 750/750 [==============================] - 0s 75us/step - loss: 0.0350 - accuracy: 1.0000 - val_loss: 0.0283 - val_accuracy: 1.0000
# Epoch 124/250
# 750/750 [==============================] - 0s 74us/step - loss: 0.0339 - accuracy: 1.0000 - val_loss: 0.0273 - val_accuracy: 1.0000
# Epoch 125/250
# 750/750 [==============================] - 0s 80us/step - loss: 0.0328 - accuracy: 1.0000 - val_loss: 0.0264 - val_accuracy: 1.0000
# Epoch 126/250
# 750/750 [==============================] - 0s 84us/step - loss: 0.0322 - accuracy: 1.0000 - val_loss: 0.0259 - val_accuracy: 1.0000
# Epoch 127/250
# 750/750 [==============================] - 0s 86us/step - loss: 0.0311 - accuracy: 1.0000 - val_loss: 0.0249 - val_accuracy: 1.0000
# Epoch 128/250
# 750/750 [==============================] - 0s 105us/step - loss: 0.0302 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 1.0000
# Epoch 129/250
# 750/750 [==============================] - 0s 81us/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 1.0000
# Epoch 130/250
# 750/750 [==============================] - 0s 75us/step - loss: 0.0283 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 1.0000
# Epoch 131/250
# 750/750 [==============================] - 0s 82us/step - loss: 0.0274 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 1.0000
# Epoch 132/250
# 750/750 [==============================] - 0s 79us/step - loss: 0.0265 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 1.0000
# Epoch 133/250
# 750/750 [==============================] - 0s 84us/step - loss: 0.0258 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 1.0000
# Epoch 134/250
# 750/750 [==============================] - 0s 84us/step - loss: 0.0249 - accuracy: 1.0000 - val_loss: 0.0195 - val_accuracy: 1.0000
# Epoch 135/250
# 750/750 [==============================] - 0s 94us/step - loss: 0.0240 - accuracy: 1.0000 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 136/250
# 750/750 [==============================] - 0s 94us/step - loss: 0.0235 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 137/250
# 750/750 [==============================] - 0s 114us/step - loss: 0.0226 - accuracy: 1.0000 - val_loss: 0.0177 - val_accuracy: 1.0000
# Epoch 138/250
# 750/750 [==============================] - 0s 98us/step - loss: 0.0218 - accuracy: 1.0000 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 139/250
# 750/750 [==============================] - 0s 95us/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 0.0165 - val_accuracy: 1.0000
# Epoch 140/250
# 750/750 [==============================] - 0s 99us/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.0159 - val_accuracy: 1.0000
# Epoch 141/250
# 750/750 [==============================] - 0s 82us/step - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.0154 - val_accuracy: 1.0000
# Epoch 142/250
# 750/750 [==============================] - 0s 82us/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 143/250
# 750/750 [==============================] - 0s 90us/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 144/250
# 750/750 [==============================] - 0s 103us/step - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 1.0000
# Epoch 145/250
# 750/750 [==============================] - 0s 83us/step - loss: 0.0174 - accuracy: 1.0000 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 146/250
# 750/750 [==============================] - 0s 107us/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 147/250
# 750/750 [==============================] - 0s 92us/step - loss: 0.0163 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 1.0000
# Epoch 148/250
# 750/750 [==============================] - 0s 84us/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 149/250
# 750/750 [==============================] - 0s 85us/step - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 150/250
# 750/750 [==============================] - 0s 84us/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 151/250
# 750/750 [==============================] - 0s 79us/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 1.0000
# Epoch 152/250
# 750/750 [==============================] - 0s 76us/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.0101 - val_accuracy: 1.0000
# Epoch 153/250
# 750/750 [==============================] - 0s 83us/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 154/250
# 750/750 [==============================] - 0s 80us/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 155/250
# 750/750 [==============================] - 0s 79us/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 156/250
# 750/750 [==============================] - 0s 85us/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 157/250
# 750/750 [==============================] - 0s 90us/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 158/250
# 750/750 [==============================] - 0s 90us/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 159/250
# 750/750 [==============================] - 0s 81us/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 160/250
# 750/750 [==============================] - 0s 84us/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 161/250
# 750/750 [==============================] - 0s 92us/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 162/250
# 750/750 [==============================] - 0s 87us/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 163/250
# 750/750 [==============================] - 0s 87us/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 164/250
# 750/750 [==============================] - 0s 79us/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 165/250
# 750/750 [==============================] - 0s 93us/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 166/250
# 750/750 [==============================] - 0s 87us/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 167/250
# 750/750 [==============================] - 0s 83us/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 168/250
# 750/750 [==============================] - 0s 82us/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 169/250
# 750/750 [==============================] - 0s 98us/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 170/250
# 750/750 [==============================] - 0s 91us/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 171/250
# 750/750 [==============================] - 0s 86us/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 172/250
# 750/750 [==============================] - 0s 86us/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 173/250
# 750/750 [==============================] - 0s 87us/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 174/250
# 750/750 [==============================] - 0s 84us/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 175/250
# 750/750 [==============================] - 0s 81us/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 176/250
# 750/750 [==============================] - 0s 100us/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 177/250
# 750/750 [==============================] - 0s 78us/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 178/250
# 750/750 [==============================] - 0s 83us/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 179/250
# 750/750 [==============================] - 0s 87us/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 180/250
# 750/750 [==============================] - 0s 108us/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 181/250
# 750/750 [==============================] - 0s 81us/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 182/250
# 750/750 [==============================] - 0s 77us/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 183/250
# 750/750 [==============================] - 0s 78us/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 184/250
# 750/750 [==============================] - 0s 80us/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 185/250
# 750/750 [==============================] - 0s 75us/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 186/250
# 750/750 [==============================] - 0s 78us/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 187/250
# 750/750 [==============================] - 0s 78us/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 188/250
# 750/750 [==============================] - 0s 105us/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 189/250
# 750/750 [==============================] - 0s 91us/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 190/250
# 750/750 [==============================] - 0s 83us/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 191/250
# 750/750 [==============================] - 0s 92us/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 192/250
# 750/750 [==============================] - 0s 104us/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 193/250
# 750/750 [==============================] - 0s 95us/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 194/250
# 750/750 [==============================] - 0s 88us/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 195/250
# 750/750 [==============================] - 0s 79us/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 196/250
# 750/750 [==============================] - 0s 84us/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 197/250
# 750/750 [==============================] - 0s 84us/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 198/250
# 750/750 [==============================] - 0s 101us/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 199/250
# 750/750 [==============================] - 0s 102us/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 200/250
# 750/750 [==============================] - 0s 84us/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 201/250
# 750/750 [==============================] - 0s 84us/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 202/250
# 750/750 [==============================] - 0s 92us/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 203/250
# 750/750 [==============================] - 0s 80us/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 204/250
# 750/750 [==============================] - 0s 85us/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 205/250
# 750/750 [==============================] - 0s 84us/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 206/250
# 750/750 [==============================] - 0s 90us/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 207/250
# 750/750 [==============================] - 0s 82us/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 208/250
# 750/750 [==============================] - 0s 92us/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 209/250
# 750/750 [==============================] - 0s 103us/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 210/250
# 750/750 [==============================] - 0s 104us/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 211/250
# 750/750 [==============================] - 0s 86us/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 212/250
# 750/750 [==============================] - 0s 74us/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 213/250
# 750/750 [==============================] - 0s 80us/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 9.8204e-04 - val_accuracy: 1.0000
# Epoch 214/250
# 750/750 [==============================] - 0s 86us/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 9.5030e-04 - val_accuracy: 1.0000
# Epoch 215/250
# 750/750 [==============================] - 0s 74us/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 9.1454e-04 - val_accuracy: 1.0000
# Epoch 216/250
# 750/750 [==============================] - 0s 87us/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 8.8189e-04 - val_accuracy: 1.0000
# Epoch 217/250
# 750/750 [==============================] - 0s 96us/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 8.5464e-04 - val_accuracy: 1.0000
# Epoch 218/250
# 750/750 [==============================] - 0s 91us/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 8.2029e-04 - val_accuracy: 1.0000
# Epoch 219/250
# 750/750 [==============================] - 0s 89us/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 7.9764e-04 - val_accuracy: 1.0000
# Epoch 220/250
# 750/750 [==============================] - 0s 85us/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 7.7877e-04 - val_accuracy: 1.0000
# Epoch 221/250
# 750/750 [==============================] - 0s 92us/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 7.5439e-04 - val_accuracy: 1.0000
# Epoch 222/250
# 750/750 [==============================] - 0s 84us/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 7.1925e-04 - val_accuracy: 1.0000
# Epoch 223/250
# 750/750 [==============================] - 0s 84us/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 6.9978e-04 - val_accuracy: 1.0000
# Epoch 224/250
# 750/750 [==============================] - 0s 77us/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 6.6816e-04 - val_accuracy: 1.0000
# Epoch 225/250
# 750/750 [==============================] - 0s 102us/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 6.4306e-04 - val_accuracy: 1.0000
# Epoch 226/250
# 750/750 [==============================] - 0s 100us/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 6.2879e-04 - val_accuracy: 1.0000
# Epoch 227/250
# 750/750 [==============================] - 0s 105us/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 6.0075e-04 - val_accuracy: 1.0000
# Epoch 228/250
# 750/750 [==============================] - 0s 124us/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 5.7458e-04 - val_accuracy: 1.0000
# Epoch 229/250
# 750/750 [==============================] - 0s 111us/step - loss: 9.9321e-04 - accuracy: 1.0000 - val_loss: 5.5887e-04 - val_accuracy: 1.0000
# Epoch 230/250
# 750/750 [==============================] - 0s 141us/step - loss: 9.9911e-04 - accuracy: 1.0000 - val_loss: 5.3814e-04 - val_accuracy: 1.0000
# Epoch 231/250
# 750/750 [==============================] - 0s 114us/step - loss: 9.3835e-04 - accuracy: 1.0000 - val_loss: 5.1646e-04 - val_accuracy: 1.0000
# Epoch 232/250
# 750/750 [==============================] - 0s 84us/step - loss: 9.1767e-04 - accuracy: 1.0000 - val_loss: 4.9799e-04 - val_accuracy: 1.0000
# Epoch 233/250
# 750/750 [==============================] - 0s 84us/step - loss: 8.6397e-04 - accuracy: 1.0000 - val_loss: 4.8044e-04 - val_accuracy: 1.0000
# Epoch 234/250
# 750/750 [==============================] - 0s 80us/step - loss: 8.3594e-04 - accuracy: 1.0000 - val_loss: 4.6051e-04 - val_accuracy: 1.0000
# Epoch 235/250
# 750/750 [==============================] - 0s 84us/step - loss: 8.0040e-04 - accuracy: 1.0000 - val_loss: 4.4639e-04 - val_accuracy: 1.0000
# Epoch 236/250
# 750/750 [==============================] - 0s 79us/step - loss: 7.8838e-04 - accuracy: 1.0000 - val_loss: 4.2882e-04 - val_accuracy: 1.0000
# Epoch 237/250
# 750/750 [==============================] - 0s 85us/step - loss: 7.5823e-04 - accuracy: 1.0000 - val_loss: 4.1837e-04 - val_accuracy: 1.0000
# Epoch 238/250
# 750/750 [==============================] - 0s 94us/step - loss: 7.6677e-04 - accuracy: 1.0000 - val_loss: 4.0785e-04 - val_accuracy: 1.0000
# Epoch 239/250
# 750/750 [==============================] - 0s 76us/step - loss: 7.3637e-04 - accuracy: 1.0000 - val_loss: 3.9482e-04 - val_accuracy: 1.0000
# Epoch 240/250
# 750/750 [==============================] - 0s 83us/step - loss: 7.1296e-04 - accuracy: 1.0000 - val_loss: 3.8545e-04 - val_accuracy: 1.0000
# Epoch 241/250
# 750/750 [==============================] - 0s 86us/step - loss: 6.9754e-04 - accuracy: 1.0000 - val_loss: 3.7225e-04 - val_accuracy: 1.0000
# Epoch 242/250
# 750/750 [==============================] - 0s 79us/step - loss: 6.7132e-04 - accuracy: 1.0000 - val_loss: 3.5865e-04 - val_accuracy: 1.0000
# Epoch 243/250
# 750/750 [==============================] - 0s 84us/step - loss: 6.3747e-04 - accuracy: 1.0000 - val_loss: 3.3927e-04 - val_accuracy: 1.0000
# Epoch 244/250
# 750/750 [==============================] - 0s 90us/step - loss: 6.1181e-04 - accuracy: 1.0000 - val_loss: 3.1946e-04 - val_accuracy: 1.0000
# Epoch 245/250
# 750/750 [==============================] - 0s 89us/step - loss: 5.9530e-04 - accuracy: 1.0000 - val_loss: 3.0945e-04 - val_accuracy: 1.0000
# Epoch 246/250
# 750/750 [==============================] - ETA: 0s - loss: 2.6894e-04 - accuracy: 1.00 - 0s 79us/step - loss: 5.6887e-04 - accuracy: 1.0000 - val_loss: 2.9661e-04 - val_accuracy: 1.0000
# Epoch 247/250
# 750/750 [==============================] - 0s 105us/step - loss: 5.4045e-04 - accuracy: 1.0000 - val_loss: 2.8242e-04 - val_accuracy: 1.0000
# Epoch 248/250
# 750/750 [==============================] - 0s 94us/step - loss: 5.4285e-04 - accuracy: 1.0000 - val_loss: 2.7081e-04 - val_accuracy: 1.0000
# Epoch 249/250
# 750/750 [==============================] - 0s 78us/step - loss: 5.2310e-04 - accuracy: 1.0000 - val_loss: 2.6053e-04 - val_accuracy: 1.0000
# Epoch 250/250
# 750/750 [==============================] - 0s 75us/step - loss: 5.0600e-04 - accuracy: 1.0000 - val_loss: 2.5025e-04 - val_accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 10)                30
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'val_loss', 'val_accuracy', 'accuracy'])

# %% [markdown]
# Notar que se agregaron una keys, asociadas al set de validación. Grafiquemos.

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ¿Cuántos parámetros tiene ahora el modelo?

# %%
print(model.get_weights())
# Out:
# [array([[ 1.2563754 ,  1.8589114 , -2.7431989 ,  2.38917   , -1.0549763 ,
#         -2.4314463 ,  0.03382935,  1.2307994 , -2.4409246 , -0.90178955],
#        [-1.4170371 ,  0.81261486, -0.7001128 ,  0.17905246,  1.1508746 ,
#         -0.23792206,  1.8001863 , -1.1540424 , -0.24950929,  1.0840005 ]],
#       dtype=float32), array([-0.87809014,  1.5520722 ,  1.3516423 , -1.2940418 , -0.8628252 ,
#        -1.3148519 , -0.7201433 , -0.87709296, -1.3188382 , -0.7570773 ],
#       dtype=float32), array([[ 2.526316 ],
#        [-2.3804264],
#        [ 4.3000216],
#        [ 5.648951 ],
#        [-3.3913422],
#        [-5.5860004],
#        [-2.4118333],
#        [ 2.157555 ],
#        [-5.83806  ],
#        [-2.9908524]], dtype=float32), array([-0.9807476], dtype=float32)]

# %% [markdown]
# Y graficamos las fronteras de decisión. ¿Notan que ya no es una frontera abrupta, sino que hay una zona de cambio?¿A qué se debe?

# %%
plt.figure(figsize = (10,6))

ax = sns.scatterplot(x = X[:,0], y = X[:,1], hue = y)
xlim = ax.get_xlim()
ylim = ax.get_ylim()
xx, yy = np.meshgrid(np.linspace(*xlim, num=200),
                      np.linspace(*ylim, num=200))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
contours = ax.contourf(xx, yy, Z, levels = 10, alpha=0.3, cmap = 'plasma')
plt.show()

# %% [markdown]
# **Ejercicio:** volver a correr esta sección, pero reemplazando la función que genera los datos `make_blobs` por `make_moons`. ¿Qué problema ven en el resultado?

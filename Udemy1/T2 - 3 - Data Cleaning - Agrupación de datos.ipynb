# %%
import numpy as np
import pandas as pd

# %%
gender = ["Male", "Female"]
income = ["Poor", "Middle Class", "Rich"]

# %%
gender_data = []
income_data = []

for i in range(0,500):
    gender_data.append(np.random.choice(gender))
    income_data.append(np.random.choice(income))

# %%
gender_data[1:10]
# Out:
# ['Male',
#  'Male',
#  'Male',
#  'Female',
#  'Female',
#  'Male',
#  'Female',
#  'Female',
#  'Male']

# %%
income_data[1:10]
# Out:
# ['Middle Class',
#  'Rich',
#  'Middle Class',
#  'Middle Class',
#  'Middle Class',
#  'Middle Class',
#  'Middle Class',
#  'Middle Class',
#  'Rich']

# %%
n = 500
height = 160 + 30 * np.random.randn(n)
weight = 65 + 25 * np.random.randn(n)
age = 30 + 12 * np.random.randn(n)
income = 18000 + 3500 * np.random.rand(n)

# %%
data = pd.DataFrame(
    {
        "Gender" : gender_data,
        "Economic Status" : income_data,
        "Height" : height,
        "Weight" : weight,
        "Age" : age,
        "Income" : income
    }
)

# %%
data.head()
# Out:
#    Gender Economic Status      Height     Weight        Age        Income
# 0  Female            Rich  159.568122  47.285346  22.356860  19658.786317
# 1    Male    Middle Class  176.542427  64.933623  42.790762  18868.449410
# 2    Male            Rich  127.186468  67.250264  32.642043  19646.224771
# 3    Male    Middle Class  152.047987  95.336582  31.071772  20270.470754
# 4  Female    Middle Class  113.903682  88.846191  48.370033  18586.376641

# %% [markdown]
# ## Agrupación de datos

# %%
grouped_gender = data.groupby("Gender")

# %%
grouped_gender.groups
# Out:
# {'Female': Int64Index([  0,   4,   5,   7,   8,  10,  12,  13,  17,  21,
#              ...
#              482, 485, 490, 492, 493, 494, 495, 497, 498, 499],
#             dtype='int64', length=263),
#  'Male': Int64Index([  1,   2,   3,   6,   9,  11,  14,  15,  16,  18,
#              ...
#              478, 481, 483, 484, 486, 487, 488, 489, 491, 496],
#             dtype='int64', length=237)}

# %%
for names, groups in grouped_gender:
    print(names)
    print(groups)
# Out:
# Female
#      Gender Economic Status      Height      Weight        Age        Income
# 0    Female            Rich  159.568122   47.285346  22.356860  19658.786317
# 4    Female    Middle Class  113.903682   88.846191  48.370033  18586.376641
# 5    Female    Middle Class  162.056054  107.957686  12.460485  19063.302050
# 7    Female    Middle Class  145.613222   36.636072  18.981125  19287.481840
# 8    Female    Middle Class  178.193561   40.683697  17.663998  19656.551660
# ..      ...             ...         ...         ...        ...           ...
# 494  Female            Poor   99.139990   58.681779  37.524035  21274.039907
# 495  Female            Poor  144.148242   81.485072  33.283558  18337.441751
# 497  Female            Rich  132.734372   43.226378  47.297293  18676.682626
# 498  Female            Rich  203.104756   50.854155  31.777838  19287.464438
# 499  Female            Poor  164.614472   25.792572  10.080428  18684.716111
#
# [263 rows x 6 columns]
# Male
#     Gender Economic Status      Height      Weight        Age        Income
# 1     Male    Middle Class  176.542427   64.933623  42.790762  18868.449410
# 2     Male            Rich  127.186468   67.250264  32.642043  19646.224771
# 3     Male    Middle Class  152.047987   95.336582  31.071772  20270.470754
# 6     Male    Middle Class  134.549732   78.692999  10.164686  18709.172879
# 9     Male            Rich  134.885479  103.099281  16.986336  18436.291730
# ..     ...             ...         ...         ...        ...           ...
# 487   Male            Poor  194.917518   78.722210  48.232201  21130.368043
# 488   Male            Rich  168.981479   74.803361  35.421646  21423.072551
# 489   Male            Poor  114.600901   64.559429  39.155154  20588.693078
# 491   Male    Middle Class  167.381929   79.404268  28.912538  19515.088372
# 496   Male    Middle Class  172.854270   86.057443  24.508625  18731.855275
#
# [237 rows x 6 columns]

# %%
grouped_gender.get_group("Female")
# Out:
#      Gender Economic Status      Height      Weight        Age        Income
# 0    Female            Rich  159.568122   47.285346  22.356860  19658.786317
# 4    Female    Middle Class  113.903682   88.846191  48.370033  18586.376641
# 5    Female    Middle Class  162.056054  107.957686  12.460485  19063.302050
# 7    Female    Middle Class  145.613222   36.636072  18.981125  19287.481840
# 8    Female    Middle Class  178.193561   40.683697  17.663998  19656.551660
# ..      ...             ...         ...         ...        ...           ...
# 494  Female            Poor   99.139990   58.681779  37.524035  21274.039907
# 495  Female            Poor  144.148242   81.485072  33.283558  18337.441751
# 497  Female            Rich  132.734372   43.226378  47.297293  18676.682626
# 498  Female            Rich  203.104756   50.854155  31.777838  19287.464438
# 499  Female            Poor  164.614472   25.792572  10.080428  18684.716111
#
# [263 rows x 6 columns]

# %%
double_group = data.groupby(["Gender", "Economic Status"])

# %%
len(double_group)
# Out:
# 6

# %%
for names, groups in double_group:
    print(names)
    print(groups)
# Out:
# ('Female', 'Middle Class')
#      Gender Economic Status      Height      Weight        Age        Income
# 4    Female    Middle Class  113.903682   88.846191  48.370033  18586.376641
# 5    Female    Middle Class  162.056054  107.957686  12.460485  19063.302050
# 7    Female    Middle Class  145.613222   36.636072  18.981125  19287.481840
# 8    Female    Middle Class  178.193561   40.683697  17.663998  19656.551660
# 12   Female    Middle Class  175.833685   23.503892  17.771835  18165.096866
# ..      ...             ...         ...         ...        ...           ...
# 451  Female    Middle Class  153.688667   67.819843  33.552288  19023.307360
# 460  Female    Middle Class  150.275135   60.791265  16.408814  18890.310234
# 465  Female    Middle Class  118.829482   45.428735   9.744352  19602.695686
# 468  Female    Middle Class  113.250926   27.857223  22.704098  21302.172044
# 479  Female    Middle Class  162.647079  117.754442  36.863874  19135.183530
#
# [87 rows x 6 columns]
# ('Female', 'Poor')
#      Gender Economic Status      Height      Weight        Age        Income
# 10   Female            Poor  129.314601   77.226056  47.327880  18659.092584
# 17   Female            Poor  128.294818   71.353729  51.522034  18268.959625
# 23   Female            Poor  168.531351  111.891635  29.374953  21438.142077
# 27   Female            Poor  112.703972   79.177705  42.713377  21397.016222
# 33   Female            Poor  119.035432   62.273758  24.377965  20179.239137
# ..      ...             ...         ...         ...        ...           ...
# 485  Female            Poor  154.898898   97.507984  14.591315  18341.454054
# 490  Female            Poor  154.856017   87.054057  23.290177  20328.311504
# 494  Female            Poor   99.139990   58.681779  37.524035  21274.039907
# 495  Female            Poor  144.148242   81.485072  33.283558  18337.441751
# 499  Female            Poor  164.614472   25.792572  10.080428  18684.716111
#
# [85 rows x 6 columns]
# ('Female', 'Rich')
#      Gender Economic Status      Height     Weight        Age        Income
# 0    Female            Rich  159.568122  47.285346  22.356860  19658.786317
# 21   Female            Rich  156.555361  31.236849  32.386126  21477.173831
# 36   Female            Rich  141.143860  69.913613  20.854787  19011.982055
# 38   Female            Rich  133.833494  80.076869  43.647407  20139.435918
# 47   Female            Rich  178.493973  62.682412  38.325947  20104.098966
# ..      ...             ...         ...        ...        ...           ...
# 482  Female            Rich  147.138592  80.445908   9.066252  21051.874854
# 492  Female            Rich  130.769889  93.483458  42.951928  19601.052687
# 493  Female            Rich  142.933849  90.968973  40.297326  19855.717321
# 497  Female            Rich  132.734372  43.226378  47.297293  18676.682626
# 498  Female            Rich  203.104756  50.854155  31.777838  19287.464438
#
# [91 rows x 6 columns]
# ('Male', 'Middle Class')
#     Gender Economic Status      Height      Weight        Age        Income
# 1     Male    Middle Class  176.542427   64.933623  42.790762  18868.449410
# 3     Male    Middle Class  152.047987   95.336582  31.071772  20270.470754
# 6     Male    Middle Class  134.549732   78.692999  10.164686  18709.172879
# 16    Male    Middle Class  161.944794   37.212297  22.204984  21228.387756
# 18    Male    Middle Class  149.452810   96.270692  22.284775  18291.517021
# ..     ...             ...         ...         ...        ...           ...
# 478   Male    Middle Class  211.093357   91.538326  41.940034  19126.123804
# 483   Male    Middle Class   90.045493   90.815908  13.098464  18955.171846
# 484   Male    Middle Class  141.577974  142.391833  35.411630  20477.906202
# 491   Male    Middle Class  167.381929   79.404268  28.912538  19515.088372
# 496   Male    Middle Class  172.854270   86.057443  24.508625  18731.855275
#
# [76 rows x 6 columns]
# ('Male', 'Poor')
#     Gender Economic Status      Height      Weight        Age        Income
# 14    Male            Poor  151.507753   41.703148  35.192170  18528.545410
# 15    Male            Poor  152.110348   80.398473  32.586426  20445.186602
# 22    Male            Poor  169.156897  107.217097  23.617943  21017.730049
# 24    Male            Poor  191.408853   38.415221  30.080205  19654.473100
# 25    Male            Poor  201.528004   64.434478  21.543777  18803.044179
# ..     ...             ...         ...         ...        ...           ...
# 466   Male            Poor  175.821835   65.976838  34.259656  18319.525689
# 471   Male            Poor  190.704169   22.411536  38.930515  21128.141814
# 477   Male            Poor  131.086657   87.139507  24.160214  18647.023835
# 487   Male            Poor  194.917518   78.722210  48.232201  21130.368043
# 489   Male            Poor  114.600901   64.559429  39.155154  20588.693078
#
# [90 rows x 6 columns]
# ('Male', 'Rich')
#     Gender Economic Status      Height      Weight        Age        Income
# 2     Male            Rich  127.186468   67.250264  32.642043  19646.224771
# 9     Male            Rich  134.885479  103.099281  16.986336  18436.291730
# 11    Male            Rich  154.640301   22.419241  21.819654  19845.617665
# 19    Male            Rich  203.789052   65.535214  34.950055  18125.889821
# 20    Male            Rich  159.417503   82.038412  24.954427  21202.263791
# ..     ...             ...         ...         ...        ...           ...
# 472   Male            Rich  175.318588   42.358639  31.493415  18032.961491
# 476   Male            Rich  169.898783   63.068250  36.071519  21018.864739
# 481   Male            Rich  168.489690   25.059853  17.787852  18233.766837
# 486   Male            Rich  163.217912   24.129289  15.477351  20552.258536
# 488   Male            Rich  168.981479   74.803361  35.421646  21423.072551
#
# [71 rows x 6 columns]

# %% [markdown]
# ## Operaciones sobre datos agrupados

# %%
double_group.sum()
# Out:
#                               Height       Weight          Age        Income
# Gender Economic Status
# Female Middle Class     13522.119736  5570.495047  2786.620858  1.710782e+06
#        Poor             13589.904742  5496.807407  2446.311986  1.658301e+06
#        Rich             14194.658689  6188.570951  2647.075583  1.806310e+06
# Male   Middle Class     12570.780742  5147.694874  2347.617187  1.491242e+06
#        Poor             14539.262526  5674.568111  2885.248531  1.799313e+06
#        Rich             11407.264696  4691.510473  2160.902293  1.403781e+06

# %%
double_group.describe()
# Out:
#                        Height                                                 \
#                         count        mean        std         min         25%
# Gender Economic Status
# Female Middle Class      87.0  155.426664  28.320984   86.723656  140.316511
#        Poor              85.0  159.881232  29.471990   98.304209  137.612140
#        Rich              91.0  155.985260  30.640605   92.088204  130.588271
# Male   Middle Class      76.0  165.405010  30.143113   90.045493  142.949563
#        Poor              90.0  161.547361  27.329407  100.591486  144.865019
#        Rich              71.0  160.665700  30.528695   87.757474  142.560744
#
#                                                            Weight             \
#                                50%         75%         max  count       mean
# Gender Economic Status
# Female Middle Class     151.520634  175.585520  213.983068   87.0  64.028679
#        Poor             156.177257  178.245077  239.555000   85.0  64.668322
#        Rich             157.987937  178.677871  246.174617   91.0  68.006274
# Male   Middle Class     168.375982  183.042267  233.352215   76.0  67.732827
#        Poor             161.564013  181.702358  222.604522   90.0  63.050757
#        Rich             161.292549  177.252972  261.621406   71.0  66.077612
#
#                         ...        Age            Income                \
#                         ...        75%        max  count          mean
# Gender Economic Status  ...
# Female Middle Class     ...  41.352703  56.728890   87.0  19664.164011
#        Poor             ...  37.050579  59.267267   85.0  19509.423825
#        Rich             ...  37.298697  57.897763   91.0  19849.559099
# Male   Middle Class     ...  42.039366  55.906127   76.0  19621.603674
#        Poor             ...  38.928002  55.915939   90.0  19992.367199
#        Rich             ...  37.669881  62.961423   71.0  19771.570166
#
#                                                                                \
#                                 std           min           25%           50%
# Gender Economic Status
# Female Middle Class     1021.210307  18014.561962  18812.057287  19494.296702
#        Poor             1076.715052  18020.648713  18644.424673  19204.996957
#        Rich             1013.549495  18074.354236  18980.790448  19825.747705
# Male   Middle Class     1040.590121  18000.294639  18856.637818  19436.082166
#        Poor             1048.930799  18037.513194  19033.870412  20223.906666
#        Rich             1069.625746  18032.961491  18855.467140  19822.160693
#
#
#                                  75%           max
# Gender Economic Status
# Female Middle Class     20593.561144  21463.301909
#        Poor             20497.498650  21486.663020
#        Rich             20705.576969  21477.173831
# Male   Middle Class     20436.193183  21494.173498
#        Poor             20999.161868  21496.133328
#        Rich             20853.786805  21423.072551
#
# [6 rows x 32 columns]

# %%
double_group.mean()
# Out:
#                             Height     Weight        Age        Income
# Gender Economic Status
# Female Middle Class     155.426664  64.028679  32.030125  19664.164011
#        Poor             159.881232  64.668322  28.780141  19509.423825
#        Rich             155.985260  68.006274  29.088743  19849.559099
# Male   Middle Class     165.405010  67.732827  30.889700  19621.603674
#        Poor             161.547361  63.050757  32.058317  19992.367199
#        Rich             160.665700  66.077612  30.435244  19771.570166

# %%
double_group.size()
# Out:
# Gender  Economic Status
# Female  Middle Class       87
#         Poor               85
#         Rich               91
# Male    Middle Class       76
#         Poor               90
#         Rich               71
# dtype: int64

# %%
grouped_income = double_group["Income"]

# %%
grouped_income.describe()
# Out:
#                         count          mean          std           min  \
# Gender Economic Status
# Female Middle Class      87.0  19664.164011  1021.210307  18014.561962
#        Poor              85.0  19509.423825  1076.715052  18020.648713
#        Rich              91.0  19849.559099  1013.549495  18074.354236
# Male   Middle Class      76.0  19621.603674  1040.590121  18000.294639
#        Poor              90.0  19992.367199  1048.930799  18037.513194
#        Rich              71.0  19771.570166  1069.625746  18032.961491
#
#                                  25%           50%           75%           max
# Gender Economic Status
# Female Middle Class     18812.057287  19494.296702  20593.561144  21463.301909
#        Poor             18644.424673  19204.996957  20497.498650  21486.663020
#        Rich             18980.790448  19825.747705  20705.576969  21477.173831
# Male   Middle Class     18856.637818  19436.082166  20436.193183  21494.173498
#        Poor             19033.870412  20223.906666  20999.161868  21496.133328
#        Rich             18855.467140  19822.160693  20853.786805  21423.072551

# %%
double_group.aggregate(
    {
        "Income": np.sum,
        "Age" : np.mean,
        "Height" : np.std
    }
)
# Out:
#                               Income        Age     Height
# Gender Economic Status
# Female Middle Class     1.710782e+06  32.030125  28.320984
#        Poor             1.658301e+06  28.780141  29.471990
#        Rich             1.806310e+06  29.088743  30.640605
# Male   Middle Class     1.491242e+06  30.889700  30.143113
#        Poor             1.799313e+06  32.058317  27.329407
#        Rich             1.403781e+06  30.435244  30.528695

# %%
double_group.aggregate(
    {
        "Age" : np.mean,
        "Height" : lambda h:(np.mean(h))/np.std(h)
    }
)
# Out:
#                               Age    Height
# Gender Economic Status
# Female Middle Class     32.030125  5.519854
#        Poor             28.780141  5.457049
#        Rich             29.088743  5.119006
# Male   Middle Class     30.889700  5.523784
#        Poor             32.058317  5.944234
#        Rich             30.435244  5.300235

# %%
double_group.aggregate([np.sum, np.mean, np.std])
# Out:
#                               Height                              Weight  \
#                                  sum        mean        std          sum
# Gender Economic Status
# Female Middle Class     13522.119736  155.426664  28.320984  5570.495047
#        Poor             13589.904742  159.881232  29.471990  5496.807407
#        Rich             14194.658689  155.985260  30.640605  6188.570951
# Male   Middle Class     12570.780742  165.405010  30.143113  5147.694874
#        Poor             14539.262526  161.547361  27.329407  5674.568111
#        Rich             11407.264696  160.665700  30.528695  4691.510473
#
#                                                       Age             \
#                              mean        std          sum       mean
# Gender Economic Status
# Female Middle Class     64.028679  26.319159  2786.620858  32.030125
#        Poor             64.668322  25.188420  2446.311986  28.780141
#        Rich             68.006274  26.493474  2647.075583  29.088743
# Male   Middle Class     67.732827  26.410425  2347.617187  30.889700
#        Poor             63.050757  25.882580  2885.248531  32.058317
#        Rich             66.077612  26.650499  2160.902293  30.435244
#
#                                          Income
#                               std           sum          mean          std
# Gender Economic Status
# Female Middle Class     12.158857  1.710782e+06  19664.164011  1021.210307
#        Poor             12.360622  1.658301e+06  19509.423825  1076.715052
#        Rich             11.067023  1.806310e+06  19849.559099  1013.549495
# Male   Middle Class     13.585809  1.491242e+06  19621.603674  1040.590121
#        Poor              9.898059  1.799313e+06  19992.367199  1048.930799
#        Rich             11.591892  1.403781e+06  19771.570166  1069.625746

# %%
double_group.aggregate([lambda x: np.mean(x) / np.std(x)])
# Out:
#                           Height    Weight       Age     Income
#                         <lambda>  <lambda>  <lambda>   <lambda>
# Gender Economic Status
# Female Middle Class     5.519854  2.446882  2.649575  19.367372
#        Poor             5.457049  2.582620  2.342192  18.226928
#        Rich             5.119006  2.581128  2.642978  19.692704
# Male   Middle Class     5.523784  2.581666  2.288782  18.981519
#        Poor             5.944234  2.449678  3.256994  19.166536
#        Rich             5.300235  2.497061  2.644251  18.616133

# %% [markdown]
# ### Filtrado de datos

# %%
double_group["Age"].filter(lambda x: x.sum()>2400)
# Out:
# 0      22.356860
# 4      48.370033
# 5      12.460485
# 7      18.981125
# 8      17.663998
#          ...
# 494    37.524035
# 495    33.283558
# 497    47.297293
# 498    31.777838
# 499    10.080428
# Name: Age, Length: 353, dtype: float64

# %% [markdown]
# ### Transformación de variables

# %%
zscore = lambda x : (x - x.mean())/x.std()

# %%
z_group = double_group.transform(zscore)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(z_group["Age"])
# Out:
# (array([  6.,  24.,  62.,  73.,  83., 104.,  93.,  37.,  13.,   5.]),
#  array([-2.64585867, -2.10067857, -1.55549847, -1.01031837, -0.46513827,
#          0.08004183,  0.62522193,  1.17040203,  1.71558213,  2.26076223,
#          2.80594233]),
#  <a list of 10 Patch objects>)

# %%
fill_na_mean = lambda x : x.fillna(x.mean())

# %%
double_group.transform(fill_na_mean)
# Out:
#          Height     Weight        Age        Income
# 0    159.568122  47.285346  22.356860  19658.786317
# 1    176.542427  64.933623  42.790762  18868.449410
# 2    127.186468  67.250264  32.642043  19646.224771
# 3    152.047987  95.336582  31.071772  20270.470754
# 4    113.903682  88.846191  48.370033  18586.376641
# ..          ...        ...        ...           ...
# 495  144.148242  81.485072  33.283558  18337.441751
# 496  172.854270  86.057443  24.508625  18731.855275
# 497  132.734372  43.226378  47.297293  18676.682626
# 498  203.104756  50.854155  31.777838  19287.464438
# 499  164.614472  25.792572  10.080428  18684.716111
#
# [500 rows x 4 columns]

# %% [markdown]
# ## Operaciones diversas muy útiles

# %%
double_group.head(1)
# Out:
#     Gender Economic Status      Height     Weight        Age        Income
# 0   Female            Rich  159.568122  47.285346  22.356860  19658.786317
# 1     Male    Middle Class  176.542427  64.933623  42.790762  18868.449410
# 2     Male            Rich  127.186468  67.250264  32.642043  19646.224771
# 4   Female    Middle Class  113.903682  88.846191  48.370033  18586.376641
# 10  Female            Poor  129.314601  77.226056  47.327880  18659.092584
# 14    Male            Poor  151.507753  41.703148  35.192170  18528.545410

# %%
double_group.nth(32) ## treintaidosavo
# Out:
#                             Height     Weight        Age        Income
# Gender Economic Status
# Female Middle Class     186.373932  75.442795  34.208295  21250.236349
#        Poor             196.227651  38.748094  26.440639  21234.108526
#        Rich             166.239085  22.983869  12.486221  20983.980040
# Male   Middle Class     190.144054  40.807857  17.482794  19255.001765
#        Poor             179.856206  51.459870  22.151866  20373.882328
#        Rich             156.466164  14.421997  43.550360  19837.434099

# %%
double_group.nth(82)
# Out:
#                             Height      Weight        Age        Income
# Gender Economic Status
# Female Middle Class     153.688667   67.819843  33.552288  19023.307360
#        Poor              99.139990   58.681779  37.524035  21274.039907
#        Rich             205.608990   50.651334  26.147375  20667.884637
# Male   Poor             140.433241  102.868039  39.186865  18562.388262

# %%
data_sorted = data.sort_values(["Age", "Income"])

# %%
data_sorted.head(10)
# Out:
#      Gender Economic Status      Height     Weight       Age        Income
# 405    Male    Middle Class  197.978429  71.187229  0.055356  21156.820424
# 175    Male    Middle Class  120.357868  85.340952  1.201799  20604.830332
# 235  Female            Poor  166.345636  29.902176  2.021177  18278.971582
# 57     Male    Middle Class  166.524231  98.525541  2.582542  20291.128941
# 341    Male            Rich  157.549296   3.313366  4.695605  20020.995426
# 370    Male            Poor  135.755064  61.333674  5.869451  21117.531960
# 294  Female            Poor  187.416371  58.052958  6.059105  20512.472017
# 109  Female            Poor  146.029436  65.925689  6.068227  21109.792475
# 309  Female    Middle Class   94.483171  69.375200  7.196051  18753.946676
# 347    Male            Rich  144.823431  40.012989  7.395610  20273.650427

# %%
age_grouped = data_sorted.groupby("Gender")

# %%
age_grouped.head(1)
# Out:
#      Gender Economic Status      Height     Weight       Age        Income
# 405    Male    Middle Class  197.978429  71.187229  0.055356  21156.820424
# 235  Female            Poor  166.345636  29.902176  2.021177  18278.971582

# %% [markdown]
# ### Conjunto de entrenamiento y conjunto de testing

# %%
import pandas as pd

# %%
data = pd.read_csv("./datasets/customer-churn-model/Customer Churn Model.txt")

# %%
len(data)
# Out:
# 3333

# %% [markdown]
# #### Dividir utilizando la distribución normal

# %%
a = np.random.randn(len(data))

# %%
plt.hist(a)
# Out:
# (array([ 13.,  88., 337., 713., 970., 766., 338.,  92.,  14.,   2.]),
#  array([-3.33844246, -2.59517142, -1.85190038, -1.10862934, -0.36535829,
#          0.37791275,  1.12118379,  1.86445484,  2.60772588,  3.35099692,
#          4.09426796]),
#  <a list of 10 Patch objects>)

# %%
check = (a<0.80)

# %%
check
# Out:
# array([ True,  True,  True, ..., False,  True, False])

# %%
training = data[check]
testing = data[~check]

# %%
len(training)
# Out:
# 2621

# %%
len(testing)
# Out:
# 712

# %% [markdown]
# ## Con la libreria sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(data, test_size=0.2)

# %%
len(train)
# Out:
# 2666

# %%
len(test)
# Out:
# 667

# %% [markdown]
# ## Usando una funcion shuffle

# %%
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0       244.7           91         11.01       10.0           3         2.70
# 1       254.4          103         11.45       13.7           3         3.70
# 2       162.6          104          7.32       12.2           5         3.29
# 3       196.9           89          8.86        6.6           7         1.78
# 4       186.9          121          8.41       10.1           3         2.73
#
#    CustServ Calls  Churn?
# 0               1  False.
# 1               1  False.
# 2               0  False.
# 3               2  False.
# 4               3  False.
#
# [5 rows x 21 columns]

# %%
import sklearn

# %%
data = sklearn.utils.shuffle(data)

# %%
data.head()
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 165     DE              92        415  361-9845         no        yes
# 2562    KS             110        510  354-2434         no         no
# 1709    NV              96        408  375-6911         no         no
# 3135    WV             120        510  341-8667         no         no
# 2050    MT             121        408  334-4354         no         no
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# 165              33     243.1         92       41.33  ...         92
# 2562              0     208.0         69       35.36  ...         94
# 1709              0     197.7         68       33.61  ...         53
# 3135              0     192.6        123       32.74  ...        105
# 2050              0     213.2         79       36.24  ...        116
#
#       Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  \
# 165        18.17       228.7          104         10.29       12.1
# 2562        8.08       178.5          129          8.03        8.0
# 1709       21.29       181.2           67          8.15       10.5
# 3135       17.54       283.2           93         12.74       10.8
# 2050       10.26       244.4          102         11.00        7.5
#
#       Intl Calls  Intl Charge  CustServ Calls  Churn?
# 165            2         3.27               2  False.
# 2562          11         2.16               1  False.
# 1709           3         2.84               3  False.
# 3135           3         2.92               1  False.
# 2050           4         2.03               1  False.
#
# [5 rows x 21 columns]

# %%
cut_id = int(0.75 * len(data))
train_data = data[:cut_id]
test_data = data[(cut_id + 1):]

# %%
len(train_data)
# Out:
# 2499

# %%
len(test_data)
# Out:
# 833

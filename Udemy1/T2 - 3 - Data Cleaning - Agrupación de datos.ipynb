# %%
import numpy as np
import pandas as pd

# %%
gender = ["Male", "Female"]
income = ["Poor", "Middle Class", "Rich"]

# %%
gender_data = []
income_data = []

for i in range(0,500):
    gender_data.append(np.random.choice(gender))
    income_data.append(np.random.choice(income))

# %%
gender_data[1:10]
# Out:
# ['Female',
#  'Male',
#  'Male',
#  'Female',
#  'Male',
#  'Female',
#  'Female',
#  'Female',
#  'Male']

# %%
income_data[1:10]
# Out:
# ['Poor',
#  'Poor',
#  'Poor',
#  'Middle Class',
#  'Poor',
#  'Rich',
#  'Poor',
#  'Poor',
#  'Poor']

# %%
n = 500
height = 160 + 30 * np.random.randn(n)
weight = 65 + 25 * np.random.randn(n)
age = 30 + 12 * np.random.randn(n)
income = 18000 + 3500 * np.random.rand(n)

# %%
data = pd.DataFrame(
    {
        "Gender" : gender_data,
        "Economic Status" : income_data,
        "Height" : height,
        "Weight" : weight,
        "Age" : age,
        "Income" : income
    }
)

# %%
data.head()
# Out:
#    Gender Economic Status      Height      Weight        Age        Income
# 0    Male            Poor  110.112317   79.479549  31.527415  21355.914841
# 1  Female            Poor  120.166155   66.794449  32.777609  20059.081163
# 2    Male            Poor  175.533471  133.618794  22.195798  18595.807168
# 3    Male            Poor  105.610164   58.494929  13.903228  18941.725649
# 4  Female    Middle Class  147.615067   90.104973  39.222336  18928.154851

# %% [markdown]
# ## Agrupación de datos

# %%
grouped_gender = data.groupby("Gender")

# %%
grouped_gender.groups
# Out:
# {'Female': Int64Index([  1,   4,   6,   7,   8,  10,  12,  16,  17,  18,
#              ...
#              473, 475, 478, 480, 483, 488, 493, 495, 498, 499],
#             dtype='int64', length=244),
#  'Male': Int64Index([  0,   2,   3,   5,   9,  11,  13,  14,  15,  23,
#              ...
#              485, 486, 487, 489, 490, 491, 492, 494, 496, 497],
#             dtype='int64', length=256)}

# %%
for names, groups in grouped_gender:
    print(names)
    print(groups)
# Out:
# Female
#      Gender Economic Status      Height     Weight        Age        Income
# 1    Female            Poor  120.166155  66.794449  32.777609  20059.081163
# 4    Female    Middle Class  147.615067  90.104973  39.222336  18928.154851
# 6    Female            Rich  168.960249  59.685545  43.056678  19452.563752
# 7    Female            Poor  207.588584  75.156727  15.698054  20748.238083
# 8    Female            Poor  209.949394  72.313220  19.928761  18979.278838
# ..      ...             ...         ...        ...        ...           ...
# 488  Female    Middle Class  112.507630  54.792622  32.998414  18117.385168
# 493  Female    Middle Class  164.209112  57.784178  47.152593  21221.758077
# 495  Female            Rich  136.745307  57.804873  40.461359  20433.908836
# 498  Female            Rich  117.896289  63.672498  35.420035  18266.872318
# 499  Female            Rich  167.393679  94.005584  38.621068  18295.307129
#
# [244 rows x 6 columns]
# Male
#     Gender Economic Status      Height      Weight        Age        Income
# 0     Male            Poor  110.112317   79.479549  31.527415  21355.914841
# 2     Male            Poor  175.533471  133.618794  22.195798  18595.807168
# 3     Male            Poor  105.610164   58.494929  13.903228  18941.725649
# 5     Male            Poor  152.249277   62.169933  19.475937  18511.041919
# 9     Male            Poor  185.748540  101.930577  32.470472  21128.960142
# ..     ...             ...         ...         ...        ...           ...
# 491   Male            Poor  160.651827   61.273406  42.739488  19043.726934
# 492   Male            Rich  149.684724   70.621524  24.603956  20119.206665
# 494   Male            Poor  168.391097   41.044784  26.603970  19985.325500
# 496   Male    Middle Class  192.764851   89.138974  31.896949  19535.878356
# 497   Male            Poor  211.407032   65.638323  20.198812  19944.587307
#
# [256 rows x 6 columns]

# %%
grouped_gender.get_group("Female")
# Out:
#      Gender Economic Status      Height     Weight        Age        Income
# 1    Female            Poor  120.166155  66.794449  32.777609  20059.081163
# 4    Female    Middle Class  147.615067  90.104973  39.222336  18928.154851
# 6    Female            Rich  168.960249  59.685545  43.056678  19452.563752
# 7    Female            Poor  207.588584  75.156727  15.698054  20748.238083
# 8    Female            Poor  209.949394  72.313220  19.928761  18979.278838
# ..      ...             ...         ...        ...        ...           ...
# 488  Female    Middle Class  112.507630  54.792622  32.998414  18117.385168
# 493  Female    Middle Class  164.209112  57.784178  47.152593  21221.758077
# 495  Female            Rich  136.745307  57.804873  40.461359  20433.908836
# 498  Female            Rich  117.896289  63.672498  35.420035  18266.872318
# 499  Female            Rich  167.393679  94.005584  38.621068  18295.307129
#
# [244 rows x 6 columns]

# %%
double_group = data.groupby(["Gender", "Economic Status"])

# %%
len(double_group)
# Out:
# 6

# %%
for names, groups in double_group:
    print(names)
    print(groups)
# Out:
# ('Female', 'Middle Class')
#      Gender Economic Status      Height     Weight        Age        Income
# 4    Female    Middle Class  147.615067  90.104973  39.222336  18928.154851
# 12   Female    Middle Class  202.855653  42.844408  30.298518  18377.828588
# 20   Female    Middle Class  117.247484  83.480546  17.022852  18600.216967
# 21   Female    Middle Class  142.492731  73.618103  29.449397  19597.113504
# 22   Female    Middle Class  144.984067  25.652110  30.333869  18580.605265
# ..      ...             ...         ...        ...        ...           ...
# 475  Female    Middle Class  192.171531  73.513362  51.677149  20486.239907
# 480  Female    Middle Class  170.128579  76.179190  43.712016  20368.776806
# 483  Female    Middle Class  160.204135  45.749324  18.886702  18514.552587
# 488  Female    Middle Class  112.507630  54.792622  32.998414  18117.385168
# 493  Female    Middle Class  164.209112  57.784178  47.152593  21221.758077
#
# [84 rows x 6 columns]
# ('Female', 'Poor')
#      Gender Economic Status      Height      Weight        Age        Income
# 1    Female            Poor  120.166155   66.794449  32.777609  20059.081163
# 7    Female            Poor  207.588584   75.156727  15.698054  20748.238083
# 8    Female            Poor  209.949394   72.313220  19.928761  18979.278838
# 18   Female            Poor  154.834988   66.728733  27.144048  21367.364184
# 31   Female            Poor  120.532364   32.963931  40.039632  20639.934694
# ..      ...             ...         ...         ...        ...           ...
# 447  Female            Poor  166.807326   58.147251  20.958615  20270.644372
# 467  Female            Poor  177.194352   58.332330  14.771187  19326.740138
# 469  Female            Poor  141.456288   54.237229  21.823848  18719.716303
# 470  Female            Poor  110.674984   88.616744  42.759093  18661.584358
# 471  Female            Poor  182.436753  122.835456  20.648156  19138.948103
#
# [91 rows x 6 columns]
# ('Female', 'Rich')
#      Gender Economic Status      Height     Weight        Age        Income
# 6    Female            Rich  168.960249  59.685545  43.056678  19452.563752
# 10   Female            Rich  181.014637  87.190900  36.783420  21405.736037
# 16   Female            Rich  184.159500  62.291167  38.406244  18170.348853
# 17   Female            Rich  148.159150  95.214868  12.936578  19127.788443
# 19   Female            Rich  103.079546  37.072319  46.773310  18213.899499
# ..      ...             ...         ...        ...        ...           ...
# 466  Female            Rich  155.470930  94.838736  31.080985  20853.876236
# 478  Female            Rich   99.294446  54.514490  32.855310  18323.215817
# 495  Female            Rich  136.745307  57.804873  40.461359  20433.908836
# 498  Female            Rich  117.896289  63.672498  35.420035  18266.872318
# 499  Female            Rich  167.393679  94.005584  38.621068  18295.307129
#
# [69 rows x 6 columns]
# ('Male', 'Middle Class')
#     Gender Economic Status      Height     Weight        Age        Income
# 23    Male    Middle Class  199.698340  92.541200  31.725669  19591.303619
# 24    Male    Middle Class  129.591378  92.294287  58.914801  20133.980079
# 29    Male    Middle Class  143.530136  38.014772  31.827185  18536.632187
# 35    Male    Middle Class  171.046341  59.358245  37.812589  19029.517678
# 38    Male    Middle Class  177.267973  52.844182  12.298182  20322.453942
# ..     ...             ...         ...        ...        ...           ...
# 461   Male    Middle Class  153.080059  51.608810  15.421677  18387.729899
# 463   Male    Middle Class  159.878802  55.843174  38.801859  21227.465576
# 477   Male    Middle Class  186.328848  28.327441  45.573616  20352.228469
# 490   Male    Middle Class  186.859770  71.721637  49.925683  20605.706984
# 496   Male    Middle Class  192.764851  89.138974  31.896949  19535.878356
#
# [88 rows x 6 columns]
# ('Male', 'Poor')
#     Gender Economic Status      Height      Weight        Age        Income
# 0     Male            Poor  110.112317   79.479549  31.527415  21355.914841
# 2     Male            Poor  175.533471  133.618794  22.195798  18595.807168
# 3     Male            Poor  105.610164   58.494929  13.903228  18941.725649
# 5     Male            Poor  152.249277   62.169933  19.475937  18511.041919
# 9     Male            Poor  185.748540  101.930577  32.470472  21128.960142
# ..     ...             ...         ...         ...        ...           ...
# 482   Male            Poor  160.512124   68.236248  19.956950  19561.886401
# 484   Male            Poor  164.630594   48.507687  30.635176  19613.332917
# 491   Male            Poor  160.651827   61.273406  42.739488  19043.726934
# 494   Male            Poor  168.391097   41.044784  26.603970  19985.325500
# 497   Male            Poor  211.407032   65.638323  20.198812  19944.587307
#
# [77 rows x 6 columns]
# ('Male', 'Rich')
#     Gender Economic Status      Height     Weight        Age        Income
# 11    Male            Rich  148.091061  56.259674  20.556472  18771.811323
# 14    Male            Rich  141.334455  32.432789  26.076492  19078.844472
# 25    Male            Rich  144.292921  71.193180  24.624189  19904.729651
# 30    Male            Rich  141.621453  60.603378  36.681688  21238.876594
# 33    Male            Rich  182.571061  55.750033  35.453289  19796.587110
# ..     ...             ...         ...        ...        ...           ...
# 485   Male            Rich  167.682933  38.668841  58.182228  18209.534977
# 486   Male            Rich  168.786288  65.302147  45.168018  21415.916868
# 487   Male            Rich  165.274103  44.994673  17.518514  19128.970727
# 489   Male            Rich  185.363480  91.237766  26.275004  18601.750777
# 492   Male            Rich  149.684724  70.621524  24.603956  20119.206665
#
# [91 rows x 6 columns]

# %% [markdown]
# ## Operaciones sobre datos agrupados

# %%
double_group.sum()
# Out:
#                               Height       Weight          Age        Income
# Gender Economic Status
# Female Middle Class     13604.555831  5622.775689  2458.611632  1.642369e+06
#        Poor             14381.232259  5824.347972  2712.369676  1.790865e+06
#        Rich             10686.059073  4714.141017  2004.775893  1.369646e+06
# Male   Middle Class     14177.218794  6020.198643  2717.233761  1.736374e+06
#        Poor             12278.375783  4979.619669  2427.705195  1.509768e+06
#        Rich             14484.327365  5730.567822  2870.875803  1.786214e+06

# %%
double_group.describe()
# Out:
#                        Height                                                \
#                         count        mean        std        min         25%
# Gender Economic Status
# Female Middle Class      84.0  161.958998  27.176188  80.140027  144.548794
#        Poor              91.0  158.035519  32.355814  96.877526  133.019196
#        Rich              69.0  154.870421  35.072255  56.659219  136.745307
# Male   Middle Class      88.0  161.104759  32.190579  94.443327  135.934258
#        Poor              77.0  159.459426  32.386713  89.363883  141.000371
#        Rich              91.0  159.168433  31.215836  80.585695  141.477954
#
#                                                            Weight             \
#                                50%         75%         max  count       mean
# Gender Economic Status
# Female Middle Class     161.467093  177.789650  228.533475   84.0  66.937806
#        Poor             154.834988  182.184195  255.524433   91.0  64.003824
#        Rich             156.137704  181.014637  226.319237   69.0  68.320884
# Male   Middle Class     159.909863  186.612326  226.035005   88.0  68.411348
#        Poor             158.975829  175.533471  253.295752   77.0  64.670385
#        Rich             159.470970  176.009274  229.825105   91.0  62.973273
#
#                         ...        Age            Income                \
#                         ...        75%        max  count          mean
# Gender Economic Status  ...
# Female Middle Class     ...  39.234780  57.704392   84.0  19552.005973
#        Poor             ...  37.308846  61.376875   91.0  19679.830492
#        Rich             ...  38.535696  54.759319   69.0  19849.937383
# Male   Middle Class     ...  37.350549  58.914801   88.0  19731.522346
#        Poor             ...  39.738288  61.069227   77.0  19607.382232
#        Rich             ...  39.276295  59.822661   91.0  19628.728024
#
#                                                                                \
#                                 std           min           25%           50%
# Gender Economic Status
# Female Middle Class     1032.034805  18017.575581  18576.843519  19530.945345
#        Poor              960.280086  18055.339325  18900.492826  19710.913469
#        Rich             1109.096183  18093.441189  18893.453314  19801.152893
# Male   Middle Class     1011.188479  18034.332451  18811.280974  19845.706870
#        Poor              976.763748  18012.773797  18729.915625  19456.380865
#        Rich              935.257152  18030.678249  18904.773512  19510.813543
#
#
#                                  75%           max
# Gender Economic Status
# Female Middle Class     20396.146785  21390.175405
#        Poor             20379.460959  21469.696622
#        Rich             20831.887667  21476.009659
# Male   Middle Class     20507.029804  21462.177212
#        Poor             20441.683234  21466.932182
#        Rich             20301.073243  21451.222483
#
# [6 rows x 32 columns]

# %%
double_group.mean()
# Out:
#                             Height     Weight        Age        Income
# Gender Economic Status
# Female Middle Class     161.958998  66.937806  29.269186  19552.005973
#        Poor             158.035519  64.003824  29.806260  19679.830492
#        Rich             154.870421  68.320884  29.054723  19849.937383
# Male   Middle Class     161.104759  68.411348  30.877656  19731.522346
#        Poor             159.459426  64.670385  31.528639  19607.382232
#        Rich             159.168433  62.973273  31.548086  19628.728024

# %%
double_group.size()
# Out:
# Gender  Economic Status
# Female  Middle Class       84
#         Poor               91
#         Rich               69
# Male    Middle Class       88
#         Poor               77
#         Rich               91
# dtype: int64

# %%
grouped_income = double_group["Income"]

# %%
grouped_income.describe()
# Out:
#                         count          mean          std           min  \
# Gender Economic Status
# Female Middle Class      84.0  19552.005973  1032.034805  18017.575581
#        Poor              91.0  19679.830492   960.280086  18055.339325
#        Rich              69.0  19849.937383  1109.096183  18093.441189
# Male   Middle Class      88.0  19731.522346  1011.188479  18034.332451
#        Poor              77.0  19607.382232   976.763748  18012.773797
#        Rich              91.0  19628.728024   935.257152  18030.678249
#
#                                  25%           50%           75%           max
# Gender Economic Status
# Female Middle Class     18576.843519  19530.945345  20396.146785  21390.175405
#        Poor             18900.492826  19710.913469  20379.460959  21469.696622
#        Rich             18893.453314  19801.152893  20831.887667  21476.009659
# Male   Middle Class     18811.280974  19845.706870  20507.029804  21462.177212
#        Poor             18729.915625  19456.380865  20441.683234  21466.932182
#        Rich             18904.773512  19510.813543  20301.073243  21451.222483

# %%
double_group.aggregate(
    {
        "Income": np.sum,
        "Age" : np.mean,
        "Height" : np.std
    }
)
# Out:
#                               Income        Age     Height
# Gender Economic Status
# Female Middle Class     1.642369e+06  29.269186  27.176188
#        Poor             1.790865e+06  29.806260  32.355814
#        Rich             1.369646e+06  29.054723  35.072255
# Male   Middle Class     1.736374e+06  30.877656  32.190579
#        Poor             1.509768e+06  31.528639  32.386713
#        Rich             1.786214e+06  31.548086  31.215836

# %%
double_group.aggregate(
    {
        "Age" : np.mean,
        "Height" : lambda h:(np.mean(h))/np.std(h)
    }
)
# Out:
#                               Age    Height
# Gender Economic Status
# Female Middle Class     29.269186  5.995386
#        Poor             29.806260  4.911361
#        Rich             29.054723  4.448103
# Male   Middle Class     30.877656  5.033398
#        Poor             31.528639  4.955893
#        Rich             31.548086  5.127214

# %%
double_group.aggregate([np.sum, np.mean, np.std])
# Out:
#                               Height                              Weight  \
#                                  sum        mean        std          sum
# Gender Economic Status
# Female Middle Class     13604.555831  161.958998  27.176188  5622.775689
#        Poor             14381.232259  158.035519  32.355814  5824.347972
#        Rich             10686.059073  154.870421  35.072255  4714.141017
# Male   Middle Class     14177.218794  161.104759  32.190579  6020.198643
#        Poor             12278.375783  159.459426  32.386713  4979.619669
#        Rich             14484.327365  159.168433  31.215836  5730.567822
#
#                                                       Age             \
#                              mean        std          sum       mean
# Gender Economic Status
# Female Middle Class     66.937806  23.605290  2458.611632  29.269186
#        Poor             64.003824  23.440682  2712.369676  29.806260
#        Rich             68.320884  22.902492  2004.775893  29.054723
# Male   Middle Class     68.411348  24.805276  2717.233761  30.877656
#        Poor             64.670385  24.928733  2427.705195  31.528639
#        Rich             62.973273  24.808324  2870.875803  31.548086
#
#                                          Income
#                               std           sum          mean          std
# Gender Economic Status
# Female Middle Class     12.944224  1.642369e+06  19552.005973  1032.034805
#        Poor             12.094932  1.790865e+06  19679.830492   960.280086
#        Rich             11.646159  1.369646e+06  19849.937383  1109.096183
# Male   Middle Class     11.638071  1.736374e+06  19731.522346  1011.188479
#        Poor             11.803979  1.509768e+06  19607.382232   976.763748
#        Rich             12.666502  1.786214e+06  19628.728024   935.257152

# %%
double_group.aggregate([lambda x: np.mean(x) / np.std(x)])
# Out:
#                           Height    Weight       Age     Income
#                         <lambda>  <lambda>  <lambda>   <lambda>
# Gender Economic Status
# Female Middle Class     5.995386  2.852744  2.274758  19.058889
#        Poor             4.911361  2.745586  2.478013  20.607384
#        Rich             4.448103  3.004975  2.513067  18.028518
# Male   Middle Class     5.033398  2.773740  2.668364  19.625024
#        Poor             4.955893  2.611222  2.688533  20.205456
#        Rich             5.127214  2.552456  2.504470  21.103795

# %% [markdown]
# ### Filtrado de datos

# %%
double_group["Age"].filter(lambda x: x.sum()>2400)
# Out:
# 0      31.527415
# 1      32.777609
# 2      22.195798
# 3      13.903228
# 4      39.222336
#          ...
# 492    24.603956
# 493    47.152593
# 494    26.603970
# 496    31.896949
# 497    20.198812
# Name: Age, Length: 431, dtype: float64

# %% [markdown]
# ### Transformación de variables

# %%
zscore = lambda x : (x - x.mean())/x.std()

# %%
z_group = double_group.transform(zscore)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(z_group["Age"])
# Out:
# (array([ 4., 18., 52., 92., 96., 91., 67., 44., 23., 13.]),
#  array([-2.5911413 , -2.07100366, -1.55086603, -1.03072839, -0.51059075,
#          0.00954688,  0.52968452,  1.04982216,  1.5699598 ,  2.09009743,
#          2.61023507]),
#  <a list of 10 Patch objects>)

# %%
fill_na_mean = lambda x : x.fillna(x.mean())

# %%
double_group.transform(fill_na_mean)
# Out:
#          Height      Weight        Age        Income
# 0    110.112317   79.479549  31.527415  21355.914841
# 1    120.166155   66.794449  32.777609  20059.081163
# 2    175.533471  133.618794  22.195798  18595.807168
# 3    105.610164   58.494929  13.903228  18941.725649
# 4    147.615067   90.104973  39.222336  18928.154851
# ..          ...         ...        ...           ...
# 495  136.745307   57.804873  40.461359  20433.908836
# 496  192.764851   89.138974  31.896949  19535.878356
# 497  211.407032   65.638323  20.198812  19944.587307
# 498  117.896289   63.672498  35.420035  18266.872318
# 499  167.393679   94.005584  38.621068  18295.307129
#
# [500 rows x 4 columns]

# %% [markdown]
# ## Operaciones diversas muy útiles

# %%
double_group.head(1)
# Out:
#     Gender Economic Status      Height     Weight        Age        Income
# 0     Male            Poor  110.112317  79.479549  31.527415  21355.914841
# 1   Female            Poor  120.166155  66.794449  32.777609  20059.081163
# 4   Female    Middle Class  147.615067  90.104973  39.222336  18928.154851
# 6   Female            Rich  168.960249  59.685545  43.056678  19452.563752
# 11    Male            Rich  148.091061  56.259674  20.556472  18771.811323
# 23    Male    Middle Class  199.698340  92.541200  31.725669  19591.303619

# %%
double_group.nth(32) ## treintaidosavo
# Out:
#                             Height      Weight        Age        Income
# Gender Economic Status
# Female Middle Class     163.333082   68.086994  25.919302  20956.112118
#        Poor             201.052638   64.352460  18.002779  19186.198695
#        Rich             160.367218   89.231882  44.637729  18493.537500
# Male   Middle Class     138.557174   91.991969  25.475771  20174.206589
#        Poor             153.843105   46.592677  46.960188  18853.353602
#        Rich             127.905981  102.483507  27.079119  21245.811374

# %%
double_group.nth(82)
# Out:
#                             Height     Weight        Age        Income
# Gender Economic Status
# Female Middle Class     112.507630  54.792622  32.998414  18117.385168
#        Poor             133.766386  -2.034642  40.677680  20595.883012
# Male   Middle Class     213.475403  76.352945  15.568698  19831.505328
#        Rich             176.031707  60.139357  43.820277  18897.643946

# %%
data_sorted = data.sort_values(["Age", "Income"])

# %%
data_sorted.head(10)
# Out:
#      Gender Economic Status      Height     Weight       Age        Income
# 160  Female    Middle Class  143.334830  42.698334 -3.823574  20752.418096
# 165  Female            Rich  162.804568  84.914935 -1.122120  19801.152893
# 377  Female            Poor  207.735920  50.068549  0.363697  20439.277527
# 32   Female    Middle Class  202.388691  57.635965  4.144664  19100.906574
# 441  Female            Poor  174.619032  31.039269  5.587974  19977.917302
# 120    Male    Middle Class  143.780437  75.736548  5.679774  20263.151646
# 350    Male            Rich  155.529296  73.628403  6.556211  19379.218948
# 365    Male            Rich  194.547797  69.937128  7.060359  18813.118548
# 372  Female            Poor  132.676935  74.475189  7.307339  19855.812371
# 102  Female            Poor  160.368351  80.683064  7.824208  21203.519151

# %%
age_grouped = data_sorted.groupby("Gender")

# %%
age_grouped.head(1)
# Out:
#      Gender Economic Status      Height     Weight       Age        Income
# 160  Female    Middle Class  143.334830  42.698334 -3.823574  20752.418096
# 120    Male    Middle Class  143.780437  75.736548  5.679774  20263.151646

# %% [markdown]
# ### Conjunto de entrenamiento y conjunto de testing

# %%
import pandas as pd

# %%
data = pd.read_csv("./datasets/customer-churn-model/Customer Churn Model.txt")

# %%
len(data)
# Out:
# 3333

# %% [markdown]
# #### Dividir utilizando la distribución normal

# %%
a = np.random.randn(len(data))

# %%
plt.hist(a)
# Out:
# (array([ 11.,  59., 203., 575., 840., 855., 530., 194.,  57.,   9.]),
#  array([-3.49153126, -2.79837652, -2.10522177, -1.41206703, -0.71891228,
#         -0.02575754,  0.6673972 ,  1.36055195,  2.05370669,  2.74686144,
#          3.44001618]),
#  <a list of 10 Patch objects>)

# %%
check = (a<0.80)

# %%
check
# Out:
# array([ True,  True,  True, ...,  True,  True, False])

# %%
training = data[check]
testing = data[~check]

# %%
len(training)
# Out:
# 2659

# %%
len(testing)
# Out:
# 674

# %% [markdown]
# ## Con la libreria sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(data, test_size=0.2)

# %%
len(train)
# Out:
# 2666

# %%
len(test)
# Out:
# 667

# %% [markdown]
# ## Usando una funcion shuffle

# %%
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0       244.7           91         11.01       10.0           3         2.70
# 1       254.4          103         11.45       13.7           3         3.70
# 2       162.6          104          7.32       12.2           5         3.29
# 3       196.9           89          8.86        6.6           7         1.78
# 4       186.9          121          8.41       10.1           3         2.73
#
#    CustServ Calls  Churn?
# 0               1  False.
# 1               1  False.
# 2               0  False.
# 3               2  False.
# 4               3  False.
#
# [5 rows x 21 columns]

# %%
import sklearn

# %%
data = sklearn.utils.shuffle(data)

# %%
data.head()
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 165     DE              92        415  361-9845         no        yes
# 2562    KS             110        510  354-2434         no         no
# 1709    NV              96        408  375-6911         no         no
# 3135    WV             120        510  341-8667         no         no
# 2050    MT             121        408  334-4354         no         no
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# 165              33     243.1         92       41.33  ...         92
# 2562              0     208.0         69       35.36  ...         94
# 1709              0     197.7         68       33.61  ...         53
# 3135              0     192.6        123       32.74  ...        105
# 2050              0     213.2         79       36.24  ...        116
#
#       Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  \
# 165        18.17       228.7          104         10.29       12.1
# 2562        8.08       178.5          129          8.03        8.0
# 1709       21.29       181.2           67          8.15       10.5
# 3135       17.54       283.2           93         12.74       10.8
# 2050       10.26       244.4          102         11.00        7.5
#
#       Intl Calls  Intl Charge  CustServ Calls  Churn?
# 165            2         3.27               2  False.
# 2562          11         2.16               1  False.
# 1709           3         2.84               3  False.
# 3135           3         2.92               1  False.
# 2050           4         2.03               1  False.
#
# [5 rows x 21 columns]

# %%
cut_id = int(0.75 * len(data))
train_data = data[:cut_id]
test_data = data[(cut_id + 1):]

# %%
len(train_data)
# Out:
# 2499

# %%
len(test_data)
# Out:
# 833

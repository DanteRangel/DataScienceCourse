# %%
import numpy as np
import pandas as pd

# %%
gender = ["Male", "Female"]
income = ["Poor", "Middle Class", "Rich"]

# %%
gender_data = []
income_data = []

for i in range(0,500):
    gender_data.append(np.random.choice(gender))
    income_data.append(np.random.choice(income))

# %%
gender_data[1:10]
# Out:
# ['Female',
#  'Male',
#  'Female',
#  'Male',
#  'Male',
#  'Male',
#  'Female',
#  'Female',
#  'Female']

# %%
income_data[1:10]
# Out:
# ['Rich',
#  'Middle Class',
#  'Middle Class',
#  'Poor',
#  'Poor',
#  'Rich',
#  'Poor',
#  'Rich',
#  'Rich']

# %%
n = 500
height = 160 + 30 * np.random.randn(n)
weight = 65 + 25 * np.random.randn(n)
age = 30 + 12 * np.random.randn(n)
income = 18000 + 3500 * np.random.rand(n)

# %%
data = pd.DataFrame(
    {
        "Gender" : gender_data,
        "Economic Status" : income_data,
        "Height" : height,
        "Weight" : weight,
        "Age" : age,
        "Income" : income
    }
)

# %%
data.head()
# Out:
#    Gender Economic Status      Height     Weight        Age        Income
# 0    Male    Middle Class  118.639959  33.083603  27.763501  19097.542724
# 1  Female            Rich  100.965576  92.829558  39.016762  20619.454454
# 2    Male    Middle Class  136.001566  46.839499  17.830811  21441.073269
# 3  Female    Middle Class  169.153780  84.821063  34.580010  18407.008429
# 4    Male            Poor  200.538071  58.198494  33.037069  21356.613741

# %% [markdown]
# ## Agrupación de datos

# %%
grouped_gender = data.groupby("Gender")

# %%
grouped_gender.groups
# Out:
# {'Female': Int64Index([  1,   3,   7,   8,   9,  12,  13,  14,  15,  16,
#              ...
#              465, 468, 475, 479, 482, 483, 486, 488, 491, 496],
#             dtype='int64', length=239),
#  'Male': Int64Index([  0,   2,   4,   5,   6,  10,  11,  18,  23,  24,
#              ...
#              487, 489, 490, 492, 493, 494, 495, 497, 498, 499],
#             dtype='int64', length=261)}

# %%
for names, groups in grouped_gender:
    print(names)
    print(groups)
# Out:
# Female
#      Gender Economic Status      Height     Weight        Age        Income
# 1    Female            Rich  100.965576  92.829558  39.016762  20619.454454
# 3    Female    Middle Class  169.153780  84.821063  34.580010  18407.008429
# 7    Female            Poor  170.812839  95.043379  23.841889  20303.345189
# 8    Female            Rich  169.242147  74.964065  28.425763  19414.815111
# 9    Female            Rich  149.547522  57.442473  19.182548  20550.954406
# ..      ...             ...         ...        ...        ...           ...
# 483  Female    Middle Class  133.432696  54.520812  23.473071  18817.484390
# 486  Female            Poor  174.085503  48.919414  20.337573  19394.015737
# 488  Female            Rich  132.177601  96.364125  32.822395  19930.223954
# 491  Female    Middle Class  155.053158  56.055138  28.393015  19489.871336
# 496  Female            Poor  200.925955  83.707563  51.753104  20484.660588
#
# [239 rows x 6 columns]
# Male
#     Gender Economic Status      Height     Weight        Age        Income
# 0     Male    Middle Class  118.639959  33.083603  27.763501  19097.542724
# 2     Male    Middle Class  136.001566  46.839499  17.830811  21441.073269
# 4     Male            Poor  200.538071  58.198494  33.037069  21356.613741
# 5     Male            Poor  156.675367  42.992072  25.437508  18256.139626
# 6     Male            Rich   75.437014  48.949403  50.704941  19392.653938
# ..     ...             ...         ...        ...        ...           ...
# 494   Male            Poor  168.788178  41.982094  48.269750  18447.812867
# 495   Male            Rich  139.303939  28.692048  22.788310  19123.186337
# 497   Male            Poor  160.398240  73.358791  43.467252  21305.649576
# 498   Male            Poor  150.542980  89.121007  37.639512  19739.242741
# 499   Male    Middle Class  134.342716  52.349067  37.172269  19463.214001
#
# [261 rows x 6 columns]

# %%
grouped_gender.get_group("Female")
# Out:
#      Gender Economic Status      Height     Weight        Age        Income
# 1    Female            Rich  100.965576  92.829558  39.016762  20619.454454
# 3    Female    Middle Class  169.153780  84.821063  34.580010  18407.008429
# 7    Female            Poor  170.812839  95.043379  23.841889  20303.345189
# 8    Female            Rich  169.242147  74.964065  28.425763  19414.815111
# 9    Female            Rich  149.547522  57.442473  19.182548  20550.954406
# ..      ...             ...         ...        ...        ...           ...
# 483  Female    Middle Class  133.432696  54.520812  23.473071  18817.484390
# 486  Female            Poor  174.085503  48.919414  20.337573  19394.015737
# 488  Female            Rich  132.177601  96.364125  32.822395  19930.223954
# 491  Female    Middle Class  155.053158  56.055138  28.393015  19489.871336
# 496  Female            Poor  200.925955  83.707563  51.753104  20484.660588
#
# [239 rows x 6 columns]

# %%
double_group = data.groupby(["Gender", "Economic Status"])

# %%
len(double_group)
# Out:
# 6

# %%
for names, groups in double_group:
    print(names)
    print(groups)
# Out:
# ('Female', 'Middle Class')
#      Gender Economic Status      Height      Weight        Age        Income
# 3    Female    Middle Class  169.153780   84.821063  34.580010  18407.008429
# 13   Female    Middle Class  167.146223   34.042583  33.285895  18738.517751
# 15   Female    Middle Class  255.186833  122.509658  21.934391  18908.581112
# 17   Female    Middle Class  168.964960   38.574666  17.468033  20394.178514
# 19   Female    Middle Class  160.056863   42.438522  40.154190  18018.669092
# ..      ...             ...         ...         ...        ...           ...
# 463  Female    Middle Class  182.274236   61.866329  19.977512  20661.385196
# 465  Female    Middle Class  207.908714   60.809575  33.940553  20797.598009
# 468  Female    Middle Class  175.693238   87.045530  39.556105  20913.847860
# 483  Female    Middle Class  133.432696   54.520812  23.473071  18817.484390
# 491  Female    Middle Class  155.053158   56.055138  28.393015  19489.871336
#
# [86 rows x 6 columns]
# ('Female', 'Poor')
#      Gender Economic Status      Height      Weight        Age        Income
# 7    Female            Poor  170.812839   95.043379  23.841889  20303.345189
# 12   Female            Poor  142.498201   76.304373  34.502260  21008.903896
# 14   Female            Poor  161.862587   78.584872  21.563122  18297.959850
# 21   Female            Poor  184.119992   78.871203  44.773099  21247.556925
# 22   Female            Poor  115.390864  101.413935  39.948095  19513.771176
# ..      ...             ...         ...         ...        ...           ...
# 429  Female            Poor  180.193187   35.952403  27.315845  20439.026781
# 444  Female            Poor  107.409476   42.701485  17.777294  18935.653892
# 450  Female            Poor  206.393569   32.002518  -7.476861  18434.240630
# 486  Female            Poor  174.085503   48.919414  20.337573  19394.015737
# 496  Female            Poor  200.925955   83.707563  51.753104  20484.660588
#
# [72 rows x 6 columns]
# ('Female', 'Rich')
#      Gender Economic Status      Height     Weight        Age        Income
# 1    Female            Rich  100.965576  92.829558  39.016762  20619.454454
# 8    Female            Rich  169.242147  74.964065  28.425763  19414.815111
# 9    Female            Rich  149.547522  57.442473  19.182548  20550.954406
# 16   Female            Rich  154.990619  32.170671  64.784709  18855.057423
# 33   Female            Rich  187.550905  60.749815  12.119875  21122.750584
# ..      ...             ...         ...        ...        ...           ...
# 464  Female            Rich  142.128989  62.026109  25.650601  21386.849367
# 475  Female            Rich  200.085483  56.199545  51.973801  18783.019969
# 479  Female            Rich  113.860240  52.674313   7.129219  18875.307273
# 482  Female            Rich  221.275717  75.796015  41.026330  20225.915061
# 488  Female            Rich  132.177601  96.364125  32.822395  19930.223954
#
# [81 rows x 6 columns]
# ('Male', 'Middle Class')
#     Gender Economic Status      Height      Weight        Age        Income
# 0     Male    Middle Class  118.639959   33.083603  27.763501  19097.542724
# 2     Male    Middle Class  136.001566   46.839499  17.830811  21441.073269
# 24    Male    Middle Class  144.674757   66.587389  19.754593  21270.547132
# 29    Male    Middle Class  143.420389   63.289134  36.970383  18660.860189
# 46    Male    Middle Class  169.089918   58.155778  16.315310  21399.785474
# ..     ...             ...         ...         ...        ...           ...
# 481   Male    Middle Class  133.511469   45.150293  26.533270  18954.334193
# 484   Male    Middle Class  133.241310   76.369682  31.578957  20898.153195
# 485   Male    Middle Class  164.877613  117.769573  33.254197  19659.894906
# 493   Male    Middle Class  154.885217   85.670038  43.996361  18490.562157
# 499   Male    Middle Class  134.342716   52.349067  37.172269  19463.214001
#
# [88 rows x 6 columns]
# ('Male', 'Poor')
#     Gender Economic Status      Height      Weight        Age        Income
# 4     Male            Poor  200.538071   58.198494  33.037069  21356.613741
# 5     Male            Poor  156.675367   42.992072  25.437508  18256.139626
# 23    Male            Poor  174.529030   24.927023  34.318026  21271.463796
# 32    Male            Poor  215.771293  103.949901  29.529780  21221.084583
# 40    Male            Poor  201.432906   57.733057  34.707273  19672.437375
# ..     ...             ...         ...         ...        ...           ...
# 489   Male            Poor  181.371194   71.431232  24.038537  18576.928576
# 492   Male            Poor  203.082094   62.176407  30.013188  19920.107691
# 494   Male            Poor  168.788178   41.982094  48.269750  18447.812867
# 497   Male            Poor  160.398240   73.358791  43.467252  21305.649576
# 498   Male            Poor  150.542980   89.121007  37.639512  19739.242741
#
# [86 rows x 6 columns]
# ('Male', 'Rich')
#     Gender Economic Status      Height      Weight        Age        Income
# 6     Male            Rich   75.437014   48.949403  50.704941  19392.653938
# 10    Male            Rich  135.205022   42.575443  48.419585  21086.617892
# 11    Male            Rich  157.866443  122.347613  32.271928  18993.765881
# 18    Male            Rich  135.539358   31.314168  48.402369  19116.408672
# 25    Male            Rich  129.700572   69.179945  30.218122  20701.188668
# ..     ...             ...         ...         ...        ...           ...
# 474   Male            Rich  151.412290   67.081534  30.681408  20802.033485
# 478   Male            Rich  148.891431   49.356333  47.115192  20349.555255
# 487   Male            Rich  130.667685   62.113423  51.415287  20571.604105
# 490   Male            Rich  179.873083   68.093246  11.754747  19067.173037
# 495   Male            Rich  139.303939   28.692048  22.788310  19123.186337
#
# [87 rows x 6 columns]

# %% [markdown]
# ## Operaciones sobre datos agrupados

# %%
double_group.sum()
# Out:
#                               Height       Weight          Age        Income
# Gender Economic Status
# Female Middle Class     13763.196778  5764.648693  2643.506311  1.703821e+06
#        Poor             11492.003233  4479.272913  2100.975002  1.414089e+06
#        Rich             13183.576331  4979.608278  2580.777802  1.598424e+06
# Male   Middle Class     13884.364261  6121.185571  2670.367848  1.744332e+06
#        Poor             14360.429254  5597.222247  2643.639878  1.708525e+06
#        Rich             13909.541409  5774.191678  2597.609863  1.709784e+06

# %%
double_group.describe()
# Out:
#                        Height                                                 \
#                         count        mean        std         min         25%
# Gender Economic Status
# Female Middle Class      86.0  160.037172  31.218705   76.144091  137.365833
#        Poor              72.0  159.611156  27.712242  106.104662  140.644856
#        Rich              81.0  162.760202  30.657658   91.750329  143.527425
# Male   Middle Class      88.0  157.776867  28.617625   94.058910  137.594743
#        Poor              86.0  166.981736  32.965864   54.308621  152.028753
#        Rich              87.0  159.879786  30.775010   75.437014  135.742494
#
#                                                            Weight             \
#                                50%         75%         max  count       mean
# Gender Economic Status
# Female Middle Class     161.519839  173.656060  255.186833   86.0  67.030799
#        Poor             159.195137  178.333475  244.260044   72.0  62.212124
#        Rich             159.219068  185.430621  244.428031   81.0  61.476645
# Male   Middle Class     155.160668  174.476597  238.648201   88.0  69.558927
#        Poor             167.071307  189.174038  246.771190   86.0  65.083980
#        Rich             152.595413  189.260640  234.345952   87.0  66.370019
#
#                         ...        Age            Income                \
#                         ...        75%        max  count          mean
# Gender Economic Status  ...
# Female Middle Class     ...  37.846565  62.184033   86.0  19811.873489
#        Poor             ...  35.020174  55.312201   72.0  19640.125029
#        Rich             ...  40.724312  64.784709   81.0  19733.633119
# Male   Middle Class     ...  37.116127  59.430877   88.0  19821.953699
#        Poor             ...  38.195185  56.993248   86.0  19866.565740
#        Rich             ...  37.623480  51.415287   87.0  19652.691031
#
#                                                                                \
#                                 std           min           25%           50%
# Gender Economic Status
# Female Middle Class     1060.884218  18018.669092  18854.096810  19983.199597
#        Poor              919.814687  18048.896629  18895.828944  19547.898548
#        Rich              945.953290  18017.640861  18975.147092  19641.856721
# Male   Middle Class     1046.275886  18015.310743  18869.176772  19907.186971
#        Poor             1108.464232  18042.501472  18752.706837  19958.729429
#        Rich             1011.359880  18022.117563  18886.542384  19529.406386
#
#
#                                  75%           max
# Gender Economic Status
# Female Middle Class     20800.284693  21414.012523
#        Poor             20389.300851  21474.695544
#        Rich             20593.321358  21386.849367
# Male   Middle Class     20726.751751  21445.916415
#        Poor             20961.780636  21443.880719
#        Rich             20441.196489  21495.956870
#
# [6 rows x 32 columns]

# %%
double_group.mean()
# Out:
#                             Height     Weight        Age        Income
# Gender Economic Status
# Female Middle Class     160.037172  67.030799  30.738445  19811.873489
#        Poor             159.611156  62.212124  29.180208  19640.125029
#        Rich             162.760202  61.476645  31.861454  19733.633119
# Male   Middle Class     157.776867  69.558927  30.345089  19821.953699
#        Poor             166.981736  65.083980  30.739999  19866.565740
#        Rich             159.879786  66.370019  29.857585  19652.691031

# %%
double_group.size()
# Out:
# Gender  Economic Status
# Female  Middle Class       86
#         Poor               72
#         Rich               81
# Male    Middle Class       88
#         Poor               86
#         Rich               87
# dtype: int64

# %%
grouped_income = double_group["Income"]

# %%
grouped_income.describe()
# Out:
#                         count          mean          std           min  \
# Gender Economic Status
# Female Middle Class      86.0  19811.873489  1060.884218  18018.669092
#        Poor              72.0  19640.125029   919.814687  18048.896629
#        Rich              81.0  19733.633119   945.953290  18017.640861
# Male   Middle Class      88.0  19821.953699  1046.275886  18015.310743
#        Poor              86.0  19866.565740  1108.464232  18042.501472
#        Rich              87.0  19652.691031  1011.359880  18022.117563
#
#                                  25%           50%           75%           max
# Gender Economic Status
# Female Middle Class     18854.096810  19983.199597  20800.284693  21414.012523
#        Poor             18895.828944  19547.898548  20389.300851  21474.695544
#        Rich             18975.147092  19641.856721  20593.321358  21386.849367
# Male   Middle Class     18869.176772  19907.186971  20726.751751  21445.916415
#        Poor             18752.706837  19958.729429  20961.780636  21443.880719
#        Rich             18886.542384  19529.406386  20441.196489  21495.956870

# %%
double_group.aggregate(
    {
        "Income": np.sum,
        "Age" : np.mean,
        "Height" : np.std
    }
)
# Out:
#                               Income        Age     Height
# Gender Economic Status
# Female Middle Class     1.703821e+06  30.738445  31.218705
#        Poor             1.414089e+06  29.180208  27.712242
#        Rich             1.598424e+06  31.861454  30.657658
# Male   Middle Class     1.744332e+06  30.345089  28.617625
#        Poor             1.708525e+06  30.739999  32.965864
#        Rich             1.709784e+06  29.857585  30.775010

# %%
double_group.aggregate(
    {
        "Age" : np.mean,
        "Height" : lambda h:(np.mean(h))/np.std(h)
    }
)
# Out:
#                               Age    Height
# Gender Economic Status
# Female Middle Class     30.738445  5.156390
#        Poor             29.180208  5.800009
#        Rich             31.861454  5.342035
# Male   Middle Class     30.345089  5.544871
#        Poor             30.739999  5.095001
#        Rich             29.857585  5.225234

# %%
double_group.aggregate([np.sum, np.mean, np.std])
# Out:
#                               Height                              Weight  \
#                                  sum        mean        std          sum
# Gender Economic Status
# Female Middle Class     13763.196778  160.037172  31.218705  5764.648693
#        Poor             11492.003233  159.611156  27.712242  4479.272913
#        Rich             13183.576331  162.760202  30.657658  4979.608278
# Male   Middle Class     13884.364261  157.776867  28.617625  6121.185571
#        Poor             14360.429254  166.981736  32.965864  5597.222247
#        Rich             13909.541409  159.879786  30.775010  5774.191678
#
#                                                       Age             \
#                              mean        std          sum       mean
# Gender Economic Status
# Female Middle Class     67.030799  26.932985  2643.506311  30.738445
#        Poor             62.212124  24.581232  2100.975002  29.180208
#        Rich             61.476645  25.784960  2580.777802  31.861454
# Male   Middle Class     69.558927  24.266837  2670.367848  30.345089
#        Poor             65.083980  25.312961  2643.639878  30.739999
#        Rich             66.370019  23.090991  2597.609863  29.857585
#
#                                          Income
#                               std           sum          mean          std
# Gender Economic Status
# Female Middle Class     11.698003  1.703821e+06  19811.873489  1060.884218
#        Poor             11.090465  1.414089e+06  19640.125029   919.814687
#        Rich             11.935004  1.598424e+06  19733.633119   945.953290
# Male   Middle Class     12.626513  1.744332e+06  19821.953699  1046.275886
#        Poor             10.542123  1.708525e+06  19866.565740  1108.464232
#        Rich             11.386856  1.709784e+06  19652.691031  1011.359880

# %%
double_group.aggregate([lambda x: np.mean(x) / np.std(x)])
# Out:
#                           Height    Weight       Age     Income
#                         <lambda>  <lambda>  <lambda>   <lambda>
# Gender Economic Status
# Female Middle Class     5.156390  2.503397  2.643078  18.784400
#        Poor             5.800009  2.548640  2.649572  21.502105
#        Rich             5.342035  2.399061  2.686214  20.991084
# Male   Middle Class     5.544871  2.882846  2.417056  19.053815
#        Poor             5.095001  2.586252  2.933023  18.027723
#        Rich             5.225234  2.890945  2.637310  19.544596

# %% [markdown]
# ### Filtrado de datos

# %%
double_group["Age"].filter(lambda x: x.sum()>2400)
# Out:
# 0      27.763501
# 1      39.016762
# 2      17.830811
# 3      34.580010
# 4      33.037069
#          ...
# 494    48.269750
# 495    22.788310
# 497    43.467252
# 498    37.639512
# 499    37.172269
# Name: Age, Length: 428, dtype: float64

# %% [markdown]
# ### Transformación de variables

# %%
zscore = lambda x : (x - x.mean())/x.std()

# %%
z_group = double_group.transform(zscore)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(z_group["Age"])
# Out:
# (array([  3.,   4.,  24.,  62., 105., 123.,  96.,  49.,  23.,  11.]),
#  array([-3.30527791, -2.69889554, -2.09251318, -1.48613082, -0.87974846,
#         -0.2733661 ,  0.33301627,  0.93939863,  1.54578099,  2.15216335,
#          2.75854572]),
#  <a list of 10 Patch objects>)

# %%
fill_na_mean = lambda x : x.fillna(x.mean())

# %%
double_group.transform(fill_na_mean)
# Out:
#          Height     Weight        Age        Income
# 0    118.639959  33.083603  27.763501  19097.542724
# 1    100.965576  92.829558  39.016762  20619.454454
# 2    136.001566  46.839499  17.830811  21441.073269
# 3    169.153780  84.821063  34.580010  18407.008429
# 4    200.538071  58.198494  33.037069  21356.613741
# ..          ...        ...        ...           ...
# 495  139.303939  28.692048  22.788310  19123.186337
# 496  200.925955  83.707563  51.753104  20484.660588
# 497  160.398240  73.358791  43.467252  21305.649576
# 498  150.542980  89.121007  37.639512  19739.242741
# 499  134.342716  52.349067  37.172269  19463.214001
#
# [500 rows x 4 columns]

# %% [markdown]
# ## Operaciones diversas muy útiles

# %%
double_group.head(1)
# Out:
#    Gender Economic Status      Height     Weight        Age        Income
# 0    Male    Middle Class  118.639959  33.083603  27.763501  19097.542724
# 1  Female            Rich  100.965576  92.829558  39.016762  20619.454454
# 3  Female    Middle Class  169.153780  84.821063  34.580010  18407.008429
# 4    Male            Poor  200.538071  58.198494  33.037069  21356.613741
# 6    Male            Rich   75.437014  48.949403  50.704941  19392.653938
# 7  Female            Poor  170.812839  95.043379  23.841889  20303.345189

# %%
double_group.nth(32) ## treintaidosavo
# Out:
#                             Height      Weight        Age        Income
# Gender Economic Status
# Female Middle Class     169.767961   88.166765  27.410508  18925.623500
#        Poor             144.166895   63.236426  16.988667  19061.546918
#        Rich             169.932697   55.256954  22.592754  21146.672109
# Male   Middle Class     197.747374   59.849732  26.536119  21421.396599
#        Poor             167.932048   49.192061  24.390216  20952.625515
#        Rich             234.345952  100.096044  27.955372  19011.791940

# %%
double_group.nth(82)
# Out:
#                             Height     Weight        Age        Income
# Gender Economic Status
# Female Middle Class     207.908714  60.809575  33.940553  20797.598009
# Male   Middle Class     238.648201  71.769194  36.891079  18701.463155
#        Poor             203.082094  62.176407  30.013188  19920.107691
#        Rich             151.412290  67.081534  30.681408  20802.033485

# %%
data_sorted = data.sort_values(["Age", "Income"])

# %%
data_sorted.head(10)
# Out:
#      Gender Economic Status      Height     Weight       Age        Income
# 448    Male    Middle Class  154.958853  51.155447 -8.232566  19147.749164
# 450  Female            Poor  206.393569  32.002518 -7.476861  18434.240630
# 268  Female            Rich  225.516923  57.027485 -1.715703  19509.553562
# 74   Female    Middle Class  161.827204  71.786287  0.911961  20801.180254
# 206    Male            Rich  199.104659  65.355418  4.675203  18666.356038
# 349    Male    Middle Class  182.456190  26.556905  5.624359  20437.691429
# 364    Male            Rich  170.146162  92.389450  5.668987  18885.999115
# 124  Female            Poor  174.996456  85.534352  6.260650  19261.615119
# 171    Male            Poor  194.960981  97.838157  6.324339  21222.376421
# 292    Male            Rich  171.040649  73.199261  6.376824  18446.992765

# %%
age_grouped = data_sorted.groupby("Gender")

# %%
age_grouped.head(1)
# Out:
#      Gender Economic Status      Height     Weight       Age        Income
# 448    Male    Middle Class  154.958853  51.155447 -8.232566  19147.749164
# 450  Female            Poor  206.393569  32.002518 -7.476861  18434.240630

# %% [markdown]
# ### Conjunto de entrenamiento y conjunto de testing

# %%
import pandas as pd

# %%
data = pd.read_csv("../datasets/customer-churn-model/Customer Churn Model.txt")

# %%
len(data)
# Out:
# 3333

# %% [markdown]
# #### Dividir utilizando la distribución normal

# %%
a = np.random.randn(len(data))

# %%
plt.hist(a)
# Out:
# (array([3.000e+00, 3.400e+01, 2.540e+02, 6.880e+02, 1.074e+03, 8.930e+02,
#         3.090e+02, 7.100e+01, 6.000e+00, 1.000e+00]),
#  array([-3.9579821 , -3.09795616, -2.23793021, -1.37790426, -0.51787831,
#          0.34214763,  1.20217358,  2.06219953,  2.92222548,  3.78225143,
#          4.64227737]),
#  <a list of 10 Patch objects>)

# %%
check = (a<0.80)

# %%
check
# Out:
# array([ True,  True,  True, ..., False,  True,  True])

# %%
training = data[check]
testing = data[~check]

# %%
len(training)
# Out:
# 2581

# %%
len(testing)
# Out:
# 752

# %% [markdown]
# ## Con la libreria sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(data, test_size=0.2)

# %%
len(train)
# Out:
# 2666

# %%
len(test)
# Out:
# 667

# %% [markdown]
# ## Usando una funcion shuffle

# %%
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0       244.7           91         11.01       10.0           3         2.70
# 1       254.4          103         11.45       13.7           3         3.70
# 2       162.6          104          7.32       12.2           5         3.29
# 3       196.9           89          8.86        6.6           7         1.78
# 4       186.9          121          8.41       10.1           3         2.73
#
#    CustServ Calls  Churn?
# 0               1  False.
# 1               1  False.
# 2               0  False.
# 3               2  False.
# 4               3  False.
#
# [5 rows x 21 columns]

# %%
import sklearn

# %%
data = sklearn.utils.shuffle(data)

# %%
data.head()
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 2745    PA              61        408  343-1347         no        yes
# 1859    IL             116        510  360-7477         no         no
# 3153    AZ              94        415  366-9015         no         no
# 2903    DE              97        415  390-5267         no        yes
# 1673    WY              16        415  400-3197         no         no
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# 2745             40     105.0         78       17.85  ...        100
# 1859              0     164.6        110       27.98  ...        103
# 3153              0     220.8        111       37.54  ...         67
# 2903             32     183.4         94       31.18  ...        120
# 1673              0     174.7         83       29.70  ...        122
#
#       Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  \
# 2745       15.35       174.1          115          7.83       10.2
# 1859       23.00       230.4          109         10.37        8.0
# 3153       13.28       187.9           89          8.46       10.5
# 2903       22.87       203.5           38          9.16        6.7
# 1673       23.87       171.7           80          7.73       10.5
#
#       Intl Calls  Intl Charge  CustServ Calls  Churn?
# 2745           2         2.75               2   True.
# 1859           3         2.16               0  False.
# 3153           4         2.84               2  False.
# 2903           4         1.81               5  False.
# 1673           8         2.84               5  False.
#
# [5 rows x 21 columns]

# %%
cut_id = int(0.75 * len(data))
train_data = data[:cut_id]
test_data = data[(cut_id + 1):]

# %%
len(train_data)
# Out:
# 2499

# %%
len(test_data)
# Out:
# 833
